# %%
import numpy as np
import torch
import torch.nn as nn

import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# %%
# ============================================================
# LOAD BEST CONFIG
# ============================================================

import json

# Open the file and parse its contents
with open('descriptornet_datasetA_bho/best_config.json', 'r') as file:
    best_configuration = json.load(file)
best_configuration
# Out:
# {'depth': 2,
#  'width': 128,
#  'activation': 'gelu',
#  'lr': 0.0026820797458405802,
#  'batch_size': 256}

# %%
# ============================================================
# CONFIG
# ============================================================
TRAIN_DIR    = "../datasetA_training_data"
TEST_DIR     = "../datasetA_testing_data"
NET2_WEIGHTS = "../physicsnet/physicsnet_pretrained.pt"
 
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
 
# --- Network 1 (trained) ---
N1_DEPTH = best_configuration["depth"]
N1_WIDTH = best_configuration["width"]
N1_ACT = best_configuration["activation"]


# --- Network 2 (frozen) ---
N2_DEPTH = 3
N2_WIDTH = 256
N2_ACT = "silu"
 
# --- Training ---
EPOCHS = 200
LR = best_configuration["lr"]
BATCH_SIZE = best_configuration["batch_size"]
N_RHO_INTEGRATION = 20 # 50
 
SEED = 0

# %%
# ============================================================
# DATA
# ============================================================
def load_dataset(data_dir, start_id=0):
    c = np.load(f"{data_dir}/c_release_matrix.npy")[start_id:]
    t = np.load(f"{data_dir}/t_release_matrix.npy")[start_id:]
    D0 = np.load(f"{data_dir}/D0_array.npy")[start_id:]
    eps = np.load(f"{data_dir}/epsilon_array.npy")[start_id:]
    tau = np.load(f"{data_dir}/tau_ort_array.npy")[start_id:]
    D_eff = np.load(f"{data_dir}/Deff_array.npy")[start_id:]
    R = np.load(f"{data_dir}/R_array.npy")[start_id:]
    return {"c": c, "t": t, "D0": D0, "eps": eps, "tau": tau,
            "D_eff": D_eff, "R": R, "N": c.shape[0], "T": c.shape[1]}
 
 
def make_tensors(ds, desc_mean, desc_std):
    desc_raw = np.stack([ds["eps"], ds["tau"], np.log10(ds["D0"])], axis=1)
    desc_norm = (desc_raw - desc_mean) / desc_std
    return {
        "desc": torch.tensor(desc_norm, dtype=torch.float32, device=DEVICE),
        "t": torch.tensor(ds["t"], dtype=torch.float32, device=DEVICE),
        "c": torch.tensor(ds["c"], dtype=torch.float32, device=DEVICE),
        "R": torch.tensor(ds["R"], dtype=torch.float32, device=DEVICE),
        "D_eff": torch.tensor(ds["D_eff"], dtype=torch.float32, device=DEVICE),
        "N": ds["N"], "T": ds["T"],
    }

# %%
# ============================================================
# NETWORKS
# ============================================================
def get_activation(name):
    return {"tanh": nn.Tanh(), "silu": nn.SiLU(), "gelu": nn.GELU()}[name.lower()]
 
 
class MLP(nn.Module):
    def __init__(self, in_dim, out_dim, depth, width, activation):
        super().__init__()
        layers = [nn.Linear(in_dim, width), get_activation(activation)]
        for _ in range(depth - 1):
            layers += [nn.Linear(width, width), get_activation(activation)]
        layers.append(nn.Linear(width, out_dim))
        self.net = nn.Sequential(*layers)
 
    def forward(self, x):
        return self.net(x)
 
 
class DescriptorNet(nn.Module):
    """Network 1 (trained): descriptors -> log10(D_eff in cm^2/s)."""
    def __init__(self, n_desc=3, depth=N1_DEPTH, width=N1_WIDTH,
                 activation=N1_ACT, log10_D_init=-10.0):
        super().__init__()
        self.mlp = MLP(n_desc, 1, depth, width, activation)
        final_linear = self.mlp.net[-1]
        # nn.init.zeros_(final_linear.weight)
        nn.init.constant_(final_linear.bias, log10_D_init)
 
    def forward(self, desc):
        return self.mlp(desc).squeeze(-1)
 
 
class PhysicsNet(nn.Module):
    """Network 2 (frozen): (rho, Fo) -> u(rho, Fo).
 
    IMPORTANT: this class must be structurally identical to the PhysicsNet
    in pretrain_net2.py, including the ansatz form, or load_state_dict will
    fail or silently load wrong weights.
    """
    def __init__(self, depth=N2_DEPTH, width=N2_WIDTH, activation=N2_ACT):
        super().__init__()
        self.mlp = MLP(2, 1, depth, width, activation)
 
    def forward(self, rho, Fo):
        x = torch.cat([rho**2, Fo], dim=1)
        raw = self.mlp(x)
        return (1.0 - rho**2) * raw          # hard BC: u(rho=1) = 0

# %%
# ============================================================
# BRIDGE + INTEGRATION
# ============================================================
def predicted_release(net2, D_eff, t_abs, R, n_rho=N_RHO_INTEGRATION):
    """
    Predicted fractional release for a batch of particles.
 
    net2 is frozen, but we do NOT use torch.no_grad(): gradient must flow
    through net2 (w.r.t. its Fo input) back to D_eff and hence Network 1.
    Only net2's PARAMETERS are frozen, not the graph.
    """
    N, T = t_abs.shape
    device = t_abs.device
 
    Fo = D_eff.view(N, 1) * t_abs / (R.view(N, 1) ** 2)      # (N,T)
    rho_grid = torch.linspace(0, 1, n_rho, device=device)
 
    Fo_exp = Fo.view(N, T, 1).expand(N, T, n_rho)
    rho_exp = rho_grid.view(1, 1, n_rho).expand(N, T, n_rho)
 
    rho_flat = rho_exp.reshape(-1, 1)
    Fo_flat = Fo_exp.reshape(-1, 1)
 
    u = net2(rho_flat, Fo_flat).view(N, T, n_rho)
 
    integrand = u * (rho_grid.view(1, 1, n_rho) ** 2)
    integral = torch.trapz(integrand, rho_grid, dim=2)
    return 1.0 - 3.0 * integral

# %%
# ============================================================
# TRAIN
# ============================================================
def main():
    torch.manual_seed(SEED)
    np.random.seed(SEED)
    print(f"Device: {DEVICE}")
 
    # --- Data ---
    train_raw = load_dataset(TRAIN_DIR)
    test_raw = load_dataset(TEST_DIR)
    print(f"Train: {train_raw['N']} particles | Test: {test_raw['N']}")
 
    desc_raw_train = np.stack(
        [train_raw["eps"], train_raw["tau"], np.log10(train_raw["D0"])], axis=1
    )
    desc_mean = desc_raw_train.mean(axis=0)
    desc_std = desc_raw_train.std(axis=0)
 
    train = make_tensors(train_raw, desc_mean, desc_std)
    test = make_tensors(test_raw, desc_mean, desc_std)
 
    # --- Network 1: trained ---
    log10_D_init = float(np.mean(np.log10(train_raw["D_eff"])))
    # log10_D_init = -8.0
    print(f"Network 1 output bias init: log10(D) = {log10_D_init:.3f}")
    net1 = DescriptorNet(log10_D_init=log10_D_init).to(DEVICE)
 
    # --- Network 2: load pre-trained weights, then FREEZE ---
    net2 = PhysicsNet().to(DEVICE)
    try:
        state = torch.load(NET2_WEIGHTS, map_location=DEVICE)
        net2.load_state_dict(state)
    except Exception as e:
        raise RuntimeError(
            f"Failed to load {NET2_WEIGHTS}. The most likely cause is an "
            f"architecture mismatch: N2_DEPTH/N2_WIDTH/N2_ACT here must match "
            f"pretrain_net2.py exactly. Original error:\n{e}"
        )

    
    # Freeze: parameters do not update. Graph still flows through net2.
    for p in net2.parameters():
        p.requires_grad_(False)
    net2.eval()   # frozen physics; eval mode (no dropout/BN here anyway)
 
    n1_params = sum(p.numel() for p in net1.parameters())
    n2_params = sum(p.numel() for p in net2.parameters())
    print(f"Network 1 (trained): {n1_params:,} params")
    print(f"Network 2 (FROZEN):  {n2_params:,} params")
 
    # Optimizer gets ONLY Network 1's parameters.
    optimizer = torch.optim.Adam(net1.parameters(), lr=LR)
    print("-" * 70)
 
    N_train = train["N"]
    n_batches = (N_train + BATCH_SIZE - 1) // BATCH_SIZE
 
    for epoch in range(EPOCHS):
        net1.train()
 
        perm = torch.randperm(N_train, device=DEVICE)
        epoch_data = 0.0
 
        for b in range(n_batches):
            idx = perm[b * BATCH_SIZE:(b + 1) * BATCH_SIZE]
 
            optimizer.zero_grad()
 
            log10_D = net1(train["desc"][idx])
            D_eff_pred = 10.0 ** log10_D
 
            release_pred = predicted_release(
                net2, D_eff_pred, train["t"][idx], train["R"][idx]
            )
 
            loss_data = torch.mean((release_pred - train["c"][idx]) ** 2)
            loss_data.backward()
            grad_norm = sum(
                p.grad.norm().item()**2 
                for p in net1.parameters() 
                if p.grad is not None
            )**0.5

            
            torch.nn.utils.clip_grad_norm_(net1.parameters(), 1.0)
            optimizer.step()
 
            epoch_data += loss_data.item()
 
        epoch_data /= n_batches
 
        # --- Logging ---
        if epoch % 1 == 0 or epoch == EPOCHS - 1:
            net1.eval()
            with torch.no_grad():
                # D recovery error on train
                log_err_sum = 0.0
                for b in range(n_batches):
                    sl = slice(b * BATCH_SIZE, (b + 1) * BATCH_SIZE)
                    D_pred = 10.0 ** net1(train["desc"][sl])
                    D_true = train["D_eff"][sl]
                    log_err_sum += torch.sum(
                        torch.abs(torch.log10(D_pred) - torch.log10(D_true))
                    ).item()
                train_D_logerr = log_err_sum / N_train
 
                # D recovery error on test
                N_test = test["N"]
                n_tb = (N_test + BATCH_SIZE - 1) // BATCH_SIZE
                test_logerr_sum = 0.0
                test_data_sum = 0.0
                for b in range(n_tb):
                    sl = slice(b * BATCH_SIZE, (b + 1) * BATCH_SIZE)
                    D_pred = 10.0 ** net1(test["desc"][sl])
                    D_true = test["D_eff"][sl]
                    test_logerr_sum += torch.sum(
                        torch.abs(torch.log10(D_pred) - torch.log10(D_true))
                    ).item()
                    release_test = predicted_release(
                        net2, D_pred, test["t"][sl], test["R"][sl]
                    )
                    test_data_sum += torch.sum(
                        (release_test - test["c"][sl]) ** 2
                    ).item()
                test_D_logerr = test_logerr_sum / N_test
                test_data = test_data_sum / (N_test * test["T"])
        
 
            print(
                f"epoch {epoch:5d} | "
                f"data {epoch_data:.3e} | "
                f"test_data {test_data:.3e} | "
                f"D log-err train {train_D_logerr:.4f} | "
                f"test {test_D_logerr:.4f} | "
                f"gradient {grad_norm:.4f}"
            )
 
    print("-" * 70)
    return net1, net2

# %%
descriptornet, physicsnet = main()
# Out:
# Device: cuda
# Train: 8192 particles | Test: 1024
# Network 1 output bias init: log10(D) = -12.525
# Network 1 (trained): 17,153 params
# Network 2 (FROZEN):  132,609 params
# ----------------------------------------------------------------------
# epoch     0 | data 3.025e-03 | test_data 7.069e-04 | D log-err train 0.0260 | test 0.0260 | gradient 0.0047
# epoch     1 | data 6.449e-04 | test_data 5.784e-04 | D log-err train 0.0198 | test 0.0199 | gradient 0.0043
# epoch     2 | data 5.513e-04 | test_data 5.391e-04 | D log-err train 0.0118 | test 0.0118 | gradient 0.0010
# epoch     3 | data 5.331e-04 | test_data 5.275e-04 | D log-err train 0.0103 | test 0.0103 | gradient 0.0014
# epoch     4 | data 5.242e-04 | test_data 5.204e-04 | D log-err train 0.0103 | test 0.0103 | gradient 0.0007
# epoch     5 | data 5.189e-04 | test_data 5.177e-04 | D log-err train 0.0117 | test 0.0117 | gradient 0.0007
# epoch     6 | data 5.164e-04 | test_data 5.153e-04 | D log-err train 0.0104 | test 0.0104 | gradient 0.0012
# epoch     7 | data 5.149e-04 | test_data 5.147e-04 | D log-err train 0.0084 | test 0.0085 | gradient 0.0008
# epoch     8 | data 5.145e-04 | test_data 5.164e-04 | D log-err train 0.0126 | test 0.0126 | gradient 0.0014
# epoch     9 | data 5.146e-04 | test_data 5.147e-04 | D log-err train 0.0107 | test 0.0107 | gradient 0.0015
# epoch    10 | data 5.136e-04 | test_data 5.128e-04 | D log-err train 0.0086 | test 0.0086 | gradient 0.0008
# epoch    11 | data 5.123e-04 | test_data 5.134e-04 | D log-err train 0.0117 | test 0.0117 | gradient 0.0008
# epoch    12 | data 5.113e-04 | test_data 5.120e-04 | D log-err train 0.0072 | test 0.0073 | gradient 0.0011
# epoch    13 | data 5.112e-04 | test_data 5.111e-04 | D log-err train 0.0089 | test 0.0089 | gradient 0.0014
# epoch    14 | data 5.105e-04 | test_data 5.111e-04 | D log-err train 0.0094 | test 0.0094 | gradient 0.0003
# epoch    15 | data 5.099e-04 | test_data 5.091e-04 | D log-err train 0.0076 | test 0.0076 | gradient 0.0005
# epoch    16 | data 5.090e-04 | test_data 5.085e-04 | D log-err train 0.0095 | test 0.0095 | gradient 0.0007
# epoch    17 | data 5.084e-04 | test_data 5.077e-04 | D log-err train 0.0098 | test 0.0098 | gradient 0.0016
# epoch    18 | data 5.079e-04 | test_data 5.085e-04 | D log-err train 0.0111 | test 0.0111 | gradient 0.0010
# epoch    19 | data 5.070e-04 | test_data 5.073e-04 | D log-err train 0.0065 | test 0.0065 | gradient 0.0004
# epoch    20 | data 5.061e-04 | test_data 5.054e-04 | D log-err train 0.0080 | test 0.0080 | gradient 0.0011
# epoch    21 | data 5.057e-04 | test_data 5.063e-04 | D log-err train 0.0066 | test 0.0066 | gradient 0.0012
# epoch    22 | data 5.053e-04 | test_data 5.052e-04 | D log-err train 0.0061 | test 0.0061 | gradient 0.0005
# epoch    23 | data 5.047e-04 | test_data 5.046e-04 | D log-err train 0.0086 | test 0.0086 | gradient 0.0004
# epoch    24 | data 5.044e-04 | test_data 5.045e-04 | D log-err train 0.0095 | test 0.0095 | gradient 0.0009
# epoch    25 | data 5.042e-04 | test_data 5.043e-04 | D log-err train 0.0077 | test 0.0077 | gradient 0.0004
# epoch    26 | data 5.042e-04 | test_data 5.040e-04 | D log-err train 0.0081 | test 0.0081 | gradient 0.0007
# epoch    27 | data 5.039e-04 | test_data 5.041e-04 | D log-err train 0.0095 | test 0.0095 | gradient 0.0003
# epoch    28 | data 5.037e-04 | test_data 5.041e-04 | D log-err train 0.0080 | test 0.0080 | gradient 0.0004
# epoch    29 | data 5.039e-04 | test_data 5.037e-04 | D log-err train 0.0076 | test 0.0076 | gradient 0.0008
# epoch    30 | data 5.038e-04 | test_data 5.036e-04 | D log-err train 0.0079 | test 0.0079 | gradient 0.0004
# epoch    31 | data 5.041e-04 | test_data 5.038e-04 | D log-err train 0.0079 | test 0.0079 | gradient 0.0011
# epoch    32 | data 5.037e-04 | test_data 5.044e-04 | D log-err train 0.0097 | test 0.0097 | gradient 0.0007
# epoch    33 | data 5.038e-04 | test_data 5.034e-04 | D log-err train 0.0081 | test 0.0081 | gradient 0.0009
# epoch    34 | data 5.035e-04 | test_data 5.034e-04 | D log-err train 0.0073 | test 0.0073 | gradient 0.0006
# epoch    35 | data 5.035e-04 | test_data 5.035e-04 | D log-err train 0.0069 | test 0.0069 | gradient 0.0003
# epoch    36 | data 5.036e-04 | test_data 5.037e-04 | D log-err train 0.0088 | test 0.0088 | gradient 0.0009
# epoch    37 | data 5.037e-04 | test_data 5.034e-04 | D log-err train 0.0072 | test 0.0072 | gradient 0.0006
# epoch    38 | data 5.034e-04 | test_data 5.036e-04 | D log-err train 0.0091 | test 0.0091 | gradient 0.0005
# epoch    39 | data 5.035e-04 | test_data 5.034e-04 | D log-err train 0.0087 | test 0.0087 | gradient 0.0003
# epoch    40 | data 5.037e-04 | test_data 5.039e-04 | D log-err train 0.0062 | test 0.0063 | gradient 0.0004
# epoch    41 | data 5.036e-04 | test_data 5.051e-04 | D log-err train 0.0044 | test 0.0045 | gradient 0.0006
# epoch    42 | data 5.036e-04 | test_data 5.032e-04 | D log-err train 0.0076 | test 0.0076 | gradient 0.0004
# epoch    43 | data 5.033e-04 | test_data 5.033e-04 | D log-err train 0.0081 | test 0.0081 | gradient 0.0004
# epoch    44 | data 5.032e-04 | test_data 5.033e-04 | D log-err train 0.0074 | test 0.0074 | gradient 0.0004
# epoch    45 | data 5.034e-04 | test_data 5.032e-04 | D log-err train 0.0073 | test 0.0073 | gradient 0.0002
# epoch    46 | data 5.035e-04 | test_data 5.039e-04 | D log-err train 0.0096 | test 0.0096 | gradient 0.0012
# epoch    47 | data 5.035e-04 | test_data 5.032e-04 | D log-err train 0.0071 | test 0.0071 | gradient 0.0004
# epoch    48 | data 5.032e-04 | test_data 5.032e-04 | D log-err train 0.0085 | test 0.0085 | gradient 0.0005
# epoch    49 | data 5.032e-04 | test_data 5.033e-04 | D log-err train 0.0068 | test 0.0068 | gradient 0.0004
# epoch    50 | data 5.033e-04 | test_data 5.039e-04 | D log-err train 0.0101 | test 0.0101 | gradient 0.0007
# epoch    51 | data 5.038e-04 | test_data 5.045e-04 | D log-err train 0.0047 | test 0.0047 | gradient 0.0003
# epoch    52 | data 5.034e-04 | test_data 5.033e-04 | D log-err train 0.0089 | test 0.0089 | gradient 0.0006
# epoch    53 | data 5.031e-04 | test_data 5.030e-04 | D log-err train 0.0080 | test 0.0080 | gradient 0.0002
# epoch    54 | data 5.031e-04 | test_data 5.031e-04 | D log-err train 0.0087 | test 0.0087 | gradient 0.0004
# epoch    55 | data 5.032e-04 | test_data 5.033e-04 | D log-err train 0.0067 | test 0.0067 | gradient 0.0003
# epoch    56 | data 5.032e-04 | test_data 5.030e-04 | D log-err train 0.0072 | test 0.0072 | gradient 0.0006
# epoch    57 | data 5.035e-04 | test_data 5.032e-04 | D log-err train 0.0078 | test 0.0078 | gradient 0.0010
# epoch    58 | data 5.035e-04 | test_data 5.037e-04 | D log-err train 0.0086 | test 0.0086 | gradient 0.0009
# epoch    59 | data 5.034e-04 | test_data 5.036e-04 | D log-err train 0.0064 | test 0.0064 | gradient 0.0002
# epoch    60 | data 5.033e-04 | test_data 5.032e-04 | D log-err train 0.0079 | test 0.0079 | gradient 0.0005
# epoch    61 | data 5.032e-04 | test_data 5.041e-04 | D log-err train 0.0060 | test 0.0060 | gradient 0.0006
# epoch    62 | data 5.035e-04 | test_data 5.036e-04 | D log-err train 0.0098 | test 0.0098 | gradient 0.0005
# epoch    63 | data 5.031e-04 | test_data 5.034e-04 | D log-err train 0.0090 | test 0.0090 | gradient 0.0003
# epoch    64 | data 5.037e-04 | test_data 5.047e-04 | D log-err train 0.0107 | test 0.0107 | gradient 0.0013
# epoch    65 | data 5.038e-04 | test_data 5.035e-04 | D log-err train 0.0094 | test 0.0094 | gradient 0.0015
# epoch    66 | data 5.044e-04 | test_data 5.038e-04 | D log-err train 0.0058 | test 0.0058 | gradient 0.0004
# epoch    67 | data 5.042e-04 | test_data 5.030e-04 | D log-err train 0.0074 | test 0.0074 | gradient 0.0006
# epoch    68 | data 5.035e-04 | test_data 5.032e-04 | D log-err train 0.0083 | test 0.0083 | gradient 0.0004
# epoch    69 | data 5.033e-04 | test_data 5.034e-04 | D log-err train 0.0066 | test 0.0066 | gradient 0.0015
# epoch    70 | data 5.042e-04 | test_data 5.033e-04 | D log-err train 0.0091 | test 0.0091 | gradient 0.0012
# epoch    71 | data 5.042e-04 | test_data 5.034e-04 | D log-err train 0.0071 | test 0.0071 | gradient 0.0008
# epoch    72 | data 5.038e-04 | test_data 5.041e-04 | D log-err train 0.0052 | test 0.0052 | gradient 0.0010
# epoch    73 | data 5.052e-04 | test_data 5.036e-04 | D log-err train 0.0085 | test 0.0085 | gradient 0.0014
# epoch    74 | data 5.054e-04 | test_data 5.060e-04 | D log-err train 0.0040 | test 0.0040 | gradient 0.0018
# epoch    75 | data 5.049e-04 | test_data 5.044e-04 | D log-err train 0.0060 | test 0.0059 | gradient 0.0014
# epoch    76 | data 5.043e-04 | test_data 5.033e-04 | D log-err train 0.0071 | test 0.0071 | gradient 0.0004
# epoch    77 | data 5.032e-04 | test_data 5.033e-04 | D log-err train 0.0072 | test 0.0072 | gradient 0.0005
# epoch    78 | data 5.035e-04 | test_data 5.034e-04 | D log-err train 0.0076 | test 0.0076 | gradient 0.0006
# epoch    79 | data 5.035e-04 | test_data 5.045e-04 | D log-err train 0.0052 | test 0.0052 | gradient 0.0014
# epoch    80 | data 5.054e-04 | test_data 5.119e-04 | D log-err train 0.0136 | test 0.0136 | gradient 0.0013
# epoch    81 | data 5.061e-04 | test_data 5.053e-04 | D log-err train 0.0045 | test 0.0045 | gradient 0.0017
# epoch    82 | data 5.051e-04 | test_data 5.038e-04 | D log-err train 0.0071 | test 0.0071 | gradient 0.0013
# epoch    83 | data 5.040e-04 | test_data 5.033e-04 | D log-err train 0.0092 | test 0.0092 | gradient 0.0004
# epoch    84 | data 5.031e-04 | test_data 5.029e-04 | D log-err train 0.0073 | test 0.0073 | gradient 0.0003
# epoch    85 | data 5.030e-04 | test_data 5.032e-04 | D log-err train 0.0064 | test 0.0064 | gradient 0.0008
# epoch    86 | data 5.039e-04 | test_data 5.031e-04 | D log-err train 0.0066 | test 0.0066 | gradient 0.0004
# epoch    87 | data 5.034e-04 | test_data 5.045e-04 | D log-err train 0.0101 | test 0.0101 | gradient 0.0012
# epoch    88 | data 5.034e-04 | test_data 5.031e-04 | D log-err train 0.0068 | test 0.0068 | gradient 0.0006
# epoch    89 | data 5.031e-04 | test_data 5.030e-04 | D log-err train 0.0069 | test 0.0069 | gradient 0.0004
# epoch    90 | data 5.035e-04 | test_data 5.044e-04 | D log-err train 0.0100 | test 0.0100 | gradient 0.0012
# epoch    91 | data 5.059e-04 | test_data 5.062e-04 | D log-err train 0.0120 | test 0.0120 | gradient 0.0019
# epoch    92 | data 5.039e-04 | test_data 5.037e-04 | D log-err train 0.0062 | test 0.0062 | gradient 0.0004
# epoch    93 | data 5.039e-04 | test_data 5.063e-04 | D log-err train 0.0036 | test 0.0036 | gradient 0.0010
# epoch    94 | data 5.042e-04 | test_data 5.050e-04 | D log-err train 0.0051 | test 0.0051 | gradient 0.0004
# epoch    95 | data 5.043e-04 | test_data 5.031e-04 | D log-err train 0.0068 | test 0.0068 | gradient 0.0002
# epoch    96 | data 5.031e-04 | test_data 5.038e-04 | D log-err train 0.0075 | test 0.0075 | gradient 0.0005
# epoch    97 | data 5.037e-04 | test_data 5.036e-04 | D log-err train 0.0092 | test 0.0092 | gradient 0.0010
# epoch    98 | data 5.032e-04 | test_data 5.032e-04 | D log-err train 0.0083 | test 0.0082 | gradient 0.0007
# epoch    99 | data 5.034e-04 | test_data 5.043e-04 | D log-err train 0.0099 | test 0.0099 | gradient 0.0008
# epoch   100 | data 5.036e-04 | test_data 5.040e-04 | D log-err train 0.0083 | test 0.0083 | gradient 0.0013
# epoch   101 | data 5.044e-04 | test_data 5.034e-04 | D log-err train 0.0075 | test 0.0075 | gradient 0.0008
# epoch   102 | data 5.036e-04 | test_data 5.044e-04 | D log-err train 0.0097 | test 0.0097 | gradient 0.0010
# epoch   103 | data 5.033e-04 | test_data 5.031e-04 | D log-err train 0.0067 | test 0.0067 | gradient 0.0010
# epoch   104 | data 5.052e-04 | test_data 5.057e-04 | D log-err train 0.0116 | test 0.0116 | gradient 0.0027
# epoch   105 | data 5.072e-04 | test_data 5.052e-04 | D log-err train 0.0046 | test 0.0046 | gradient 0.0012
# epoch   106 | data 5.037e-04 | test_data 5.033e-04 | D log-err train 0.0082 | test 0.0082 | gradient 0.0004
# epoch   107 | data 5.034e-04 | test_data 5.029e-04 | D log-err train 0.0076 | test 0.0076 | gradient 0.0006
# epoch   108 | data 5.062e-04 | test_data 5.072e-04 | D log-err train 0.0110 | test 0.0110 | gradient 0.0020
# epoch   109 | data 5.043e-04 | test_data 5.046e-04 | D log-err train 0.0104 | test 0.0104 | gradient 0.0006
# epoch   110 | data 5.068e-04 | test_data 5.033e-04 | D log-err train 0.0075 | test 0.0075 | gradient 0.0013
# epoch   111 | data 5.034e-04 | test_data 5.028e-04 | D log-err train 0.0074 | test 0.0074 | gradient 0.0003
# epoch   112 | data 5.036e-04 | test_data 5.032e-04 | D log-err train 0.0075 | test 0.0075 | gradient 0.0006
# epoch   113 | data 5.033e-04 | test_data 5.045e-04 | D log-err train 0.0073 | test 0.0073 | gradient 0.0013
# epoch   114 | data 5.043e-04 | test_data 5.040e-04 | D log-err train 0.0072 | test 0.0072 | gradient 0.0010
# epoch   115 | data 5.033e-04 | test_data 5.035e-04 | D log-err train 0.0076 | test 0.0076 | gradient 0.0002
# epoch   116 | data 5.033e-04 | test_data 5.032e-04 | D log-err train 0.0081 | test 0.0081 | gradient 0.0011
# epoch   117 | data 5.033e-04 | test_data 5.029e-04 | D log-err train 0.0089 | test 0.0089 | gradient 0.0005
# epoch   118 | data 5.033e-04 | test_data 5.031e-04 | D log-err train 0.0074 | test 0.0074 | gradient 0.0005
# epoch   119 | data 5.031e-04 | test_data 5.028e-04 | D log-err train 0.0079 | test 0.0079 | gradient 0.0004
# epoch   120 | data 5.036e-04 | test_data 5.044e-04 | D log-err train 0.0049 | test 0.0049 | gradient 0.0017
# epoch   121 | data 5.033e-04 | test_data 5.033e-04 | D log-err train 0.0073 | test 0.0073 | gradient 0.0005
# epoch   122 | data 5.065e-04 | test_data 5.133e-04 | D log-err train 0.0061 | test 0.0061 | gradient 0.0022
# epoch   123 | data 5.150e-04 | test_data 5.154e-04 | D log-err train 0.0123 | test 0.0123 | gradient 0.0031
# epoch   124 | data 5.080e-04 | test_data 5.043e-04 | D log-err train 0.0075 | test 0.0075 | gradient 0.0012
# epoch   125 | data 5.046e-04 | test_data 5.038e-04 | D log-err train 0.0087 | test 0.0087 | gradient 0.0012
# epoch   126 | data 5.034e-04 | test_data 5.043e-04 | D log-err train 0.0047 | test 0.0047 | gradient 0.0007
# epoch   127 | data 5.037e-04 | test_data 5.029e-04 | D log-err train 0.0083 | test 0.0083 | gradient 0.0007
# epoch   128 | data 5.031e-04 | test_data 5.029e-04 | D log-err train 0.0083 | test 0.0083 | gradient 0.0007
# epoch   129 | data 5.033e-04 | test_data 5.032e-04 | D log-err train 0.0086 | test 0.0086 | gradient 0.0003
# epoch   130 | data 5.031e-04 | test_data 5.036e-04 | D log-err train 0.0090 | test 0.0090 | gradient 0.0006
# epoch   131 | data 5.033e-04 | test_data 5.039e-04 | D log-err train 0.0093 | test 0.0093 | gradient 0.0010
# epoch   132 | data 5.030e-04 | test_data 5.031e-04 | D log-err train 0.0090 | test 0.0090 | gradient 0.0006
# epoch   133 | data 5.044e-04 | test_data 5.047e-04 | D log-err train 0.0053 | test 0.0053 | gradient 0.0010
# epoch   134 | data 5.041e-04 | test_data 5.032e-04 | D log-err train 0.0073 | test 0.0073 | gradient 0.0010
# epoch   135 | data 5.035e-04 | test_data 5.046e-04 | D log-err train 0.0057 | test 0.0057 | gradient 0.0014
# epoch   136 | data 5.078e-04 | test_data 5.077e-04 | D log-err train 0.0121 | test 0.0121 | gradient 0.0026
# epoch   137 | data 5.051e-04 | test_data 5.051e-04 | D log-err train 0.0060 | test 0.0060 | gradient 0.0013
# epoch   138 | data 5.041e-04 | test_data 5.033e-04 | D log-err train 0.0090 | test 0.0090 | gradient 0.0005
# epoch   139 | data 5.041e-04 | test_data 5.062e-04 | D log-err train 0.0074 | test 0.0074 | gradient 0.0019
# epoch   140 | data 5.052e-04 | test_data 5.041e-04 | D log-err train 0.0094 | test 0.0094 | gradient 0.0007
# epoch   141 | data 5.037e-04 | test_data 5.033e-04 | D log-err train 0.0071 | test 0.0071 | gradient 0.0011
# epoch   142 | data 5.052e-04 | test_data 5.045e-04 | D log-err train 0.0052 | test 0.0052 | gradient 0.0003
# epoch   143 | data 5.041e-04 | test_data 5.043e-04 | D log-err train 0.0096 | test 0.0096 | gradient 0.0005
# epoch   144 | data 5.038e-04 | test_data 5.032e-04 | D log-err train 0.0066 | test 0.0066 | gradient 0.0007
# epoch   145 | data 5.031e-04 | test_data 5.031e-04 | D log-err train 0.0069 | test 0.0069 | gradient 0.0003
# epoch   146 | data 5.034e-04 | test_data 5.045e-04 | D log-err train 0.0065 | test 0.0065 | gradient 0.0007
# epoch   147 | data 5.047e-04 | test_data 5.063e-04 | D log-err train 0.0118 | test 0.0118 | gradient 0.0014
# epoch   148 | data 5.046e-04 | test_data 5.042e-04 | D log-err train 0.0078 | test 0.0078 | gradient 0.0009
# epoch   149 | data 5.044e-04 | test_data 5.041e-04 | D log-err train 0.0078 | test 0.0078 | gradient 0.0008
# epoch   150 | data 5.048e-04 | test_data 5.069e-04 | D log-err train 0.0063 | test 0.0063 | gradient 0.0008
# epoch   151 | data 5.044e-04 | test_data 5.057e-04 | D log-err train 0.0091 | test 0.0091 | gradient 0.0015
# epoch   152 | data 5.060e-04 | test_data 5.041e-04 | D log-err train 0.0085 | test 0.0085 | gradient 0.0013
# epoch   153 | data 5.037e-04 | test_data 5.044e-04 | D log-err train 0.0074 | test 0.0074 | gradient 0.0008
# epoch   154 | data 5.052e-04 | test_data 5.052e-04 | D log-err train 0.0061 | test 0.0061 | gradient 0.0008
# epoch   155 | data 5.046e-04 | test_data 5.034e-04 | D log-err train 0.0064 | test 0.0064 | gradient 0.0013
# epoch   156 | data 5.032e-04 | test_data 5.036e-04 | D log-err train 0.0078 | test 0.0077 | gradient 0.0011
# epoch   157 | data 5.046e-04 | test_data 5.056e-04 | D log-err train 0.0091 | test 0.0090 | gradient 0.0012
# epoch   158 | data 5.046e-04 | test_data 5.050e-04 | D log-err train 0.0079 | test 0.0079 | gradient 0.0019
# epoch   159 | data 5.039e-04 | test_data 5.028e-04 | D log-err train 0.0079 | test 0.0079 | gradient 0.0003
# epoch   160 | data 5.033e-04 | test_data 5.035e-04 | D log-err train 0.0089 | test 0.0089 | gradient 0.0009
# epoch   161 | data 5.036e-04 | test_data 5.036e-04 | D log-err train 0.0061 | test 0.0061 | gradient 0.0004
# epoch   162 | data 5.037e-04 | test_data 5.035e-04 | D log-err train 0.0093 | test 0.0093 | gradient 0.0003
# epoch   163 | data 5.032e-04 | test_data 5.030e-04 | D log-err train 0.0085 | test 0.0085 | gradient 0.0005
# epoch   164 | data 5.032e-04 | test_data 5.039e-04 | D log-err train 0.0091 | test 0.0091 | gradient 0.0007
# epoch   165 | data 5.043e-04 | test_data 5.034e-04 | D log-err train 0.0063 | test 0.0063 | gradient 0.0002
# epoch   166 | data 5.038e-04 | test_data 5.038e-04 | D log-err train 0.0073 | test 0.0073 | gradient 0.0007
# epoch   167 | data 5.045e-04 | test_data 5.061e-04 | D log-err train 0.0116 | test 0.0116 | gradient 0.0007
# epoch   168 | data 5.036e-04 | test_data 5.029e-04 | D log-err train 0.0084 | test 0.0084 | gradient 0.0005
# epoch   169 | data 5.038e-04 | test_data 5.035e-04 | D log-err train 0.0061 | test 0.0061 | gradient 0.0004
# epoch   170 | data 5.037e-04 | test_data 5.031e-04 | D log-err train 0.0090 | test 0.0090 | gradient 0.0008
# epoch   171 | data 5.070e-04 | test_data 5.116e-04 | D log-err train 0.0053 | test 0.0054 | gradient 0.0033
# epoch   172 | data 5.051e-04 | test_data 5.046e-04 | D log-err train 0.0068 | test 0.0068 | gradient 0.0009
# epoch   173 | data 5.037e-04 | test_data 5.040e-04 | D log-err train 0.0094 | test 0.0094 | gradient 0.0006
# epoch   174 | data 5.045e-04 | test_data 5.062e-04 | D log-err train 0.0052 | test 0.0052 | gradient 0.0015
# epoch   175 | data 5.038e-04 | test_data 5.029e-04 | D log-err train 0.0073 | test 0.0073 | gradient 0.0004
# epoch   176 | data 5.046e-04 | test_data 5.060e-04 | D log-err train 0.0104 | test 0.0104 | gradient 0.0028
# epoch   177 | data 5.038e-04 | test_data 5.032e-04 | D log-err train 0.0091 | test 0.0091 | gradient 0.0009
# epoch   178 | data 5.091e-04 | test_data 5.066e-04 | D log-err train 0.0088 | test 0.0088 | gradient 0.0008
# epoch   179 | data 5.061e-04 | test_data 5.038e-04 | D log-err train 0.0065 | test 0.0065 | gradient 0.0014
# epoch   180 | data 5.037e-04 | test_data 5.030e-04 | D log-err train 0.0084 | test 0.0083 | gradient 0.0003
# epoch   181 | data 5.035e-04 | test_data 5.029e-04 | D log-err train 0.0079 | test 0.0079 | gradient 0.0005
# epoch   182 | data 5.030e-04 | test_data 5.029e-04 | D log-err train 0.0084 | test 0.0084 | gradient 0.0003
# epoch   183 | data 5.029e-04 | test_data 5.031e-04 | D log-err train 0.0070 | test 0.0070 | gradient 0.0002
# epoch   184 | data 5.051e-04 | test_data 5.052e-04 | D log-err train 0.0084 | test 0.0084 | gradient 0.0012
# epoch   185 | data 5.053e-04 | test_data 5.064e-04 | D log-err train 0.0087 | test 0.0087 | gradient 0.0021
# epoch   186 | data 5.049e-04 | test_data 5.068e-04 | D log-err train 0.0063 | test 0.0063 | gradient 0.0008
# epoch   187 | data 5.052e-04 | test_data 5.061e-04 | D log-err train 0.0104 | test 0.0104 | gradient 0.0010
# epoch   188 | data 5.055e-04 | test_data 5.088e-04 | D log-err train 0.0088 | test 0.0088 | gradient 0.0020
# epoch   189 | data 5.067e-04 | test_data 5.047e-04 | D log-err train 0.0057 | test 0.0057 | gradient 0.0009
# epoch   190 | data 5.049e-04 | test_data 5.039e-04 | D log-err train 0.0072 | test 0.0072 | gradient 0.0008
# epoch   191 | data 5.034e-04 | test_data 5.031e-04 | D log-err train 0.0080 | test 0.0080 | gradient 0.0008
# epoch   192 | data 5.033e-04 | test_data 5.039e-04 | D log-err train 0.0092 | test 0.0092 | gradient 0.0009
# epoch   193 | data 5.031e-04 | test_data 5.030e-04 | D log-err train 0.0085 | test 0.0085 | gradient 0.0006
# epoch   194 | data 5.029e-04 | test_data 5.028e-04 | D log-err train 0.0081 | test 0.0081 | gradient 0.0003
# epoch   195 | data 5.029e-04 | test_data 5.028e-04 | D log-err train 0.0079 | test 0.0079 | gradient 0.0004
# epoch   196 | data 5.032e-04 | test_data 5.035e-04 | D log-err train 0.0083 | test 0.0083 | gradient 0.0011
# epoch   197 | data 5.032e-04 | test_data 5.029e-04 | D log-err train 0.0075 | test 0.0075 | gradient 0.0006
# epoch   198 | data 5.041e-04 | test_data 5.029e-04 | D log-err train 0.0083 | test 0.0083 | gradient 0.0018
# epoch   199 | data 5.044e-04 | test_data 5.039e-04 | D log-err train 0.0072 | test 0.0072 | gradient 0.0015
# ----------------------------------------------------------------------

# %%
train_raw = load_dataset(TRAIN_DIR)
test_raw = load_dataset(TEST_DIR)

desc_raw_train = np.stack(
    [train_raw["eps"], train_raw["tau"], np.log10(train_raw["D0"])], axis=1
)
desc_mean = desc_raw_train.mean(axis=0)
desc_std = desc_raw_train.std(axis=0)

train = make_tensors(train_raw, desc_mean, desc_std)
test = make_tensors(test_raw, desc_mean, desc_std)

# %%
log10_D_predicted = descriptornet(test["desc"]).detach().cpu().numpy()
log10_D_actual = np.log10(test["D_eff"].detach().cpu().numpy())

# %%
import numpy as np
from sklearn.metrics import r2_score

def parity_plot(y_true, y_pred, lo=-15.5, hi=-10.5, save=None):
    """Parity plot for log10(D_eff). Shared across Figs 6, 8, 9, 11."""
    y_true = np.asarray(y_true).ravel()
    y_pred = np.asarray(y_pred).ravel()
    r2 = r2_score(y_true, y_pred)

    fig, ax = plt.subplots(figsize=(3.4, 3.4), constrained_layout=True)

    ax.plot([lo, hi], [lo, hi], color='gray', linestyle='--',
            zorder=1, label=r'$y = x$')                       # identity first, behind
    ax.scatter(y_true, y_pred, color='#1f77b4', alpha=0.7,
               edgecolor='black', linewidth=0.4, s=28,
               zorder=2, label='Predictions')

    ax.set_xlim(lo, hi); ax.set_ylim(lo, hi)
    ax.set_aspect('equal', adjustable='box')                  # true 45° line
    ax.set_xlabel(r"True $\log_{10}(D_{\mathrm{eff}})$")
    ax.set_ylabel(r"Predicted $\log_{10}(D_{\mathrm{eff}})$")
    ax.grid(True)

    ax.text(0.05, 0.95, fr"$R^2 = {r2:.4f}$", transform=ax.transAxes,
            va='top', ha='left', fontsize=8,
            bbox=dict(boxstyle='round,pad=0.3', fc='white', ec='0.7', lw=0.6))
    ax.legend(loc='lower right')

    if save:
        fig.savefig(save + ".pdf")
        fig.savefig(save + ".png", dpi=600)
    return fig, ax

# ---- Figure 6: Dataset A (synthetic) ----
parity_plot(log10_D_actual, log10_D_predicted, save="../plots/fig6_datasetA_parity")
# Out:
# (<Figure size 340x340 with 1 Axes>,
#  <Axes: xlabel='Crank-fitted $\\log_{10}(D_{\\mathrm{eff}})$', ylabel='Predicted $\\log_{10}(D_{\\mathrm{eff}})$'>)

# %% [markdown]
# # Plot release % vs actual time for different D and R values

# %%
def integrate_release(net2, Fo, rho_grid):
    """
    Compute fractional release for a batch of Fo values.
 
    Fo       : (B,)
    rho_grid : (n_rho,)
    Returns release : (B,)
    """
    B    = Fo.shape[0]
    n_rho = rho_grid.shape[0]
 
    Fo_exp  = Fo.view(B, 1).expand(B, n_rho).reshape(-1, 1)   # (B*n_rho, 1)
    rho_exp = rho_grid.view(1, n_rho).expand(B, n_rho).reshape(-1, 1)
 
    u   = net2(rho_exp, Fo_exp).view(B, n_rho)                # (B, n_rho)
    M_t = torch.trapz(u * rho_grid**2, rho_grid, dim=1)       # (B,)
 
    return torch.clamp(1.0 - 3.0 * M_t, min=0.0, max=1.0)    # (B,)


def crank_release(t_s, D_cm2_s, R_cm, n_terms=50):
    """
    Fractional release at times t for diffusivity D and radius R.

    Internal units: t in seconds, R in cm, D in cm^2/s.

    Parameters
    ----------
    t_s : array_like
        Time in seconds (non-negative).
    D_cm2_s : float
        Effective diffusivity in cm^2/s (positive).
    R_cm : float
        Particle radius in cm (positive).
    n_terms : int
        Number of series terms. Default 50.

    Returns
    -------
    M_frac : ndarray
        Fractional release, clipped to [0, 1].
    """
    t_s = np.asarray(t_s, dtype=float)
    
    if D_cm2_s <= 0 or R_cm <= 0:
        raise ValueError(f"D and R must be positive (got D={D_cm2_s}, R={R_cm}).")

    # The Fourier number is dimensionless: (cm^2/s * s) / cm^2 = 1
    Fo = D_cm2_s * t_s / (R_cm ** 2)
    
    n = np.arange(1, n_terms + 1).reshape(-1, 1)
    Fo_row = Fo.reshape(1, -1)
    
    exponent = -(n ** 2) * (np.pi ** 2) * Fo_row
    series_sum = np.sum(np.exp(exponent) / (n ** 2), axis=0)

    M_frac = 1.0 - (6.0 / np.pi ** 2) * series_sum
    
    return np.clip(M_frac, 0.0, 1.0)

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import torch
import numpy as np

indices_to_study = [0, 15, 38]
colors = ['#1f77b4', '#ff7f0e', '#2ca02c']

fig, ax = plt.subplots(figsize=(6.5, 3.6))      # full width; a touch taller for the legend

particle_legend_elements = []
for i, studied_index in enumerate(indices_to_study):
    color = colors[i]
    R = test['R'][studied_index].item()
    D_eff_actual = test['D_eff'][studied_index].item()
    D_eff_predicted = 10 ** descriptornet(test['desc'][studied_index, :]).item()

    rho_grid = torch.tensor(np.linspace(0, 1, 100), device=DEVICE, dtype=torch.float32)
    Fo_values = np.linspace(0.00001, 1.5, 100)
    t_grid = Fo_values * R**2 / D_eff_predicted
    Fo_tensor = torch.tensor(Fo_values, device=DEVICE, dtype=torch.float32)

    release_predicted = integrate_release(physicsnet, Fo_tensor, rho_grid)
    release_actual = crank_release(t_grid, D_eff_actual, R, n_terms=50)
    rel_pred_np = release_predicted.detach().cpu().numpy().ravel()

    ax.plot(t_grid, release_actual, color=color, linestyle='-')    # analytical (solid)
    ax.plot(t_grid, rel_pred_np,   color=color, linestyle='--')    # prediction (dashed)

    label_text = (fr"Idx {studied_index}: $R$={R:.2e} cm, "
                  fr"$D_{{\mathrm{{eff}}}}$={D_eff_actual:.2e} cm$^2$/s")
    particle_legend_elements.append(
        Line2D([0], [0], color=color, linestyle='-', label=label_text)
    )

# ---- unified legend ----
style_legend_elements = [
    Line2D([0], [0], color='gray', linestyle='-',  label="Analytical (Crank)"),
    Line2D([0], [0], color='gray', linestyle='--', label="Predicted (PINN)"),
]
header_particles = Line2D([], [], color='none', label=r'$\bf{Particle\ parameters}$')
header_models    = Line2D([], [], color='none', label=r'$\bf{Model\ type}$')
spacer           = Line2D([], [], color='none', label=' ')
all_handles = [header_particles, *particle_legend_elements,
               spacer, header_models, *style_legend_elements]

ax.legend(handles=all_handles, loc='upper left', bbox_to_anchor=(1.02, 1.0),
          borderaxespad=0.0, fontsize=7)

# ---- axes ----
ax.set_xlabel(r"Time $t$ (s)")
ax.set_ylabel(r"Fractional release $\mathcal{F}(t)$")
ax.set_ylim(-0.02, 1.02)
ax.grid(True)

# reserve right margin so the SAVED width stays 6.5 in (external legend)
fig.subplots_adjust(left=0.085, right=0.62, top=0.96, bottom=0.13)

fig.savefig("../plots/fig7_datasetA_releases.pdf")
fig.savefig("../plots/fig7_datasetA_releases.png", dpi=600)
plt.show()

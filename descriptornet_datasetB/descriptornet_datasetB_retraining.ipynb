# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
import torch.nn.functional as F

import matplotlib.pyplot as plt

# %%
# ============================================================
# LOAD BEST CONFIG
# ============================================================

import json

# Open the file and parse its contents
with open('descriptornet_datasetB_bho/best_config.json', 'r') as file:
    best_configuration = json.load(file)
best_configuration
# Out:
# {'depth': 6,
#  'width': 256,
#  'activation': 'tanh',
#  'lr': 0.0027730839047650853,
#  'batch_size': 128,
#  'weight_decay': 0.0001}

# %%
# ============================================================
# CONFIG
# ============================================================
DATA_DIR     = "../plga_dataset/release_dataset_with_Crank_release_even.xlsx"
NET2_WEIGHTS = "../physicsnet/physicsnet_pretrained.pt"

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
 
# --- Network 1 (trained) ---
N1_DEPTH = best_configuration["depth"]
N1_WIDTH = best_configuration["width"]
N1_ACT   = best_configuration["activation"]


# --- Network 2 (frozen, must match pretrain_net2.py exactly) ---
N2_DEPTH = 3
N2_WIDTH = 256
N2_ACT = "silu"
 
# --- Training ---
WEIGHT_DECAY      = best_configuration['weight_decay']
EPOCHS            = 1000
LR                = best_configuration["lr"]
BATCH_SIZE        = best_configuration["batch_size"]        # rows (particle x timepoint pairs)
N_RHO_INTEGRATION = 30
 
# --- Data ---
DESCRIPTOR_COLS = [
    'Drug MW', 'Drug TPSA', 'Drug LogP', 'Polymer MW', 'LA/GA',
    'Initial Drug-to-Polymer Ratio', 'Particle Size',
    'Drug Loading Capacity', 'Drug Encapsulation Efficiency',
    'Solubility Enhancer Concentration'
]
SEED = 0
torch.manual_seed(SEED)
np.random.seed(SEED)

# %%
# ============================================================
# DATA LOADING
# ============================================================
def load_data(path, release_column="Crank_Release"):
    """
    Load flat table. Each row is one (particle, timepoint) pair.
    Returns flat numpy arrays ready for TensorDataset.
    Also returns per-particle arrays for D log-err evaluation.
    """
    df = pd.read_excel(path)
 
    # Unit conversions
    df['t_s']  = df['Time'] * 86400.0          # days -> seconds
    df['R_cm'] = df['Particle Size'] / 2.0 / 1e4  # diameter um -> radius cm
 
    # Flat arrays (one row per particle x timepoint)
    X = df[DESCRIPTOR_COLS].values.astype(float)   # (N_rows, n_desc)
    t = df['t_s'].values.astype(float)              # (N_rows,)
    R = df['R_cm'].values.astype(float)             # (N_rows,)
    c = df[release_column].values.astype(float)    # (N_rows,)
    D = df['Crank_D'].values.astype(float) * 10**4         # (N_rows,) eval only
 
    # Per-particle arrays for D log-err evaluation
    df_part = (df[['Formulation Index', 'Crank_D', 'R_cm'] + DESCRIPTOR_COLS]
               .drop_duplicates(subset=['Formulation Index'])
               .reset_index(drop=True))
    X_part = df_part[DESCRIPTOR_COLS].values.astype(float)
    D_part = df_part['Crank_D'].values.astype(float) * 10**4
    fid    = df_part['Formulation Index'].values
 
    # Fo sanity check
    Fo_approx = D * t / R**2
    print(f"D range: [{D.min():.3e}, {D.max():.3e}] cm^2/s")
    print(f"R range: [{R.min():.3e}, {R.max():.3e}] cm")
    print(f"t range: [{t.min():.1f}, {t.max():.1f}] s")
    print(f"Fo range (approx): [{Fo_approx.min():.4f}, {Fo_approx.max():.4f}]")
    if Fo_approx.max() > 1.5:
        print(f"  WARNING: {(Fo_approx > 1.5).sum()} rows have Fo > 1.5 "
              f"(will be clamped to PhysicsNet ceiling).")
 
    return (X, t, R, c, D,
            X_part, D_part, fid)

# %%
# ============================================================
# NETWORKS
# ============================================================
def get_activation(name):
    return {"tanh": nn.Tanh(), "silu": nn.SiLU(), "gelu": nn.GELU()}[name.lower()]
 
 
class MLP(nn.Module):
    def __init__(self, in_dim, out_dim, depth, width, activation):
        super().__init__()
        layers = [nn.Linear(in_dim, width), get_activation(activation)]
        for _ in range(depth - 1):
            layers += [nn.Linear(width, width), get_activation(activation)]
        layers.append(nn.Linear(width, out_dim))
        self.net = nn.Sequential(*layers)
 
    def forward(self, x):
        return self.net(x)
 
 
class DescriptorNet(nn.Module):
    """Network 1 (trained): descriptors -> log10(D_eff in cm^2/s)."""
    def __init__(self, n_desc, depth=N1_DEPTH, width=N1_WIDTH,
                 activation=N1_ACT, log10_D_init=-16.0):
        super().__init__()
        self.mlp = MLP(n_desc, 1, depth, width, activation)
        nn.init.constant_(self.mlp.net[-1].bias, log10_D_init)
 
    def forward(self, desc):
        return self.mlp(desc).squeeze(-1)      # (B,)
 
 
class PhysicsNet(nn.Module):
    """Network 2 (frozen): (rho, Fo) -> u(rho, Fo)."""
    def __init__(self, depth=N2_DEPTH, width=N2_WIDTH, activation=N2_ACT):
        super().__init__()
        self.mlp = MLP(2, 1, depth, width, activation)
 
    def forward(self, rho, Fo):
        x   = torch.cat([rho**2, Fo], dim=1)
        raw = self.mlp(x)
        return (1.0 - rho**2) * raw            # hard BC: u(rho=1) = 0

# %%
# ============================================================
# INTEGRATION
# ============================================================
def integrate_release(net2, Fo, rho_grid):
    """
    Compute fractional release for a batch of Fo values.
 
    Fo       : (B,)
    rho_grid : (n_rho,)
    Returns release : (B,)
    """
    B    = Fo.shape[0]
    n_rho = rho_grid.shape[0]
 
    Fo_exp  = Fo.view(B, 1).expand(B, n_rho).reshape(-1, 1)   # (B*n_rho, 1)
    rho_exp = rho_grid.view(1, n_rho).expand(B, n_rho).reshape(-1, 1)
 
    u   = net2(rho_exp, Fo_exp).view(B, n_rho)                # (B, n_rho)
    M_t = torch.trapz(u * rho_grid**2, rho_grid, dim=1)       # (B,)
 
    return torch.clamp(1.0 - 3.0 * M_t, min=0.0, max=1.0)    # (B,)
 
 
# ============================================================
# D LOG-ERR EVALUATION (per particle, not per row)
# ============================================================
@torch.no_grad()
def eval_D_logerr(net1, X_part_tensor, D_part_tensor):
    """Mean absolute log10 D error across particles."""
    net1.eval()
    log10_D_pred = net1(X_part_tensor)
    D_pred       = 10.0 ** log10_D_pred
    log_err      = torch.mean(
        torch.abs(torch.log10(D_pred) - torch.log10(D_part_tensor))
    )
    return log_err.item()

# %%
# ============================================================
# MAIN
# ============================================================
def main():

    test_error_list = []
    print(f"Device: {DEVICE}\n")
 
    # --- Load data ---
    (X, t, R, c, D,
     X_part, D_part, fid) = load_data(DATA_DIR)
 
    n_desc = X.shape[1]
    print(f"\n{n_desc} descriptor columns.\n")
 
    # Train/test split by FORMULATION (not by row)
    # This ensures no particle leaks between train and test.
    all_fids = np.unique(fid)
    fids_train, fids_test = train_test_split(
        all_fids, test_size=0.2, random_state=SEED
    )
 
    # Build row-level masks from formulation split
    df_tmp = pd.DataFrame({'Formulation Index': 
                           pd.read_excel(DATA_DIR)['Formulation Index'].values,
                           'row': np.arange(len(X))})
    # Re-derive formulation index per row from the data
    # Simpler: reload and align
    df_raw  = pd.read_excel(DATA_DIR)
    df_raw['t_s']  = df_raw['Time'] * 86400.0
    df_raw['R_cm'] = df_raw['Particle Size'] / 2.0 / 1e4
    row_fids = df_raw['Formulation Index'].values
 
    train_mask = np.isin(row_fids, fids_train)
    test_mask  = np.isin(row_fids, fids_test)
 
    # Descriptor scaler fit on training rows only
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X[train_mask])
    X_test_scaled  = scaler.transform(X[test_mask])
 
    # Per-particle tensors for D log-err eval
    part_train_mask = np.isin(fid, fids_train)
    part_test_mask  = np.isin(fid, fids_test)
    X_part_train = torch.tensor(
        scaler.transform(X_part[part_train_mask]),
        dtype=torch.float32, device=DEVICE)
    X_part_test  = torch.tensor(
        scaler.transform(X_part[part_test_mask]),
        dtype=torch.float32, device=DEVICE)
    D_part_train = torch.tensor(D_part[part_train_mask],
                                dtype=torch.float32, device=DEVICE)
    D_part_test  = torch.tensor(D_part[part_test_mask],
                                dtype=torch.float32, device=DEVICE)
 
    # DataLoaders (flat rows)
    def make_loader(X_scaled, mask, shuffle):
        ds = TensorDataset(
            torch.tensor(X_scaled,      dtype=torch.float32),
            torch.tensor(t[mask],       dtype=torch.float32),
            torch.tensor(R[mask],       dtype=torch.float32),
            torch.tensor(c[mask],       dtype=torch.float32),
        )
        return DataLoader(ds, batch_size=BATCH_SIZE, shuffle=shuffle)
 
    train_loader = make_loader(X_train_scaled, train_mask, shuffle=True)
    test_loader  = make_loader(X_test_scaled,  test_mask,  shuffle=False)
 
    print(f"Train rows: {train_mask.sum()} | "
          f"Train particles: {part_train_mask.sum()}")
    print(f"Test  rows: {test_mask.sum()}  | "
          f"Test  particles: {part_test_mask.sum()}")
 
    # --- Networks ---
    log10_D_init = -10
    net1 = DescriptorNet(n_desc=n_desc,
                         log10_D_init=log10_D_init).to(DEVICE)
    print(f"\nNetwork 1 bias init: log10(D) = {log10_D_init:.3f}")
    print(f"Network 1 params: {sum(p.numel() for p in net1.parameters()):,}")
 
    net2 = PhysicsNet().to(DEVICE)
    net2.load_state_dict(torch.load(NET2_WEIGHTS, map_location=DEVICE))
    for p in net2.parameters():
        p.requires_grad_(False)
    net2.eval()
    print(f"Network 2 params: {sum(p.numel() for p in net2.parameters()):,} (FROZEN)")
 
    rho_grid = torch.linspace(0, 1, N_RHO_INTEGRATION, device=DEVICE)
 
    optimizer = torch.optim.Adam(net1.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
    print("-" * 70)
 
    # --- Training loop ---
    for epoch in range(EPOCHS):
        net1.train()
        epoch_loss = 0.0
 
        for desc_b, t_b, R_b, c_b in train_loader:
            desc_b = desc_b.to(DEVICE)
            t_b    = t_b.to(DEVICE)
            R_b    = R_b.to(DEVICE)
            c_b    = c_b.to(DEVICE)
 
            optimizer.zero_grad()
 
            log10_D = net1(desc_b)                          # (B,)
            D_pred  = 10.0 ** log10_D                       # (B,)
            Fo      = torch.clamp(D_pred * t_b / R_b**2,
                                  min=0.0, max=1.5)         # (B,)
 
            release = integrate_release(net2, Fo, rho_grid)         # (B,)
 
            loss = torch.mean((release - c_b)**2)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(net1.parameters(), 1.0)
            optimizer.step()
            epoch_loss += loss.item()
 
        epoch_loss /= len(train_loader)
 
        if epoch % 1 == 0 or epoch == EPOCHS - 1:
            train_D_err = eval_D_logerr(net1, X_part_train, D_part_train)
            test_D_err  = eval_D_logerr(net1, X_part_test,  D_part_test)

            # Test MSE on release
            net1.eval()
            with torch.no_grad():
                test_mse = 0.0
                for desc_b, t_b, R_b, c_b in test_loader:
                    desc_b, t_b, R_b, c_b = [x.to(DEVICE) for x in [desc_b, t_b, R_b, c_b]]
                    D_pred  = 10.0 ** net1(desc_b)
                    Fo      = torch.clamp(D_pred * t_b / R_b**2, 0.0, 1.5)
                    release = integrate_release(net2, Fo, rho_grid)
                    test_mse += torch.mean((release - c_b)**2).item()
                test_mse /= len(test_loader)
            net1.train()

            test_error_list.append(test_mse)
            print(f"epoch {epoch:5d} | "
                  f"train_loss {epoch_loss:.3e} | "
                  f"test_mse {test_mse:.3e} | "
                  f"D log-err  train {train_D_err:.4f} | "
                  f"test {test_D_err:.4f}")

    print(f"Min_error = {min(test_error_list):.4f}, its index is {test_error_list.index(min(test_error_list))}")
    print("-" * 70)
    return net1, net2

# %% [markdown]
# ## Train until 1000 iterations

# %%
SEED = 0
EPOCHS = 1000
torch.manual_seed(SEED)
np.random.seed(SEED)
descriptornet, physicsnet = main()
# Out:
# Device: cuda
#
# D range: [7.181e-17, 2.736e-11] cm^2/s
# R range: [5.765e-05, 1.478e-02] cm
# t range: [0.0, 20540069.3] s
# Fo range (approx): [0.0000, 1.7138]
#   WARNING: 5 rows have Fo > 1.5 (will be clamped to PhysicsNet ceiling).
#
# 10 descriptor columns.
#
# Train rows: 12800 | Train particles: 256
# Test  rows: 3250  | Test  particles: 65
#
# Network 1 bias init: log10(D) = -10.000
# Network 1 params: 332,033
# Network 2 params: 132,609 (FROZEN)
# ----------------------------------------------------------------------
# epoch     0 | train_loss 5.682e-02 | test_mse 3.295e-02 | D log-err  train 0.3254 | test 0.3702
# epoch     1 | train_loss 2.405e-02 | test_mse 3.649e-02 | D log-err  train 0.3062 | test 0.3888
# epoch     2 | train_loss 1.601e-02 | test_mse 2.534e-02 | D log-err  train 0.1933 | test 0.2942
# epoch     3 | train_loss 1.193e-02 | test_mse 2.779e-02 | D log-err  train 0.2098 | test 0.3001
# epoch     4 | train_loss 1.124e-02 | test_mse 3.121e-02 | D log-err  train 0.1540 | test 0.3331
# epoch     5 | train_loss 8.095e-03 | test_mse 2.786e-02 | D log-err  train 0.1370 | test 0.3014
# epoch     6 | train_loss 6.399e-03 | test_mse 3.165e-02 | D log-err  train 0.1757 | test 0.3564
# epoch     7 | train_loss 7.278e-03 | test_mse 2.496e-02 | D log-err  train 0.1225 | test 0.2902
# epoch     8 | train_loss 5.695e-03 | test_mse 2.809e-02 | D log-err  train 0.1043 | test 0.2945
# epoch     9 | train_loss 6.823e-03 | test_mse 3.198e-02 | D log-err  train 0.1263 | test 0.3082
# epoch    10 | train_loss 4.620e-03 | test_mse 2.796e-02 | D log-err  train 0.1013 | test 0.3083
# epoch    11 | train_loss 5.288e-03 | test_mse 2.600e-02 | D log-err  train 0.1061 | test 0.2974
# epoch    12 | train_loss 5.231e-03 | test_mse 3.028e-02 | D log-err  train 0.1478 | test 0.3543
# epoch    13 | train_loss 5.490e-03 | test_mse 3.105e-02 | D log-err  train 0.1223 | test 0.3315
# epoch    14 | train_loss 5.503e-03 | test_mse 2.907e-02 | D log-err  train 0.1201 | test 0.3209
# epoch    15 | train_loss 4.815e-03 | test_mse 2.916e-02 | D log-err  train 0.1393 | test 0.3474
# epoch    16 | train_loss 4.615e-03 | test_mse 2.889e-02 | D log-err  train 0.1100 | test 0.3170
# epoch    17 | train_loss 4.752e-03 | test_mse 3.242e-02 | D log-err  train 0.1181 | test 0.3562
# epoch    18 | train_loss 4.388e-03 | test_mse 3.268e-02 | D log-err  train 0.1112 | test 0.3516
# epoch    19 | train_loss 4.381e-03 | test_mse 3.025e-02 | D log-err  train 0.1009 | test 0.3275
# epoch    20 | train_loss 4.312e-03 | test_mse 2.675e-02 | D log-err  train 0.1072 | test 0.3073
# epoch    21 | train_loss 5.343e-03 | test_mse 3.215e-02 | D log-err  train 0.1056 | test 0.3410
# epoch    22 | train_loss 3.605e-03 | test_mse 2.994e-02 | D log-err  train 0.0988 | test 0.3300
# epoch    23 | train_loss 4.321e-03 | test_mse 2.883e-02 | D log-err  train 0.1490 | test 0.3561
# epoch    24 | train_loss 4.537e-03 | test_mse 3.026e-02 | D log-err  train 0.1005 | test 0.3163
# epoch    25 | train_loss 3.956e-03 | test_mse 2.739e-02 | D log-err  train 0.1488 | test 0.3266
# epoch    26 | train_loss 4.121e-03 | test_mse 3.187e-02 | D log-err  train 0.1124 | test 0.3375
# epoch    27 | train_loss 4.139e-03 | test_mse 2.817e-02 | D log-err  train 0.0871 | test 0.3241
# epoch    28 | train_loss 4.165e-03 | test_mse 2.859e-02 | D log-err  train 0.0896 | test 0.3100
# epoch    29 | train_loss 4.037e-03 | test_mse 3.061e-02 | D log-err  train 0.1242 | test 0.3278
# epoch    30 | train_loss 3.748e-03 | test_mse 3.037e-02 | D log-err  train 0.0850 | test 0.3214
# epoch    31 | train_loss 4.737e-03 | test_mse 2.700e-02 | D log-err  train 0.1362 | test 0.3329
# epoch    32 | train_loss 4.172e-03 | test_mse 2.996e-02 | D log-err  train 0.1166 | test 0.3202
# epoch    33 | train_loss 3.768e-03 | test_mse 2.946e-02 | D log-err  train 0.0987 | test 0.3123
# epoch    34 | train_loss 3.463e-03 | test_mse 2.909e-02 | D log-err  train 0.0744 | test 0.3017
# epoch    35 | train_loss 3.984e-03 | test_mse 3.301e-02 | D log-err  train 0.1216 | test 0.3386
# epoch    36 | train_loss 4.542e-03 | test_mse 2.691e-02 | D log-err  train 0.0895 | test 0.3116
# epoch    37 | train_loss 3.589e-03 | test_mse 2.791e-02 | D log-err  train 0.0849 | test 0.2985
# epoch    38 | train_loss 4.020e-03 | test_mse 2.998e-02 | D log-err  train 0.0823 | test 0.3148
# epoch    39 | train_loss 3.733e-03 | test_mse 2.646e-02 | D log-err  train 0.1522 | test 0.3188
# epoch    40 | train_loss 4.469e-03 | test_mse 2.866e-02 | D log-err  train 0.0747 | test 0.3098
# epoch    41 | train_loss 3.144e-03 | test_mse 2.637e-02 | D log-err  train 0.0947 | test 0.3079
# epoch    42 | train_loss 3.149e-03 | test_mse 2.871e-02 | D log-err  train 0.0905 | test 0.2979
# epoch    43 | train_loss 4.081e-03 | test_mse 3.035e-02 | D log-err  train 0.0902 | test 0.3210
# epoch    44 | train_loss 3.581e-03 | test_mse 2.835e-02 | D log-err  train 0.0743 | test 0.3064
# epoch    45 | train_loss 3.078e-03 | test_mse 3.033e-02 | D log-err  train 0.1064 | test 0.3199
# epoch    46 | train_loss 3.780e-03 | test_mse 2.981e-02 | D log-err  train 0.0930 | test 0.3213
# epoch    47 | train_loss 3.712e-03 | test_mse 2.893e-02 | D log-err  train 0.1053 | test 0.3112
# epoch    48 | train_loss 3.686e-03 | test_mse 2.927e-02 | D log-err  train 0.1002 | test 0.3054
# epoch    49 | train_loss 3.968e-03 | test_mse 2.931e-02 | D log-err  train 0.0901 | test 0.3165
# epoch    50 | train_loss 3.254e-03 | test_mse 2.946e-02 | D log-err  train 0.0776 | test 0.3014
# epoch    51 | train_loss 3.228e-03 | test_mse 2.762e-02 | D log-err  train 0.0791 | test 0.3053
# epoch    52 | train_loss 3.346e-03 | test_mse 3.105e-02 | D log-err  train 0.1011 | test 0.3174
# epoch    53 | train_loss 3.416e-03 | test_mse 2.972e-02 | D log-err  train 0.0786 | test 0.3035
# epoch    54 | train_loss 3.856e-03 | test_mse 3.037e-02 | D log-err  train 0.0929 | test 0.3151
# epoch    55 | train_loss 3.415e-03 | test_mse 3.021e-02 | D log-err  train 0.0770 | test 0.3158
# epoch    56 | train_loss 2.916e-03 | test_mse 2.839e-02 | D log-err  train 0.0671 | test 0.2946
# epoch    57 | train_loss 3.714e-03 | test_mse 3.038e-02 | D log-err  train 0.1445 | test 0.3388
# epoch    58 | train_loss 1.074e-01 | test_mse 1.539e-01 | D log-err  train 3.2681 | test 3.6233
# epoch    59 | train_loss 1.397e-01 | test_mse 1.344e-01 | D log-err  train 2.5728 | test 2.9601
# epoch    60 | train_loss 1.375e-01 | test_mse 1.593e-01 | D log-err  train 3.3886 | test 3.9429
# epoch    61 | train_loss 1.421e-01 | test_mse 1.544e-01 | D log-err  train 3.1087 | test 3.3638
# epoch    62 | train_loss 1.486e-01 | test_mse 1.532e-01 | D log-err  train 3.1583 | test 3.3614
# epoch    63 | train_loss 1.422e-01 | test_mse 1.400e-01 | D log-err  train 2.7374 | test 2.9996
# epoch    64 | train_loss 1.279e-01 | test_mse 1.620e-01 | D log-err  train 2.5612 | test 2.7547
# epoch    65 | train_loss 1.435e-01 | test_mse 1.977e-01 | D log-err  train 4.1434 | test 4.4922
# epoch    66 | train_loss 1.238e-01 | test_mse 1.083e-01 | D log-err  train 1.4379 | test 1.4029
# epoch    67 | train_loss 1.169e-01 | test_mse 1.191e-01 | D log-err  train 1.5488 | test 1.4693
# epoch    68 | train_loss 1.122e-01 | test_mse 1.183e-01 | D log-err  train 1.8443 | test 1.9027
# epoch    69 | train_loss 1.127e-01 | test_mse 1.043e-01 | D log-err  train 1.0535 | test 1.0797
# epoch    70 | train_loss 1.070e-01 | test_mse 9.932e-02 | D log-err  train 1.2409 | test 1.0459
# epoch    71 | train_loss 1.011e-01 | test_mse 1.020e-01 | D log-err  train 0.8946 | test 0.8977
# epoch    72 | train_loss 1.011e-01 | test_mse 9.855e-02 | D log-err  train 0.8087 | test 0.8312
# epoch    73 | train_loss 9.556e-02 | test_mse 9.956e-02 | D log-err  train 0.8127 | test 0.8426
# epoch    74 | train_loss 9.513e-02 | test_mse 9.867e-02 | D log-err  train 0.8081 | test 0.8322
# epoch    75 | train_loss 9.585e-02 | test_mse 9.959e-02 | D log-err  train 0.8356 | test 0.8432
# epoch    76 | train_loss 9.507e-02 | test_mse 9.906e-02 | D log-err  train 0.8151 | test 0.8338
# epoch    77 | train_loss 9.474e-02 | test_mse 1.069e-01 | D log-err  train 0.8879 | test 0.9016
# epoch    78 | train_loss 9.573e-02 | test_mse 9.898e-02 | D log-err  train 0.8080 | test 0.8385
# epoch    79 | train_loss 9.567e-02 | test_mse 9.991e-02 | D log-err  train 0.8255 | test 0.8424
# epoch    80 | train_loss 9.798e-02 | test_mse 1.006e-01 | D log-err  train 0.8325 | test 0.8484
# epoch    81 | train_loss 9.468e-02 | test_mse 1.001e-01 | D log-err  train 0.8186 | test 0.8470
# epoch    82 | train_loss 9.520e-02 | test_mse 9.852e-02 | D log-err  train 0.8041 | test 0.8328
# epoch    83 | train_loss 9.561e-02 | test_mse 9.850e-02 | D log-err  train 0.8034 | test 0.8327
# epoch    84 | train_loss 9.612e-02 | test_mse 1.010e-01 | D log-err  train 0.8363 | test 0.8521
# epoch    85 | train_loss 9.541e-02 | test_mse 1.009e-01 | D log-err  train 0.8358 | test 0.8516
# epoch    86 | train_loss 9.556e-02 | test_mse 9.866e-02 | D log-err  train 0.8086 | test 0.8318
# epoch    87 | train_loss 9.392e-02 | test_mse 9.334e-02 | D log-err  train 1.0114 | test 0.9176
# epoch    88 | train_loss 9.491e-02 | test_mse 9.854e-02 | D log-err  train 0.8043 | test 0.8334
# epoch    89 | train_loss 9.543e-02 | test_mse 1.017e-01 | D log-err  train 0.8435 | test 0.8586
# epoch    90 | train_loss 9.451e-02 | test_mse 9.861e-02 | D log-err  train 0.8049 | test 0.8343
# epoch    91 | train_loss 9.483e-02 | test_mse 9.849e-02 | D log-err  train 0.8040 | test 0.8331
# epoch    92 | train_loss 9.443e-02 | test_mse 9.355e-02 | D log-err  train 0.7668 | test 0.7804
# epoch    93 | train_loss 9.691e-02 | test_mse 1.031e-01 | D log-err  train 1.0708 | test 0.9739
# epoch    94 | train_loss 9.698e-02 | test_mse 1.027e-01 | D log-err  train 1.1003 | test 1.0654
# epoch    95 | train_loss 9.837e-02 | test_mse 1.075e-01 | D log-err  train 1.3884 | test 1.2897
# epoch    96 | train_loss 9.659e-02 | test_mse 9.992e-02 | D log-err  train 0.7995 | test 0.8707
# epoch    97 | train_loss 9.664e-02 | test_mse 1.022e-01 | D log-err  train 0.9290 | test 0.8623
# epoch    98 | train_loss 9.627e-02 | test_mse 1.016e-01 | D log-err  train 0.9246 | test 0.8577
# epoch    99 | train_loss 9.633e-02 | test_mse 9.923e-02 | D log-err  train 0.9003 | test 0.8355
# epoch   100 | train_loss 9.663e-02 | test_mse 9.921e-02 | D log-err  train 0.8601 | test 0.8353
# epoch   101 | train_loss 9.677e-02 | test_mse 9.923e-02 | D log-err  train 0.8171 | test 0.8356
# epoch   102 | train_loss 9.569e-02 | test_mse 9.912e-02 | D log-err  train 0.8089 | test 0.8396
# epoch   103 | train_loss 9.627e-02 | test_mse 1.005e-01 | D log-err  train 0.8230 | test 0.8513
# epoch   104 | train_loss 9.480e-02 | test_mse 9.860e-02 | D log-err  train 0.8074 | test 0.8316
# epoch   105 | train_loss 9.502e-02 | test_mse 9.862e-02 | D log-err  train 0.8078 | test 0.8314
# epoch   106 | train_loss 9.260e-02 | test_mse 7.525e-02 | D log-err  train 0.8939 | test 0.9847
# epoch   107 | train_loss 1.134e-01 | test_mse 1.036e-01 | D log-err  train 0.9949 | test 0.9354
# epoch   108 | train_loss 1.029e-01 | test_mse 1.036e-01 | D log-err  train 0.9947 | test 0.9356
# epoch   109 | train_loss 9.959e-02 | test_mse 1.049e-01 | D log-err  train 0.8690 | test 0.8871
# epoch   110 | train_loss 9.522e-02 | test_mse 9.798e-02 | D log-err  train 0.8031 | test 0.8269
# epoch   111 | train_loss 9.699e-02 | test_mse 1.127e-01 | D log-err  train 1.6460 | test 1.5268
# epoch   112 | train_loss 1.033e-01 | test_mse 9.945e-02 | D log-err  train 0.8201 | test 0.8380
# epoch   113 | train_loss 9.564e-02 | test_mse 9.904e-02 | D log-err  train 0.8083 | test 0.8390
# epoch   114 | train_loss 9.512e-02 | test_mse 9.894e-02 | D log-err  train 0.8344 | test 0.8335
# epoch   115 | train_loss 9.516e-02 | test_mse 9.933e-02 | D log-err  train 0.8186 | test 0.8367
# epoch   116 | train_loss 9.603e-02 | test_mse 1.153e-01 | D log-err  train 1.9637 | test 2.0309
# epoch   117 | train_loss 9.701e-02 | test_mse 9.964e-02 | D log-err  train 0.8405 | test 0.8430
# epoch   118 | train_loss 9.657e-02 | test_mse 9.920e-02 | D log-err  train 0.8404 | test 0.8353
# epoch   119 | train_loss 9.579e-02 | test_mse 9.900e-02 | D log-err  train 0.8315 | test 0.8340
# epoch   120 | train_loss 9.618e-02 | test_mse 1.127e-01 | D log-err  train 1.0337 | test 1.0483
# epoch   121 | train_loss 1.033e-01 | test_mse 9.970e-02 | D log-err  train 0.9154 | test 0.9621
# epoch   122 | train_loss 9.587e-02 | test_mse 1.017e-01 | D log-err  train 0.8506 | test 0.9768
# epoch   123 | train_loss 9.546e-02 | test_mse 1.001e-01 | D log-err  train 0.9718 | test 0.9573
# epoch   124 | train_loss 9.578e-02 | test_mse 1.000e-01 | D log-err  train 0.8283 | test 0.8455
# epoch   125 | train_loss 9.548e-02 | test_mse 9.883e-02 | D log-err  train 0.8078 | test 0.8374
# epoch   126 | train_loss 9.514e-02 | test_mse 9.814e-02 | D log-err  train 0.8055 | test 0.8301
# epoch   127 | train_loss 9.473e-02 | test_mse 9.959e-02 | D log-err  train 0.8304 | test 0.8411
# epoch   128 | train_loss 9.390e-02 | test_mse 1.084e-01 | D log-err  train 0.8853 | test 0.9109
# epoch   129 | train_loss 9.649e-02 | test_mse 9.957e-02 | D log-err  train 0.8131 | test 0.8427
# epoch   130 | train_loss 9.665e-02 | test_mse 1.071e-01 | D log-err  train 0.8920 | test 0.9022
# epoch   131 | train_loss 9.529e-02 | test_mse 9.993e-02 | D log-err  train 0.8258 | test 0.8428
# epoch   132 | train_loss 9.488e-02 | test_mse 9.845e-02 | D log-err  train 0.8045 | test 0.8306
# epoch   133 | train_loss 9.407e-02 | test_mse 9.857e-02 | D log-err  train 0.8182 | test 0.8323
# epoch   134 | train_loss 9.628e-02 | test_mse 1.023e-01 | D log-err  train 0.8424 | test 0.8687
# epoch   135 | train_loss 9.476e-02 | test_mse 1.099e-01 | D log-err  train 0.9147 | test 0.9258
# epoch   136 | train_loss 9.738e-02 | test_mse 1.002e-01 | D log-err  train 0.8198 | test 0.8481
# epoch   137 | train_loss 9.503e-02 | test_mse 1.033e-01 | D log-err  train 0.8522 | test 0.8756
# epoch   138 | train_loss 9.579e-02 | test_mse 1.067e-01 | D log-err  train 0.8859 | test 0.8997
# epoch   139 | train_loss 1.369e-01 | test_mse 1.794e-01 | D log-err  train 3.8902 | test 3.6920
# epoch   140 | train_loss 1.246e-01 | test_mse 1.113e-01 | D log-err  train 1.2793 | test 1.2626
# epoch   141 | train_loss 1.120e-01 | test_mse 1.032e-01 | D log-err  train 1.5090 | test 1.2799
# epoch   142 | train_loss 9.849e-02 | test_mse 1.007e-01 | D log-err  train 0.8338 | test 0.8497
# epoch   143 | train_loss 9.735e-02 | test_mse 9.902e-02 | D log-err  train 0.8082 | test 0.8388
# epoch   144 | train_loss 9.807e-02 | test_mse 1.044e-01 | D log-err  train 0.8664 | test 0.8814
# epoch   145 | train_loss 9.593e-02 | test_mse 9.855e-02 | D log-err  train 0.8059 | test 0.8313
# epoch   146 | train_loss 9.668e-02 | test_mse 9.956e-02 | D log-err  train 0.8213 | test 0.8391
# epoch   147 | train_loss 1.239e-01 | test_mse 2.587e-01 | D log-err  train 7.1723 | test 7.1725
# epoch   148 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 8.1147 | test 8.1149
# epoch   149 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 7.1595 | test 7.1634
# epoch   150 | train_loss 2.313e-01 | test_mse 1.174e-01 | D log-err  train 0.9802 | test 0.9914
# epoch   151 | train_loss 9.709e-02 | test_mse 9.882e-02 | D log-err  train 0.8114 | test 0.8328
# epoch   152 | train_loss 9.500e-02 | test_mse 9.874e-02 | D log-err  train 0.8062 | test 0.8361
# epoch   153 | train_loss 9.688e-02 | test_mse 1.002e-01 | D log-err  train 0.8290 | test 0.8451
# epoch   154 | train_loss 9.518e-02 | test_mse 1.004e-01 | D log-err  train 0.8220 | test 0.8504
# epoch   155 | train_loss 9.547e-02 | test_mse 1.013e-01 | D log-err  train 0.8483 | test 0.8346
# epoch   156 | train_loss 1.027e-01 | test_mse 1.016e-01 | D log-err  train 0.8422 | test 0.8574
# epoch   157 | train_loss 9.500e-02 | test_mse 9.879e-02 | D log-err  train 0.8048 | test 0.8351
# epoch   158 | train_loss 9.516e-02 | test_mse 9.901e-02 | D log-err  train 0.8370 | test 0.8343
# epoch   159 | train_loss 9.479e-02 | test_mse 9.752e-02 | D log-err  train 0.8239 | test 0.8311
# epoch   160 | train_loss 9.371e-02 | test_mse 9.871e-02 | D log-err  train 0.8059 | test 0.8356
# epoch   161 | train_loss 9.558e-02 | test_mse 1.000e-01 | D log-err  train 0.8187 | test 0.8463
# epoch   162 | train_loss 9.721e-02 | test_mse 1.066e-01 | D log-err  train 1.1947 | test 1.3960
# epoch   163 | train_loss 1.066e-01 | test_mse 1.078e-01 | D log-err  train 1.2025 | test 1.2431
# epoch   164 | train_loss 1.082e-01 | test_mse 1.085e-01 | D log-err  train 1.2197 | test 1.1159
# epoch   165 | train_loss 1.078e-01 | test_mse 1.114e-01 | D log-err  train 1.2411 | test 1.1544
# epoch   166 | train_loss 1.086e-01 | test_mse 1.123e-01 | D log-err  train 1.2122 | test 1.2724
# epoch   167 | train_loss 1.047e-01 | test_mse 1.088e-01 | D log-err  train 1.1602 | test 1.2230
# epoch   168 | train_loss 1.007e-01 | test_mse 1.007e-01 | D log-err  train 0.8336 | test 0.8494
# epoch   169 | train_loss 9.491e-02 | test_mse 9.869e-02 | D log-err  train 0.8090 | test 0.8320
# epoch   170 | train_loss 9.584e-02 | test_mse 9.902e-02 | D log-err  train 0.8144 | test 0.8340
# epoch   171 | train_loss 9.533e-02 | test_mse 9.873e-02 | D log-err  train 0.8098 | test 0.8322
# epoch   172 | train_loss 9.482e-02 | test_mse 9.843e-02 | D log-err  train 0.8035 | test 0.8323
# epoch   173 | train_loss 1.031e-01 | test_mse 1.046e-01 | D log-err  train 1.0777 | test 0.9588
# epoch   174 | train_loss 1.018e-01 | test_mse 1.011e-01 | D log-err  train 0.9804 | test 0.9755
# epoch   175 | train_loss 9.565e-02 | test_mse 1.035e-01 | D log-err  train 0.8547 | test 0.8776
# epoch   176 | train_loss 9.650e-02 | test_mse 9.943e-02 | D log-err  train 0.8118 | test 0.8418
# epoch   177 | train_loss 9.533e-02 | test_mse 9.839e-02 | D log-err  train 0.8078 | test 0.8302
# epoch   178 | train_loss 9.540e-02 | test_mse 1.004e-01 | D log-err  train 0.8321 | test 0.8470
# epoch   179 | train_loss 9.524e-02 | test_mse 9.859e-02 | D log-err  train 0.8055 | test 0.8347
# epoch   180 | train_loss 9.514e-02 | test_mse 9.996e-02 | D log-err  train 0.8261 | test 0.8429
# epoch   181 | train_loss 9.429e-02 | test_mse 9.852e-02 | D log-err  train 0.8106 | test 0.8314
# epoch   182 | train_loss 9.407e-02 | test_mse 9.907e-02 | D log-err  train 0.8153 | test 0.8341
# epoch   183 | train_loss 9.499e-02 | test_mse 1.117e-01 | D log-err  train 0.9343 | test 0.9363
# epoch   184 | train_loss 9.578e-02 | test_mse 9.972e-02 | D log-err  train 0.8145 | test 0.8435
# epoch   185 | train_loss 9.475e-02 | test_mse 9.921e-02 | D log-err  train 0.8101 | test 0.8407
# epoch   186 | train_loss 9.502e-02 | test_mse 9.715e-02 | D log-err  train 0.8004 | test 0.8247
# epoch   187 | train_loss 1.889e-01 | test_mse 2.587e-01 | D log-err  train 9.0946 | test 9.0948
# epoch   188 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 5.7386 | test 5.7438
# epoch   189 | train_loss 2.251e-01 | test_mse 9.853e-02 | D log-err  train 0.8055 | test 0.8312
# epoch   190 | train_loss 9.469e-02 | test_mse 9.859e-02 | D log-err  train 0.8047 | test 0.8341
# epoch   191 | train_loss 9.441e-02 | test_mse 9.891e-02 | D log-err  train 0.8075 | test 0.8379
# epoch   192 | train_loss 9.367e-02 | test_mse 8.228e-02 | D log-err  train 0.7198 | test 0.7058
# epoch   193 | train_loss 1.110e-01 | test_mse 1.140e-01 | D log-err  train 2.2350 | test 1.9897
# epoch   194 | train_loss 1.707e-01 | test_mse 2.057e-01 | D log-err  train 5.7048 | test 6.0553
# epoch   195 | train_loss 1.433e-01 | test_mse 1.115e-01 | D log-err  train 2.3481 | test 2.0418
# epoch   196 | train_loss 1.053e-01 | test_mse 9.175e-02 | D log-err  train 1.9102 | test 1.9243
# epoch   197 | train_loss 8.043e-02 | test_mse 5.250e-02 | D log-err  train 0.9801 | test 0.9438
# epoch   198 | train_loss 6.140e-02 | test_mse 5.714e-02 | D log-err  train 0.5269 | test 0.6473
# epoch   199 | train_loss 3.962e-02 | test_mse 4.287e-02 | D log-err  train 0.4439 | test 0.5716
# epoch   200 | train_loss 3.804e-02 | test_mse 3.528e-02 | D log-err  train 0.4621 | test 0.3854
# epoch   201 | train_loss 3.476e-02 | test_mse 4.053e-02 | D log-err  train 0.5145 | test 0.6591
# epoch   202 | train_loss 3.460e-02 | test_mse 3.665e-02 | D log-err  train 0.4548 | test 0.5613
# epoch   203 | train_loss 2.956e-02 | test_mse 3.409e-02 | D log-err  train 0.3196 | test 0.4961
# epoch   204 | train_loss 2.506e-02 | test_mse 3.348e-02 | D log-err  train 0.2780 | test 0.3917
# epoch   205 | train_loss 2.426e-02 | test_mse 4.361e-02 | D log-err  train 0.3153 | test 0.4631
# epoch   206 | train_loss 2.142e-02 | test_mse 3.164e-02 | D log-err  train 0.2590 | test 0.3507
# epoch   207 | train_loss 1.801e-02 | test_mse 3.344e-02 | D log-err  train 0.2561 | test 0.3512
# epoch   208 | train_loss 3.236e-02 | test_mse 3.564e-02 | D log-err  train 0.5116 | test 0.4319
# epoch   209 | train_loss 2.814e-02 | test_mse 3.153e-02 | D log-err  train 0.2769 | test 0.3433
# epoch   210 | train_loss 2.284e-02 | test_mse 3.471e-02 | D log-err  train 0.3078 | test 0.3830
# epoch   211 | train_loss 2.345e-02 | test_mse 3.630e-02 | D log-err  train 0.2760 | test 0.4199
# epoch   212 | train_loss 2.231e-02 | test_mse 2.819e-02 | D log-err  train 0.3492 | test 0.3220
# epoch   213 | train_loss 2.121e-02 | test_mse 2.824e-02 | D log-err  train 0.2441 | test 0.3200
# epoch   214 | train_loss 1.668e-02 | test_mse 3.583e-02 | D log-err  train 0.2237 | test 0.3783
# epoch   215 | train_loss 1.401e-02 | test_mse 3.129e-02 | D log-err  train 0.1972 | test 0.3631
# epoch   216 | train_loss 1.237e-02 | test_mse 2.914e-02 | D log-err  train 0.1661 | test 0.3278
# epoch   217 | train_loss 9.358e-03 | test_mse 3.446e-02 | D log-err  train 0.1512 | test 0.3613
# epoch   218 | train_loss 1.121e-02 | test_mse 2.907e-02 | D log-err  train 0.1961 | test 0.3470
# epoch   219 | train_loss 9.848e-03 | test_mse 3.966e-02 | D log-err  train 0.2259 | test 0.3688
# epoch   220 | train_loss 1.012e-02 | test_mse 3.239e-02 | D log-err  train 0.1547 | test 0.3930
# epoch   221 | train_loss 7.268e-03 | test_mse 3.688e-02 | D log-err  train 0.1221 | test 0.3704
# epoch   222 | train_loss 7.029e-03 | test_mse 3.683e-02 | D log-err  train 0.1632 | test 0.4305
# epoch   223 | train_loss 9.627e-03 | test_mse 3.475e-02 | D log-err  train 0.1518 | test 0.3211
# epoch   224 | train_loss 6.670e-03 | test_mse 3.617e-02 | D log-err  train 0.1296 | test 0.4012
# epoch   225 | train_loss 6.770e-03 | test_mse 4.024e-02 | D log-err  train 0.1548 | test 0.4119
# epoch   226 | train_loss 5.641e-03 | test_mse 4.041e-02 | D log-err  train 0.1687 | test 0.4003
# epoch   227 | train_loss 6.774e-03 | test_mse 3.837e-02 | D log-err  train 0.1232 | test 0.3624
# epoch   228 | train_loss 6.980e-03 | test_mse 3.698e-02 | D log-err  train 0.1246 | test 0.3492
# epoch   229 | train_loss 6.123e-03 | test_mse 3.640e-02 | D log-err  train 0.1309 | test 0.3551
# epoch   230 | train_loss 7.497e-03 | test_mse 3.907e-02 | D log-err  train 0.1492 | test 0.3699
# epoch   231 | train_loss 6.815e-03 | test_mse 3.664e-02 | D log-err  train 0.1513 | test 0.3477
# epoch   232 | train_loss 5.139e-03 | test_mse 3.492e-02 | D log-err  train 0.0980 | test 0.3400
# epoch   233 | train_loss 5.537e-03 | test_mse 3.717e-02 | D log-err  train 0.1702 | test 0.3684
# epoch   234 | train_loss 6.610e-03 | test_mse 3.950e-02 | D log-err  train 0.1839 | test 0.3855
# epoch   235 | train_loss 5.055e-03 | test_mse 3.670e-02 | D log-err  train 0.1332 | test 0.3555
# epoch   236 | train_loss 5.498e-03 | test_mse 3.645e-02 | D log-err  train 0.1440 | test 0.3503
# epoch   237 | train_loss 4.716e-03 | test_mse 3.708e-02 | D log-err  train 0.1262 | test 0.3610
# epoch   238 | train_loss 5.049e-03 | test_mse 3.706e-02 | D log-err  train 0.1226 | test 0.3453
# epoch   239 | train_loss 6.122e-03 | test_mse 3.918e-02 | D log-err  train 0.1402 | test 0.3657
# epoch   240 | train_loss 4.879e-03 | test_mse 3.373e-02 | D log-err  train 0.0919 | test 0.3264
# epoch   241 | train_loss 4.752e-03 | test_mse 3.605e-02 | D log-err  train 0.0832 | test 0.3336
# epoch   242 | train_loss 4.239e-03 | test_mse 3.755e-02 | D log-err  train 0.1207 | test 0.3506
# epoch   243 | train_loss 4.371e-03 | test_mse 3.566e-02 | D log-err  train 0.1115 | test 0.3256
# epoch   244 | train_loss 4.433e-03 | test_mse 3.681e-02 | D log-err  train 0.1094 | test 0.3416
# epoch   245 | train_loss 4.943e-03 | test_mse 3.466e-02 | D log-err  train 0.1062 | test 0.3197
# epoch   246 | train_loss 4.801e-03 | test_mse 3.435e-02 | D log-err  train 0.0918 | test 0.3133
# epoch   247 | train_loss 3.893e-03 | test_mse 3.258e-02 | D log-err  train 0.1089 | test 0.3119
# epoch   248 | train_loss 3.420e-03 | test_mse 3.643e-02 | D log-err  train 0.0963 | test 0.3340
# epoch   249 | train_loss 4.503e-03 | test_mse 3.489e-02 | D log-err  train 0.1407 | test 0.3546
# epoch   250 | train_loss 3.935e-03 | test_mse 3.382e-02 | D log-err  train 0.0789 | test 0.3118
# epoch   251 | train_loss 3.541e-03 | test_mse 3.537e-02 | D log-err  train 0.0760 | test 0.3303
# epoch   252 | train_loss 4.887e-03 | test_mse 3.824e-02 | D log-err  train 0.1118 | test 0.3458
# epoch   253 | train_loss 4.346e-03 | test_mse 3.589e-02 | D log-err  train 0.0831 | test 0.3256
# epoch   254 | train_loss 3.660e-03 | test_mse 3.587e-02 | D log-err  train 0.0869 | test 0.3301
# epoch   255 | train_loss 3.356e-03 | test_mse 3.746e-02 | D log-err  train 0.0825 | test 0.3326
# epoch   256 | train_loss 3.961e-03 | test_mse 3.574e-02 | D log-err  train 0.0890 | test 0.3358
# epoch   257 | train_loss 3.558e-03 | test_mse 3.610e-02 | D log-err  train 0.1038 | test 0.3375
# epoch   258 | train_loss 4.861e-03 | test_mse 3.230e-02 | D log-err  train 0.1217 | test 0.3119
# epoch   259 | train_loss 3.883e-03 | test_mse 3.568e-02 | D log-err  train 0.1249 | test 0.3297
# epoch   260 | train_loss 3.747e-03 | test_mse 3.533e-02 | D log-err  train 0.0913 | test 0.3183
# epoch   261 | train_loss 3.498e-03 | test_mse 3.742e-02 | D log-err  train 0.1152 | test 0.3383
# epoch   262 | train_loss 3.775e-03 | test_mse 3.430e-02 | D log-err  train 0.0787 | test 0.3115
# epoch   263 | train_loss 3.507e-03 | test_mse 3.370e-02 | D log-err  train 0.1032 | test 0.3124
# epoch   264 | train_loss 1.736e-02 | test_mse 6.757e-02 | D log-err  train 0.5806 | test 0.6211
# epoch   265 | train_loss 9.107e-02 | test_mse 5.115e-02 | D log-err  train 1.5385 | test 1.0694
# epoch   266 | train_loss 6.010e-02 | test_mse 6.218e-02 | D log-err  train 0.8807 | test 0.7999
# epoch   267 | train_loss 3.114e-02 | test_mse 3.484e-02 | D log-err  train 0.3505 | test 0.3860
# epoch   268 | train_loss 1.989e-02 | test_mse 3.056e-02 | D log-err  train 0.2338 | test 0.3587
# epoch   269 | train_loss 1.572e-02 | test_mse 2.459e-02 | D log-err  train 0.2257 | test 0.3031
# epoch   270 | train_loss 1.276e-02 | test_mse 2.749e-02 | D log-err  train 0.2127 | test 0.3166
# epoch   271 | train_loss 1.141e-02 | test_mse 2.672e-02 | D log-err  train 0.1595 | test 0.3077
# epoch   272 | train_loss 8.822e-03 | test_mse 2.586e-02 | D log-err  train 0.1571 | test 0.3016
# epoch   273 | train_loss 7.767e-03 | test_mse 2.959e-02 | D log-err  train 0.1438 | test 0.3181
# epoch   274 | train_loss 8.753e-03 | test_mse 2.770e-02 | D log-err  train 0.1465 | test 0.3102
# epoch   275 | train_loss 8.250e-03 | test_mse 3.600e-02 | D log-err  train 0.1611 | test 0.3380
# epoch   276 | train_loss 5.667e-03 | test_mse 3.017e-02 | D log-err  train 0.1285 | test 0.3282
# epoch   277 | train_loss 6.678e-03 | test_mse 3.022e-02 | D log-err  train 0.1455 | test 0.3263
# epoch   278 | train_loss 6.070e-03 | test_mse 2.689e-02 | D log-err  train 0.1209 | test 0.3039
# epoch   279 | train_loss 6.068e-03 | test_mse 2.798e-02 | D log-err  train 0.1264 | test 0.2979
# epoch   280 | train_loss 4.811e-03 | test_mse 2.672e-02 | D log-err  train 0.1054 | test 0.2953
# epoch   281 | train_loss 4.212e-03 | test_mse 2.716e-02 | D log-err  train 0.0911 | test 0.2871
# epoch   282 | train_loss 4.753e-03 | test_mse 3.011e-02 | D log-err  train 0.1420 | test 0.3138
# epoch   283 | train_loss 4.856e-03 | test_mse 2.657e-02 | D log-err  train 0.0908 | test 0.2999
# epoch   284 | train_loss 4.892e-03 | test_mse 2.906e-02 | D log-err  train 0.1114 | test 0.2996
# epoch   285 | train_loss 3.514e-03 | test_mse 3.094e-02 | D log-err  train 0.1008 | test 0.3182
# epoch   286 | train_loss 4.367e-03 | test_mse 3.322e-02 | D log-err  train 0.1021 | test 0.3263
# epoch   287 | train_loss 3.952e-03 | test_mse 2.772e-02 | D log-err  train 0.1018 | test 0.2830
# epoch   288 | train_loss 4.058e-03 | test_mse 2.935e-02 | D log-err  train 0.0927 | test 0.3137
# epoch   289 | train_loss 3.507e-03 | test_mse 3.374e-02 | D log-err  train 0.1567 | test 0.3413
# epoch   290 | train_loss 4.245e-03 | test_mse 3.121e-02 | D log-err  train 0.1496 | test 0.3291
# epoch   291 | train_loss 3.933e-03 | test_mse 3.116e-02 | D log-err  train 0.0813 | test 0.3172
# epoch   292 | train_loss 4.098e-03 | test_mse 3.509e-02 | D log-err  train 0.1116 | test 0.3316
# epoch   293 | train_loss 4.071e-03 | test_mse 2.969e-02 | D log-err  train 0.0897 | test 0.3036
# epoch   294 | train_loss 3.272e-03 | test_mse 3.397e-02 | D log-err  train 0.1120 | test 0.3317
# epoch   295 | train_loss 3.561e-03 | test_mse 3.330e-02 | D log-err  train 0.0812 | test 0.3313
# epoch   296 | train_loss 3.399e-03 | test_mse 3.409e-02 | D log-err  train 0.1634 | test 0.3333
# epoch   297 | train_loss 3.830e-03 | test_mse 3.056e-02 | D log-err  train 0.1310 | test 0.3106
# epoch   298 | train_loss 3.430e-03 | test_mse 3.400e-02 | D log-err  train 0.0844 | test 0.3209
# epoch   299 | train_loss 3.772e-03 | test_mse 3.261e-02 | D log-err  train 0.1125 | test 0.3224
# epoch   300 | train_loss 3.530e-03 | test_mse 3.303e-02 | D log-err  train 0.1156 | test 0.3376
# epoch   301 | train_loss 3.299e-03 | test_mse 3.221e-02 | D log-err  train 0.0722 | test 0.3195
# epoch   302 | train_loss 3.222e-03 | test_mse 3.571e-02 | D log-err  train 0.1046 | test 0.3355
# epoch   303 | train_loss 3.339e-03 | test_mse 3.610e-02 | D log-err  train 0.0771 | test 0.3451
# epoch   304 | train_loss 4.193e-03 | test_mse 3.449e-02 | D log-err  train 0.1041 | test 0.3407
# epoch   305 | train_loss 3.438e-03 | test_mse 3.530e-02 | D log-err  train 0.0849 | test 0.3341
# epoch   306 | train_loss 4.428e-03 | test_mse 3.137e-02 | D log-err  train 0.0913 | test 0.2984
# epoch   307 | train_loss 3.379e-03 | test_mse 3.400e-02 | D log-err  train 0.0793 | test 0.3158
# epoch   308 | train_loss 3.122e-03 | test_mse 3.739e-02 | D log-err  train 0.0857 | test 0.3471
# epoch   309 | train_loss 4.139e-03 | test_mse 3.246e-02 | D log-err  train 0.0800 | test 0.3044
# epoch   310 | train_loss 3.346e-03 | test_mse 3.183e-02 | D log-err  train 0.0708 | test 0.3211
# epoch   311 | train_loss 3.155e-03 | test_mse 3.499e-02 | D log-err  train 0.0794 | test 0.3351
# epoch   312 | train_loss 2.770e-03 | test_mse 3.307e-02 | D log-err  train 0.0658 | test 0.3213
# epoch   313 | train_loss 4.154e-03 | test_mse 3.224e-02 | D log-err  train 0.0837 | test 0.3014
# epoch   314 | train_loss 2.964e-03 | test_mse 3.362e-02 | D log-err  train 0.0706 | test 0.3170
# epoch   315 | train_loss 3.271e-03 | test_mse 3.396e-02 | D log-err  train 0.1098 | test 0.3302
# epoch   316 | train_loss 2.842e-03 | test_mse 3.267e-02 | D log-err  train 0.0844 | test 0.3242
# epoch   317 | train_loss 3.201e-03 | test_mse 3.295e-02 | D log-err  train 0.0781 | test 0.3143
# epoch   318 | train_loss 2.878e-03 | test_mse 3.255e-02 | D log-err  train 0.0831 | test 0.3236
# epoch   319 | train_loss 3.088e-03 | test_mse 3.492e-02 | D log-err  train 0.1106 | test 0.3472
# epoch   320 | train_loss 3.519e-03 | test_mse 3.318e-02 | D log-err  train 0.0838 | test 0.3123
# epoch   321 | train_loss 1.233e-01 | test_mse 1.867e-01 | D log-err  train 7.6653 | test 7.8017
# epoch   322 | train_loss 1.465e-01 | test_mse 1.446e-01 | D log-err  train 3.1256 | test 3.1830
# epoch   323 | train_loss 1.047e-01 | test_mse 1.072e-01 | D log-err  train 2.2527 | test 2.1619
# epoch   324 | train_loss 1.195e-01 | test_mse 1.309e-01 | D log-err  train 4.9968 | test 5.0188
# epoch   325 | train_loss 1.308e-01 | test_mse 1.213e-01 | D log-err  train 4.1755 | test 3.8770
# epoch   326 | train_loss 8.894e-02 | test_mse 7.780e-02 | D log-err  train 2.8827 | test 2.9917
# epoch   327 | train_loss 7.186e-02 | test_mse 7.408e-02 | D log-err  train 2.4237 | test 2.3306
# epoch   328 | train_loss 6.485e-02 | test_mse 7.628e-02 | D log-err  train 2.4740 | test 2.4397
# epoch   329 | train_loss 6.653e-02 | test_mse 6.953e-02 | D log-err  train 2.4208 | test 2.3120
# epoch   330 | train_loss 6.786e-02 | test_mse 7.064e-02 | D log-err  train 2.5815 | test 2.0289
# epoch   331 | train_loss 6.069e-02 | test_mse 7.125e-02 | D log-err  train 2.5062 | test 2.1726
# epoch   332 | train_loss 5.704e-02 | test_mse 6.802e-02 | D log-err  train 2.1894 | test 2.0591
# epoch   333 | train_loss 5.738e-02 | test_mse 6.813e-02 | D log-err  train 2.5455 | test 2.2524
# epoch   334 | train_loss 6.313e-02 | test_mse 6.380e-02 | D log-err  train 2.2566 | test 2.0285
# epoch   335 | train_loss 5.605e-02 | test_mse 7.107e-02 | D log-err  train 2.2510 | test 2.0624
# epoch   336 | train_loss 5.646e-02 | test_mse 7.299e-02 | D log-err  train 2.2404 | test 2.0429
# epoch   337 | train_loss 5.310e-02 | test_mse 6.292e-02 | D log-err  train 2.0725 | test 1.9827
# epoch   338 | train_loss 5.140e-02 | test_mse 5.950e-02 | D log-err  train 2.0697 | test 1.9515
# epoch   339 | train_loss 5.014e-02 | test_mse 6.387e-02 | D log-err  train 2.4700 | test 2.0451
# epoch   340 | train_loss 6.101e-02 | test_mse 1.035e-01 | D log-err  train 3.6555 | test 3.4740
# epoch   341 | train_loss 4.977e-02 | test_mse 6.128e-02 | D log-err  train 2.0672 | test 1.9792
# epoch   342 | train_loss 3.939e-02 | test_mse 4.130e-02 | D log-err  train 0.3630 | test 0.5779
# epoch   343 | train_loss 1.735e-02 | test_mse 3.632e-02 | D log-err  train 0.3410 | test 0.5560
# epoch   344 | train_loss 1.584e-02 | test_mse 3.870e-02 | D log-err  train 0.2645 | test 0.5588
# epoch   345 | train_loss 1.252e-02 | test_mse 3.205e-02 | D log-err  train 0.1560 | test 0.3269
# epoch   346 | train_loss 9.492e-03 | test_mse 3.350e-02 | D log-err  train 0.1630 | test 0.3323
# epoch   347 | train_loss 1.059e-02 | test_mse 3.339e-02 | D log-err  train 0.1938 | test 0.3530
# epoch   348 | train_loss 9.160e-03 | test_mse 2.790e-02 | D log-err  train 0.1777 | test 0.3085
# epoch   349 | train_loss 8.640e-03 | test_mse 2.895e-02 | D log-err  train 0.1355 | test 0.3072
# epoch   350 | train_loss 7.020e-03 | test_mse 3.539e-02 | D log-err  train 0.1566 | test 0.3367
# epoch   351 | train_loss 6.238e-03 | test_mse 3.072e-02 | D log-err  train 0.1332 | test 0.3192
# epoch   352 | train_loss 5.447e-03 | test_mse 2.775e-02 | D log-err  train 0.1439 | test 0.2910
# epoch   353 | train_loss 6.511e-03 | test_mse 2.833e-02 | D log-err  train 0.1661 | test 0.2959
# epoch   354 | train_loss 5.241e-03 | test_mse 2.823e-02 | D log-err  train 0.1082 | test 0.2822
# epoch   355 | train_loss 4.865e-03 | test_mse 2.855e-02 | D log-err  train 0.0959 | test 0.2842
# epoch   356 | train_loss 6.046e-03 | test_mse 2.978e-02 | D log-err  train 0.0948 | test 0.2908
# epoch   357 | train_loss 5.289e-03 | test_mse 3.207e-02 | D log-err  train 0.1045 | test 0.3149
# epoch   358 | train_loss 4.706e-03 | test_mse 2.895e-02 | D log-err  train 0.0987 | test 0.2801
# epoch   359 | train_loss 4.657e-03 | test_mse 3.030e-02 | D log-err  train 0.1018 | test 0.3054
# epoch   360 | train_loss 5.973e-03 | test_mse 2.865e-02 | D log-err  train 0.1301 | test 0.2993
# epoch   361 | train_loss 4.395e-03 | test_mse 2.663e-02 | D log-err  train 0.1275 | test 0.2839
# epoch   362 | train_loss 3.728e-03 | test_mse 3.433e-02 | D log-err  train 0.1198 | test 0.3087
# epoch   363 | train_loss 4.130e-03 | test_mse 3.248e-02 | D log-err  train 0.1077 | test 0.3141
# epoch   364 | train_loss 4.546e-03 | test_mse 2.687e-02 | D log-err  train 0.1250 | test 0.2907
# epoch   365 | train_loss 4.017e-03 | test_mse 3.264e-02 | D log-err  train 0.0922 | test 0.3175
# epoch   366 | train_loss 4.343e-03 | test_mse 2.825e-02 | D log-err  train 0.1096 | test 0.2883
# epoch   367 | train_loss 4.108e-03 | test_mse 3.053e-02 | D log-err  train 0.0900 | test 0.2978
# epoch   368 | train_loss 4.321e-03 | test_mse 2.862e-02 | D log-err  train 0.0956 | test 0.2879
# epoch   369 | train_loss 4.306e-03 | test_mse 2.977e-02 | D log-err  train 0.0996 | test 0.2916
# epoch   370 | train_loss 3.986e-03 | test_mse 3.163e-02 | D log-err  train 0.1317 | test 0.3117
# epoch   371 | train_loss 5.328e-03 | test_mse 3.049e-02 | D log-err  train 0.0990 | test 0.3017
# epoch   372 | train_loss 4.306e-03 | test_mse 3.194e-02 | D log-err  train 0.1096 | test 0.3190
# epoch   373 | train_loss 3.665e-03 | test_mse 3.066e-02 | D log-err  train 0.0856 | test 0.2926
# epoch   374 | train_loss 3.747e-03 | test_mse 2.928e-02 | D log-err  train 0.0968 | test 0.2880
# epoch   375 | train_loss 4.281e-03 | test_mse 2.810e-02 | D log-err  train 0.1287 | test 0.2938
# epoch   376 | train_loss 3.751e-03 | test_mse 3.348e-02 | D log-err  train 0.0848 | test 0.3207
# epoch   377 | train_loss 4.147e-03 | test_mse 3.370e-02 | D log-err  train 0.1893 | test 0.3353
# epoch   378 | train_loss 4.075e-03 | test_mse 3.182e-02 | D log-err  train 0.1118 | test 0.3075
# epoch   379 | train_loss 3.295e-03 | test_mse 3.117e-02 | D log-err  train 0.1243 | test 0.3119
# epoch   380 | train_loss 3.570e-03 | test_mse 3.108e-02 | D log-err  train 0.0985 | test 0.3074
# epoch   381 | train_loss 4.520e-03 | test_mse 3.193e-02 | D log-err  train 0.1532 | test 0.3276
# epoch   382 | train_loss 4.303e-03 | test_mse 3.235e-02 | D log-err  train 0.1425 | test 0.3266
# epoch   383 | train_loss 3.991e-03 | test_mse 3.049e-02 | D log-err  train 0.0935 | test 0.3116
# epoch   384 | train_loss 3.663e-03 | test_mse 3.539e-02 | D log-err  train 0.1002 | test 0.3328
# epoch   385 | train_loss 3.976e-03 | test_mse 3.322e-02 | D log-err  train 0.0696 | test 0.3105
# epoch   386 | train_loss 3.143e-03 | test_mse 3.224e-02 | D log-err  train 0.0834 | test 0.3107
# epoch   387 | train_loss 4.058e-03 | test_mse 3.158e-02 | D log-err  train 0.0852 | test 0.3061
# epoch   388 | train_loss 3.206e-03 | test_mse 3.491e-02 | D log-err  train 0.0969 | test 0.3265
# epoch   389 | train_loss 3.374e-03 | test_mse 3.180e-02 | D log-err  train 0.0807 | test 0.3106
# epoch   390 | train_loss 3.393e-03 | test_mse 3.240e-02 | D log-err  train 0.0870 | test 0.3205
# epoch   391 | train_loss 4.054e-03 | test_mse 3.447e-02 | D log-err  train 0.1382 | test 0.3351
# epoch   392 | train_loss 3.764e-03 | test_mse 3.345e-02 | D log-err  train 0.0826 | test 0.3162
# epoch   393 | train_loss 3.557e-03 | test_mse 3.333e-02 | D log-err  train 0.1046 | test 0.3152
# epoch   394 | train_loss 3.620e-03 | test_mse 3.262e-02 | D log-err  train 0.0920 | test 0.3182
# epoch   395 | train_loss 3.429e-03 | test_mse 3.382e-02 | D log-err  train 0.0764 | test 0.3224
# epoch   396 | train_loss 3.086e-03 | test_mse 3.728e-02 | D log-err  train 0.0825 | test 0.3347
# epoch   397 | train_loss 1.281e-02 | test_mse 1.065e-01 | D log-err  train 0.9686 | test 1.6956
# epoch   398 | train_loss 4.891e-02 | test_mse 5.571e-02 | D log-err  train 0.5465 | test 0.5279
# epoch   399 | train_loss 3.658e-02 | test_mse 3.796e-02 | D log-err  train 0.3235 | test 0.3823
# epoch   400 | train_loss 2.562e-02 | test_mse 4.149e-02 | D log-err  train 0.2821 | test 0.4651
# epoch   401 | train_loss 1.888e-02 | test_mse 3.394e-02 | D log-err  train 0.2347 | test 0.3425
# epoch   402 | train_loss 1.260e-02 | test_mse 3.031e-02 | D log-err  train 0.2057 | test 0.3240
# epoch   403 | train_loss 9.776e-03 | test_mse 4.124e-02 | D log-err  train 0.1797 | test 0.3860
# epoch   404 | train_loss 6.900e-03 | test_mse 3.591e-02 | D log-err  train 0.1275 | test 0.3421
# epoch   405 | train_loss 4.733e-03 | test_mse 3.398e-02 | D log-err  train 0.1022 | test 0.3243
# epoch   406 | train_loss 4.351e-03 | test_mse 3.377e-02 | D log-err  train 0.1079 | test 0.3137
# epoch   407 | train_loss 4.329e-03 | test_mse 3.421e-02 | D log-err  train 0.0960 | test 0.3256
# epoch   408 | train_loss 4.296e-03 | test_mse 3.501e-02 | D log-err  train 0.0930 | test 0.3230
# epoch   409 | train_loss 4.541e-03 | test_mse 3.462e-02 | D log-err  train 0.1062 | test 0.3256
# epoch   410 | train_loss 3.727e-03 | test_mse 3.455e-02 | D log-err  train 0.0938 | test 0.3208
# epoch   411 | train_loss 3.615e-03 | test_mse 3.566e-02 | D log-err  train 0.0757 | test 0.3162
# epoch   412 | train_loss 4.290e-03 | test_mse 3.610e-02 | D log-err  train 0.0786 | test 0.3277
# epoch   413 | train_loss 3.465e-03 | test_mse 3.674e-02 | D log-err  train 0.1011 | test 0.3364
# epoch   414 | train_loss 3.825e-03 | test_mse 3.840e-02 | D log-err  train 0.0754 | test 0.3389
# epoch   415 | train_loss 4.609e-03 | test_mse 3.798e-02 | D log-err  train 0.1150 | test 0.3422
# epoch   416 | train_loss 3.289e-03 | test_mse 3.668e-02 | D log-err  train 0.0716 | test 0.3264
# epoch   417 | train_loss 3.342e-03 | test_mse 3.549e-02 | D log-err  train 0.1079 | test 0.3302
# epoch   418 | train_loss 3.580e-03 | test_mse 4.112e-02 | D log-err  train 0.0917 | test 0.3622
# epoch   419 | train_loss 3.605e-03 | test_mse 3.551e-02 | D log-err  train 0.0842 | test 0.3155
# epoch   420 | train_loss 3.343e-03 | test_mse 3.531e-02 | D log-err  train 0.0994 | test 0.3328
# epoch   421 | train_loss 3.997e-03 | test_mse 3.876e-02 | D log-err  train 0.0766 | test 0.3423
# epoch   422 | train_loss 3.503e-03 | test_mse 3.829e-02 | D log-err  train 0.0914 | test 0.3442
# epoch   423 | train_loss 3.399e-03 | test_mse 3.983e-02 | D log-err  train 0.0741 | test 0.3392
# epoch   424 | train_loss 3.200e-03 | test_mse 4.119e-02 | D log-err  train 0.1060 | test 0.3626
# epoch   425 | train_loss 3.557e-03 | test_mse 3.988e-02 | D log-err  train 0.0896 | test 0.3462
# epoch   426 | train_loss 3.709e-03 | test_mse 4.096e-02 | D log-err  train 0.0919 | test 0.3508
# epoch   427 | train_loss 3.393e-03 | test_mse 4.254e-02 | D log-err  train 0.1232 | test 0.3719
# epoch   428 | train_loss 3.379e-03 | test_mse 4.006e-02 | D log-err  train 0.0788 | test 0.3466
# epoch   429 | train_loss 3.218e-03 | test_mse 3.749e-02 | D log-err  train 0.0923 | test 0.3375
# epoch   430 | train_loss 3.383e-03 | test_mse 3.944e-02 | D log-err  train 0.0767 | test 0.3428
# epoch   431 | train_loss 3.566e-03 | test_mse 3.978e-02 | D log-err  train 0.0936 | test 0.3523
# epoch   432 | train_loss 3.293e-03 | test_mse 4.554e-02 | D log-err  train 0.1784 | test 0.4036
# epoch   433 | train_loss 3.593e-03 | test_mse 3.678e-02 | D log-err  train 0.0897 | test 0.3327
# epoch   434 | train_loss 3.829e-03 | test_mse 3.819e-02 | D log-err  train 0.0695 | test 0.3302
# epoch   435 | train_loss 3.225e-03 | test_mse 3.998e-02 | D log-err  train 0.0652 | test 0.3484
# epoch   436 | train_loss 2.914e-03 | test_mse 3.677e-02 | D log-err  train 0.1035 | test 0.3299
# epoch   437 | train_loss 4.589e-03 | test_mse 4.025e-02 | D log-err  train 0.0849 | test 0.3399
# epoch   438 | train_loss 3.303e-03 | test_mse 3.826e-02 | D log-err  train 0.0857 | test 0.3364
# epoch   439 | train_loss 2.767e-03 | test_mse 3.849e-02 | D log-err  train 0.0750 | test 0.3392
# epoch   440 | train_loss 2.899e-03 | test_mse 3.942e-02 | D log-err  train 0.0726 | test 0.3469
# epoch   441 | train_loss 3.685e-03 | test_mse 4.147e-02 | D log-err  train 0.1047 | test 0.3553
# epoch   442 | train_loss 3.424e-03 | test_mse 3.913e-02 | D log-err  train 0.1494 | test 0.3562
# epoch   443 | train_loss 3.421e-03 | test_mse 3.784e-02 | D log-err  train 0.0838 | test 0.3337
# epoch   444 | train_loss 2.847e-03 | test_mse 4.014e-02 | D log-err  train 0.0895 | test 0.3504
# epoch   445 | train_loss 3.319e-03 | test_mse 3.570e-02 | D log-err  train 0.0756 | test 0.3214
# epoch   446 | train_loss 2.653e-03 | test_mse 4.103e-02 | D log-err  train 0.0753 | test 0.3571
# epoch   447 | train_loss 2.824e-03 | test_mse 4.056e-02 | D log-err  train 0.0753 | test 0.3424
# epoch   448 | train_loss 4.071e-03 | test_mse 3.827e-02 | D log-err  train 0.0928 | test 0.3417
# epoch   449 | train_loss 1.048e-01 | test_mse 9.088e-02 | D log-err  train 3.5470 | test 2.8390
# epoch   450 | train_loss 1.184e-01 | test_mse 1.007e-01 | D log-err  train 2.9003 | test 2.8625
# epoch   451 | train_loss 9.274e-02 | test_mse 7.291e-02 | D log-err  train 2.5420 | test 2.4110
# epoch   452 | train_loss 8.197e-02 | test_mse 1.356e-01 | D log-err  train 6.1248 | test 5.8175
# epoch   453 | train_loss 5.992e-02 | test_mse 3.408e-02 | D log-err  train 0.3683 | test 0.4104
# epoch   454 | train_loss 2.849e-02 | test_mse 2.868e-02 | D log-err  train 0.3096 | test 0.3126
# epoch   455 | train_loss 2.677e-02 | test_mse 3.348e-02 | D log-err  train 0.2643 | test 0.3517
# epoch   456 | train_loss 1.986e-02 | test_mse 3.443e-02 | D log-err  train 0.2524 | test 0.3607
# epoch   457 | train_loss 1.721e-02 | test_mse 3.306e-02 | D log-err  train 0.2130 | test 0.3613
# epoch   458 | train_loss 1.527e-02 | test_mse 4.491e-02 | D log-err  train 0.2599 | test 0.4330
# epoch   459 | train_loss 1.367e-02 | test_mse 3.138e-02 | D log-err  train 0.2983 | test 0.3649
# epoch   460 | train_loss 1.436e-02 | test_mse 3.603e-02 | D log-err  train 0.2270 | test 0.3514
# epoch   461 | train_loss 1.257e-02 | test_mse 2.796e-02 | D log-err  train 0.2334 | test 0.3190
# epoch   462 | train_loss 8.774e-03 | test_mse 3.563e-02 | D log-err  train 0.1901 | test 0.3550
# epoch   463 | train_loss 7.428e-03 | test_mse 2.818e-02 | D log-err  train 0.1210 | test 0.3051
# epoch   464 | train_loss 7.034e-03 | test_mse 3.294e-02 | D log-err  train 0.1229 | test 0.3390
# epoch   465 | train_loss 7.043e-03 | test_mse 3.326e-02 | D log-err  train 0.1772 | test 0.3512
# epoch   466 | train_loss 6.028e-03 | test_mse 3.400e-02 | D log-err  train 0.1203 | test 0.3403
# epoch   467 | train_loss 5.961e-03 | test_mse 3.237e-02 | D log-err  train 0.1035 | test 0.3266
# epoch   468 | train_loss 5.917e-03 | test_mse 3.085e-02 | D log-err  train 0.1286 | test 0.3208
# epoch   469 | train_loss 5.583e-03 | test_mse 3.100e-02 | D log-err  train 0.1057 | test 0.3164
# epoch   470 | train_loss 6.207e-03 | test_mse 2.990e-02 | D log-err  train 0.1211 | test 0.3188
# epoch   471 | train_loss 5.407e-03 | test_mse 3.175e-02 | D log-err  train 0.1079 | test 0.3150
# epoch   472 | train_loss 5.011e-03 | test_mse 3.350e-02 | D log-err  train 0.0956 | test 0.3293
# epoch   473 | train_loss 5.175e-03 | test_mse 2.921e-02 | D log-err  train 0.1601 | test 0.3097
# epoch   474 | train_loss 5.109e-03 | test_mse 2.961e-02 | D log-err  train 0.1170 | test 0.3037
# epoch   475 | train_loss 4.630e-03 | test_mse 3.012e-02 | D log-err  train 0.1055 | test 0.3240
# epoch   476 | train_loss 4.703e-03 | test_mse 3.133e-02 | D log-err  train 0.1062 | test 0.3221
# epoch   477 | train_loss 4.508e-03 | test_mse 4.142e-02 | D log-err  train 0.2438 | test 0.4088
# epoch   478 | train_loss 5.512e-03 | test_mse 3.279e-02 | D log-err  train 0.0865 | test 0.3264
# epoch   479 | train_loss 4.257e-03 | test_mse 3.094e-02 | D log-err  train 0.1072 | test 0.3162
# epoch   480 | train_loss 4.008e-03 | test_mse 3.080e-02 | D log-err  train 0.0955 | test 0.3172
# epoch   481 | train_loss 4.491e-03 | test_mse 2.865e-02 | D log-err  train 0.0900 | test 0.2898
# epoch   482 | train_loss 3.850e-03 | test_mse 3.144e-02 | D log-err  train 0.1750 | test 0.3345
# epoch   483 | train_loss 3.875e-03 | test_mse 3.035e-02 | D log-err  train 0.1057 | test 0.3131
# epoch   484 | train_loss 4.845e-03 | test_mse 3.023e-02 | D log-err  train 0.1075 | test 0.3103
# epoch   485 | train_loss 4.934e-03 | test_mse 3.130e-02 | D log-err  train 0.1020 | test 0.3173
# epoch   486 | train_loss 3.984e-03 | test_mse 3.105e-02 | D log-err  train 0.0917 | test 0.3066
# epoch   487 | train_loss 3.940e-03 | test_mse 3.020e-02 | D log-err  train 0.0870 | test 0.3020
# epoch   488 | train_loss 5.439e-03 | test_mse 3.069e-02 | D log-err  train 0.1038 | test 0.2978
# epoch   489 | train_loss 4.273e-03 | test_mse 2.913e-02 | D log-err  train 0.1017 | test 0.3110
# epoch   490 | train_loss 3.970e-03 | test_mse 3.206e-02 | D log-err  train 0.0946 | test 0.3231
# epoch   491 | train_loss 4.487e-03 | test_mse 2.940e-02 | D log-err  train 0.1109 | test 0.2944
# epoch   492 | train_loss 3.875e-03 | test_mse 3.057e-02 | D log-err  train 0.1153 | test 0.3169
# epoch   493 | train_loss 3.927e-03 | test_mse 2.735e-02 | D log-err  train 0.1212 | test 0.2914
# ...
# epoch   835 | train_loss 1.151e-01 | test_mse 1.184e-01 | D log-err  train 2.6619 | test 2.4961
# epoch   836 | train_loss 1.144e-01 | test_mse 1.143e-01 | D log-err  train 2.2490 | test 2.2947
# epoch   837 | train_loss 1.425e-01 | test_mse 1.306e-01 | D log-err  train 4.5700 | test 3.6212
# epoch   838 | train_loss 1.344e-01 | test_mse 1.326e-01 | D log-err  train 5.3930 | test 4.8275
# epoch   839 | train_loss 1.426e-01 | test_mse 1.276e-01 | D log-err  train 5.1884 | test 4.5819
# epoch   840 | train_loss 1.396e-01 | test_mse 1.284e-01 | D log-err  train 5.1380 | test 4.5298
# epoch   841 | train_loss 1.398e-01 | test_mse 1.165e-01 | D log-err  train 3.1155 | test 2.6940
# epoch   842 | train_loss 1.361e-01 | test_mse 1.219e-01 | D log-err  train 3.8815 | test 3.5788
# epoch   843 | train_loss 1.256e-01 | test_mse 1.207e-01 | D log-err  train 3.6804 | test 3.4875
# epoch   844 | train_loss 1.226e-01 | test_mse 1.141e-01 | D log-err  train 2.5353 | test 2.4821
# epoch   845 | train_loss 1.172e-01 | test_mse 1.112e-01 | D log-err  train 2.0198 | test 1.9942
# epoch   846 | train_loss 1.127e-01 | test_mse 1.110e-01 | D log-err  train 2.1490 | test 2.2276
# epoch   847 | train_loss 1.149e-01 | test_mse 1.140e-01 | D log-err  train 3.0619 | test 2.2778
# epoch   848 | train_loss 1.344e-01 | test_mse 1.140e-01 | D log-err  train 3.1082 | test 2.4938
# epoch   849 | train_loss 1.119e-01 | test_mse 1.149e-01 | D log-err  train 2.0970 | test 1.8126
# epoch   850 | train_loss 1.112e-01 | test_mse 1.234e-01 | D log-err  train 2.1104 | test 1.8281
# epoch   851 | train_loss 1.124e-01 | test_mse 1.157e-01 | D log-err  train 2.3851 | test 2.5628
# epoch   852 | train_loss 1.139e-01 | test_mse 1.155e-01 | D log-err  train 2.3201 | test 2.3498
# epoch   853 | train_loss 1.168e-01 | test_mse 1.177e-01 | D log-err  train 2.4296 | test 3.0367
# epoch   854 | train_loss 1.060e-01 | test_mse 1.111e-01 | D log-err  train 2.0895 | test 2.2457
# epoch   855 | train_loss 1.066e-01 | test_mse 1.064e-01 | D log-err  train 1.7117 | test 1.7477
# epoch   856 | train_loss 1.065e-01 | test_mse 1.105e-01 | D log-err  train 1.7426 | test 1.7712
# epoch   857 | train_loss 1.052e-01 | test_mse 1.012e-01 | D log-err  train 0.9785 | test 1.2604
# epoch   858 | train_loss 9.782e-02 | test_mse 9.861e-02 | D log-err  train 0.8651 | test 0.8316
# epoch   859 | train_loss 9.589e-02 | test_mse 9.914e-02 | D log-err  train 0.8159 | test 0.8347
# epoch   860 | train_loss 9.500e-02 | test_mse 9.859e-02 | D log-err  train 0.8071 | test 0.8315
# epoch   861 | train_loss 9.486e-02 | test_mse 9.853e-02 | D log-err  train 0.8059 | test 0.8312
# epoch   862 | train_loss 9.653e-02 | test_mse 9.939e-02 | D log-err  train 0.8113 | test 0.8415
# epoch   863 | train_loss 9.425e-02 | test_mse 1.389e-01 | D log-err  train 1.2144 | test 1.2494
# epoch   864 | train_loss 9.596e-02 | test_mse 9.868e-02 | D log-err  train 0.8057 | test 0.8353
# epoch   865 | train_loss 9.474e-02 | test_mse 9.911e-02 | D log-err  train 0.8158 | test 0.8342
# epoch   866 | train_loss 9.496e-02 | test_mse 9.844e-02 | D log-err  train 0.8043 | test 0.8308
# epoch   867 | train_loss 9.565e-02 | test_mse 9.696e-02 | D log-err  train 0.8076 | test 0.8191
# epoch   868 | train_loss 9.506e-02 | test_mse 9.844e-02 | D log-err  train 0.8080 | test 0.9081
# epoch   869 | train_loss 9.850e-02 | test_mse 1.105e-01 | D log-err  train 1.2148 | test 1.8020
# epoch   870 | train_loss 1.005e-01 | test_mse 1.016e-01 | D log-err  train 1.0301 | test 1.2730
# epoch   871 | train_loss 9.765e-02 | test_mse 9.851e-02 | D log-err  train 0.8043 | test 0.8324
# epoch   872 | train_loss 9.516e-02 | test_mse 9.923e-02 | D log-err  train 0.8098 | test 0.8405
# epoch   873 | train_loss 9.679e-02 | test_mse 9.902e-02 | D log-err  train 0.8082 | test 0.8388
# epoch   874 | train_loss 1.186e-01 | test_mse 1.077e-01 | D log-err  train 2.1107 | test 1.6624
# epoch   875 | train_loss 9.707e-02 | test_mse 9.905e-02 | D log-err  train 0.8659 | test 0.8341
# epoch   876 | train_loss 9.847e-02 | test_mse 9.853e-02 | D log-err  train 0.8042 | test 0.8331
# epoch   877 | train_loss 9.531e-02 | test_mse 9.867e-02 | D log-err  train 0.8088 | test 0.8318
# epoch   878 | train_loss 9.531e-02 | test_mse 9.890e-02 | D log-err  train 0.8075 | test 0.8379
# epoch   879 | train_loss 9.683e-02 | test_mse 1.008e-01 | D log-err  train 0.8348 | test 0.8505
# epoch   880 | train_loss 9.532e-02 | test_mse 9.854e-02 | D log-err  train 0.8058 | test 0.8313
# epoch   881 | train_loss 9.525e-02 | test_mse 1.014e-01 | D log-err  train 0.8411 | test 0.8561
# epoch   882 | train_loss 9.576e-02 | test_mse 9.839e-02 | D log-err  train 0.8058 | test 0.8306
# epoch   883 | train_loss 9.540e-02 | test_mse 9.934e-02 | D log-err  train 0.8187 | test 0.8368
# epoch   884 | train_loss 9.512e-02 | test_mse 1.022e-01 | D log-err  train 0.8474 | test 0.8621
# epoch   885 | train_loss 9.611e-02 | test_mse 9.882e-02 | D log-err  train 0.8119 | test 0.8328
# epoch   886 | train_loss 9.465e-02 | test_mse 1.005e-01 | D log-err  train 0.8234 | test 0.8509
# epoch   887 | train_loss 9.927e-02 | test_mse 1.076e-01 | D log-err  train 0.9710 | test 0.9055
# epoch   888 | train_loss 9.606e-02 | test_mse 1.001e-01 | D log-err  train 0.8277 | test 0.8440
# epoch   889 | train_loss 9.516e-02 | test_mse 9.964e-02 | D log-err  train 0.8143 | test 0.8432
# epoch   890 | train_loss 9.617e-02 | test_mse 9.963e-02 | D log-err  train 0.8134 | test 0.8429
# epoch   891 | train_loss 9.490e-02 | test_mse 1.007e-01 | D log-err  train 0.8255 | test 0.8535
# epoch   892 | train_loss 9.540e-02 | test_mse 1.097e-01 | D log-err  train 0.9166 | test 0.9209
# epoch   893 | train_loss 9.611e-02 | test_mse 1.033e-01 | D log-err  train 0.8525 | test 0.8760
# epoch   894 | train_loss 9.676e-02 | test_mse 9.885e-02 | D log-err  train 0.8071 | test 0.8373
# epoch   895 | train_loss 9.503e-02 | test_mse 1.018e-01 | D log-err  train 0.8430 | test 0.8585
# epoch   896 | train_loss 9.527e-02 | test_mse 1.065e-01 | D log-err  train 0.8857 | test 0.8981
# epoch   897 | train_loss 9.554e-02 | test_mse 1.004e-01 | D log-err  train 0.8214 | test 0.8498
# epoch   898 | train_loss 9.599e-02 | test_mse 1.022e-01 | D log-err  train 0.8403 | test 0.8671
# epoch   899 | train_loss 9.437e-02 | test_mse 1.003e-01 | D log-err  train 0.8204 | test 0.8488
# epoch   900 | train_loss 1.069e-01 | test_mse 2.300e-01 | D log-err  train 14.1939 | test 14.2661
# epoch   901 | train_loss 1.097e-01 | test_mse 1.160e-01 | D log-err  train 2.2812 | test 2.3090
# epoch   902 | train_loss 1.099e-01 | test_mse 1.035e-01 | D log-err  train 1.2514 | test 1.5041
# epoch   903 | train_loss 1.023e-01 | test_mse 1.044e-01 | D log-err  train 1.4713 | test 1.5149
# epoch   904 | train_loss 1.011e-01 | test_mse 9.913e-02 | D log-err  train 0.8090 | test 0.8398
# epoch   905 | train_loss 9.429e-02 | test_mse 9.998e-02 | D log-err  train 0.8264 | test 0.8429
# epoch   906 | train_loss 9.672e-02 | test_mse 1.020e-01 | D log-err  train 0.8379 | test 0.8653
# epoch   907 | train_loss 9.639e-02 | test_mse 9.892e-02 | D log-err  train 0.8132 | test 0.8334
# epoch   908 | train_loss 9.817e-02 | test_mse 9.890e-02 | D log-err  train 0.8076 | test 0.8380
# epoch   909 | train_loss 1.030e-01 | test_mse 1.016e-01 | D log-err  train 0.8427 | test 0.8579
# epoch   910 | train_loss 9.475e-02 | test_mse 9.912e-02 | D log-err  train 0.8094 | test 0.8399
# epoch   911 | train_loss 9.464e-02 | test_mse 9.883e-02 | D log-err  train 0.8069 | test 0.8371
# epoch   912 | train_loss 9.534e-02 | test_mse 1.020e-01 | D log-err  train 0.8463 | test 0.8611
# epoch   913 | train_loss 9.543e-02 | test_mse 9.848e-02 | D log-err  train 0.8039 | test 0.8312
# epoch   914 | train_loss 9.633e-02 | test_mse 1.005e-01 | D log-err  train 0.8314 | test 0.8476
# epoch   915 | train_loss 9.548e-02 | test_mse 9.857e-02 | D log-err  train 0.8065 | test 0.8314
# epoch   916 | train_loss 9.534e-02 | test_mse 9.853e-02 | D log-err  train 0.8052 | test 0.8314
# epoch   917 | train_loss 9.498e-02 | test_mse 1.028e-01 | D log-err  train 0.8192 | test 1.0820
# epoch   918 | train_loss 9.591e-02 | test_mse 1.041e-01 | D log-err  train 0.9279 | test 1.5108
# epoch   919 | train_loss 9.598e-02 | test_mse 9.855e-02 | D log-err  train 0.8061 | test 0.8314
# epoch   920 | train_loss 9.489e-02 | test_mse 1.036e-01 | D log-err  train 0.9206 | test 1.5094
# epoch   921 | train_loss 9.634e-02 | test_mse 1.001e-01 | D log-err  train 0.8612 | test 1.1694
# epoch   922 | train_loss 1.082e-01 | test_mse 1.050e-01 | D log-err  train 1.6544 | test 1.1121
# epoch   923 | train_loss 1.050e-01 | test_mse 1.098e-01 | D log-err  train 1.3870 | test 1.4378
# epoch   924 | train_loss 9.741e-02 | test_mse 9.855e-02 | D log-err  train 0.8060 | test 0.8314
# epoch   925 | train_loss 1.022e-01 | test_mse 1.080e-01 | D log-err  train 1.5203 | test 1.4038
# epoch   926 | train_loss 1.004e-01 | test_mse 1.014e-01 | D log-err  train 0.8402 | test 0.8556
# epoch   927 | train_loss 9.648e-02 | test_mse 1.001e-01 | D log-err  train 0.8179 | test 0.8460
# epoch   928 | train_loss 9.469e-02 | test_mse 9.971e-02 | D log-err  train 0.8284 | test 0.8428
# epoch   929 | train_loss 1.494e-01 | test_mse 2.587e-01 | D log-err  train 10.9030 | test 10.9286
# epoch   930 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.3052 | test 9.3044
# epoch   931 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.2343 | test 9.2345
# epoch   932 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.2626 | test 9.2628
# epoch   933 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.2851 | test 9.2853
# epoch   934 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.3019 | test 9.3021
# epoch   935 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.3150 | test 9.3152
# epoch   936 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.3258 | test 9.3260
# epoch   937 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.3352 | test 9.3354
# epoch   938 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.3439 | test 9.3441
# epoch   939 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.3522 | test 9.3524
# epoch   940 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.3604 | test 9.3606
# epoch   941 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.3687 | test 9.3689
# epoch   942 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.3772 | test 9.3774
# epoch   943 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.3859 | test 9.3861
# epoch   944 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.3949 | test 9.3951
# epoch   945 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.4042 | test 9.4044
# epoch   946 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.4139 | test 9.4141
# epoch   947 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.4240 | test 9.4242
# epoch   948 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.4345 | test 9.4347
# epoch   949 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.4455 | test 9.4457
# epoch   950 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.4569 | test 9.4571
# epoch   951 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.4688 | test 9.4690
# epoch   952 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.4813 | test 9.4815
# epoch   953 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.4944 | test 9.4946
# epoch   954 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.5081 | test 9.5083
# epoch   955 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.5223 | test 9.5225
# epoch   956 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.5373 | test 9.5375
# epoch   957 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.5529 | test 9.5531
# epoch   958 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.5692 | test 9.5694
# epoch   959 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.5863 | test 9.5865
# epoch   960 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.6042 | test 9.6044
# epoch   961 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.6228 | test 9.6230
# epoch   962 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.6423 | test 9.6425
# epoch   963 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.6627 | test 9.6629
# epoch   964 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.6840 | test 9.6842
# epoch   965 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.7062 | test 9.7064
# epoch   966 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.7293 | test 9.7295
# epoch   967 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.7535 | test 9.7537
# epoch   968 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.7787 | test 9.7789
# epoch   969 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.8049 | test 9.8051
# epoch   970 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.8323 | test 9.8325
# epoch   971 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.8608 | test 9.8610
# epoch   972 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.8904 | test 9.8906
# epoch   973 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.9212 | test 9.9214
# epoch   974 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.9533 | test 9.9535
# epoch   975 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 9.9866 | test 9.9868
# epoch   976 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 10.0212 | test 10.0214
# epoch   977 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 10.0571 | test 10.0573
# epoch   978 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 10.0943 | test 10.0945
# epoch   979 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 10.1328 | test 10.1330
# epoch   980 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 10.1727 | test 10.1729
# epoch   981 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 10.2140 | test 10.2142
# epoch   982 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 10.2567 | test 10.2569
# epoch   983 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 10.3008 | test 10.3010
# epoch   984 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 10.3463 | test 10.3465
# epoch   985 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 10.3933 | test 10.3935
# epoch   986 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 10.4416 | test 10.4418
# epoch   987 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 10.4913 | test 10.4915
# epoch   988 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 10.5424 | test 10.5426
# epoch   989 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 10.5949 | test 10.5951
# epoch   990 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 10.6487 | test 10.6489
# epoch   991 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 10.7038 | test 10.7039
# epoch   992 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 10.7601 | test 10.7603
# epoch   993 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 10.8177 | test 10.8179
# epoch   994 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 10.8764 | test 10.8766
# epoch   995 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 10.9362 | test 10.9364
# epoch   996 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 10.9970 | test 10.9972
# epoch   997 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 11.0587 | test 11.0589
# epoch   998 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 11.1213 | test 11.1215
# epoch   999 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 11.1847 | test 11.1849
# Min_error = 0.0246, its index is 269
# ----------------------------------------------------------------------

# %% [markdown]
# ## Train with early stopping - until best recorded performance

# %%
SEED = 0
EPOCHS = 270
torch.manual_seed(SEED)
np.random.seed(SEED)
descriptornet, physicsnet = main()
# Out:
# Device: cuda
#
# D range: [7.181e-17, 2.736e-11] cm^2/s
# R range: [5.765e-05, 1.478e-02] cm
# t range: [0.0, 20540069.3] s
# Fo range (approx): [0.0000, 1.7138]
#   WARNING: 5 rows have Fo > 1.5 (will be clamped to PhysicsNet ceiling).
#
# 10 descriptor columns.
#
# Train rows: 12800 | Train particles: 256
# Test  rows: 3250  | Test  particles: 65
#
# Network 1 bias init: log10(D) = -10.000
# Network 1 params: 332,033
# Network 2 params: 132,609 (FROZEN)
# ----------------------------------------------------------------------
# epoch     0 | train_loss 5.682e-02 | test_mse 3.295e-02 | D log-err  train 0.3254 | test 0.3702
# epoch     1 | train_loss 2.405e-02 | test_mse 3.649e-02 | D log-err  train 0.3062 | test 0.3888
# epoch     2 | train_loss 1.601e-02 | test_mse 2.534e-02 | D log-err  train 0.1933 | test 0.2942
# epoch     3 | train_loss 1.193e-02 | test_mse 2.779e-02 | D log-err  train 0.2098 | test 0.3001
# epoch     4 | train_loss 1.124e-02 | test_mse 3.121e-02 | D log-err  train 0.1540 | test 0.3331
# epoch     5 | train_loss 8.095e-03 | test_mse 2.786e-02 | D log-err  train 0.1370 | test 0.3014
# epoch     6 | train_loss 6.399e-03 | test_mse 3.165e-02 | D log-err  train 0.1757 | test 0.3564
# epoch     7 | train_loss 7.278e-03 | test_mse 2.496e-02 | D log-err  train 0.1225 | test 0.2902
# epoch     8 | train_loss 5.695e-03 | test_mse 2.809e-02 | D log-err  train 0.1043 | test 0.2945
# epoch     9 | train_loss 6.823e-03 | test_mse 3.198e-02 | D log-err  train 0.1263 | test 0.3082
# epoch    10 | train_loss 4.620e-03 | test_mse 2.796e-02 | D log-err  train 0.1013 | test 0.3083
# epoch    11 | train_loss 5.288e-03 | test_mse 2.600e-02 | D log-err  train 0.1061 | test 0.2974
# epoch    12 | train_loss 5.231e-03 | test_mse 3.028e-02 | D log-err  train 0.1478 | test 0.3543
# epoch    13 | train_loss 5.490e-03 | test_mse 3.105e-02 | D log-err  train 0.1223 | test 0.3315
# epoch    14 | train_loss 5.503e-03 | test_mse 2.907e-02 | D log-err  train 0.1201 | test 0.3209
# epoch    15 | train_loss 4.815e-03 | test_mse 2.916e-02 | D log-err  train 0.1393 | test 0.3474
# epoch    16 | train_loss 4.615e-03 | test_mse 2.889e-02 | D log-err  train 0.1100 | test 0.3170
# epoch    17 | train_loss 4.752e-03 | test_mse 3.242e-02 | D log-err  train 0.1181 | test 0.3562
# epoch    18 | train_loss 4.388e-03 | test_mse 3.268e-02 | D log-err  train 0.1112 | test 0.3516
# epoch    19 | train_loss 4.381e-03 | test_mse 3.025e-02 | D log-err  train 0.1009 | test 0.3275
# epoch    20 | train_loss 4.312e-03 | test_mse 2.675e-02 | D log-err  train 0.1072 | test 0.3073
# epoch    21 | train_loss 5.343e-03 | test_mse 3.215e-02 | D log-err  train 0.1056 | test 0.3410
# epoch    22 | train_loss 3.605e-03 | test_mse 2.994e-02 | D log-err  train 0.0988 | test 0.3300
# epoch    23 | train_loss 4.321e-03 | test_mse 2.883e-02 | D log-err  train 0.1490 | test 0.3561
# epoch    24 | train_loss 4.537e-03 | test_mse 3.026e-02 | D log-err  train 0.1005 | test 0.3163
# epoch    25 | train_loss 3.956e-03 | test_mse 2.739e-02 | D log-err  train 0.1488 | test 0.3266
# epoch    26 | train_loss 4.121e-03 | test_mse 3.187e-02 | D log-err  train 0.1124 | test 0.3375
# epoch    27 | train_loss 4.139e-03 | test_mse 2.817e-02 | D log-err  train 0.0871 | test 0.3241
# epoch    28 | train_loss 4.165e-03 | test_mse 2.859e-02 | D log-err  train 0.0896 | test 0.3100
# epoch    29 | train_loss 4.037e-03 | test_mse 3.061e-02 | D log-err  train 0.1242 | test 0.3278
# epoch    30 | train_loss 3.748e-03 | test_mse 3.037e-02 | D log-err  train 0.0850 | test 0.3214
# epoch    31 | train_loss 4.737e-03 | test_mse 2.700e-02 | D log-err  train 0.1362 | test 0.3329
# epoch    32 | train_loss 4.172e-03 | test_mse 2.996e-02 | D log-err  train 0.1166 | test 0.3202
# epoch    33 | train_loss 3.768e-03 | test_mse 2.946e-02 | D log-err  train 0.0987 | test 0.3123
# epoch    34 | train_loss 3.463e-03 | test_mse 2.909e-02 | D log-err  train 0.0744 | test 0.3017
# epoch    35 | train_loss 3.984e-03 | test_mse 3.301e-02 | D log-err  train 0.1216 | test 0.3386
# epoch    36 | train_loss 4.542e-03 | test_mse 2.691e-02 | D log-err  train 0.0895 | test 0.3116
# epoch    37 | train_loss 3.589e-03 | test_mse 2.791e-02 | D log-err  train 0.0849 | test 0.2985
# epoch    38 | train_loss 4.020e-03 | test_mse 2.998e-02 | D log-err  train 0.0823 | test 0.3148
# epoch    39 | train_loss 3.733e-03 | test_mse 2.646e-02 | D log-err  train 0.1522 | test 0.3188
# epoch    40 | train_loss 4.469e-03 | test_mse 2.866e-02 | D log-err  train 0.0747 | test 0.3098
# epoch    41 | train_loss 3.144e-03 | test_mse 2.637e-02 | D log-err  train 0.0947 | test 0.3079
# epoch    42 | train_loss 3.149e-03 | test_mse 2.871e-02 | D log-err  train 0.0905 | test 0.2979
# epoch    43 | train_loss 4.081e-03 | test_mse 3.035e-02 | D log-err  train 0.0902 | test 0.3210
# epoch    44 | train_loss 3.581e-03 | test_mse 2.835e-02 | D log-err  train 0.0743 | test 0.3064
# epoch    45 | train_loss 3.078e-03 | test_mse 3.033e-02 | D log-err  train 0.1064 | test 0.3199
# epoch    46 | train_loss 3.780e-03 | test_mse 2.981e-02 | D log-err  train 0.0930 | test 0.3213
# epoch    47 | train_loss 3.712e-03 | test_mse 2.893e-02 | D log-err  train 0.1053 | test 0.3112
# epoch    48 | train_loss 3.686e-03 | test_mse 2.927e-02 | D log-err  train 0.1002 | test 0.3054
# epoch    49 | train_loss 3.968e-03 | test_mse 2.931e-02 | D log-err  train 0.0901 | test 0.3165
# epoch    50 | train_loss 3.254e-03 | test_mse 2.946e-02 | D log-err  train 0.0776 | test 0.3014
# epoch    51 | train_loss 3.228e-03 | test_mse 2.762e-02 | D log-err  train 0.0791 | test 0.3053
# epoch    52 | train_loss 3.346e-03 | test_mse 3.105e-02 | D log-err  train 0.1011 | test 0.3174
# epoch    53 | train_loss 3.416e-03 | test_mse 2.972e-02 | D log-err  train 0.0786 | test 0.3035
# epoch    54 | train_loss 3.856e-03 | test_mse 3.037e-02 | D log-err  train 0.0929 | test 0.3151
# epoch    55 | train_loss 3.415e-03 | test_mse 3.021e-02 | D log-err  train 0.0770 | test 0.3158
# epoch    56 | train_loss 2.916e-03 | test_mse 2.839e-02 | D log-err  train 0.0671 | test 0.2946
# epoch    57 | train_loss 3.714e-03 | test_mse 3.038e-02 | D log-err  train 0.1445 | test 0.3388
# epoch    58 | train_loss 1.074e-01 | test_mse 1.539e-01 | D log-err  train 3.2681 | test 3.6233
# epoch    59 | train_loss 1.397e-01 | test_mse 1.344e-01 | D log-err  train 2.5728 | test 2.9601
# epoch    60 | train_loss 1.375e-01 | test_mse 1.593e-01 | D log-err  train 3.3886 | test 3.9429
# epoch    61 | train_loss 1.421e-01 | test_mse 1.544e-01 | D log-err  train 3.1087 | test 3.3638
# epoch    62 | train_loss 1.486e-01 | test_mse 1.532e-01 | D log-err  train 3.1583 | test 3.3614
# epoch    63 | train_loss 1.422e-01 | test_mse 1.400e-01 | D log-err  train 2.7374 | test 2.9996
# epoch    64 | train_loss 1.279e-01 | test_mse 1.620e-01 | D log-err  train 2.5612 | test 2.7547
# epoch    65 | train_loss 1.435e-01 | test_mse 1.977e-01 | D log-err  train 4.1434 | test 4.4922
# epoch    66 | train_loss 1.238e-01 | test_mse 1.083e-01 | D log-err  train 1.4379 | test 1.4029
# epoch    67 | train_loss 1.169e-01 | test_mse 1.191e-01 | D log-err  train 1.5488 | test 1.4693
# epoch    68 | train_loss 1.122e-01 | test_mse 1.183e-01 | D log-err  train 1.8443 | test 1.9027
# epoch    69 | train_loss 1.127e-01 | test_mse 1.043e-01 | D log-err  train 1.0535 | test 1.0797
# epoch    70 | train_loss 1.070e-01 | test_mse 9.932e-02 | D log-err  train 1.2409 | test 1.0459
# epoch    71 | train_loss 1.011e-01 | test_mse 1.020e-01 | D log-err  train 0.8946 | test 0.8977
# epoch    72 | train_loss 1.011e-01 | test_mse 9.855e-02 | D log-err  train 0.8087 | test 0.8312
# epoch    73 | train_loss 9.556e-02 | test_mse 9.956e-02 | D log-err  train 0.8127 | test 0.8426
# epoch    74 | train_loss 9.513e-02 | test_mse 9.867e-02 | D log-err  train 0.8081 | test 0.8322
# epoch    75 | train_loss 9.585e-02 | test_mse 9.959e-02 | D log-err  train 0.8356 | test 0.8432
# epoch    76 | train_loss 9.507e-02 | test_mse 9.906e-02 | D log-err  train 0.8151 | test 0.8338
# epoch    77 | train_loss 9.474e-02 | test_mse 1.069e-01 | D log-err  train 0.8879 | test 0.9016
# epoch    78 | train_loss 9.573e-02 | test_mse 9.898e-02 | D log-err  train 0.8080 | test 0.8385
# epoch    79 | train_loss 9.567e-02 | test_mse 9.991e-02 | D log-err  train 0.8255 | test 0.8424
# epoch    80 | train_loss 9.798e-02 | test_mse 1.006e-01 | D log-err  train 0.8325 | test 0.8484
# epoch    81 | train_loss 9.468e-02 | test_mse 1.001e-01 | D log-err  train 0.8186 | test 0.8470
# epoch    82 | train_loss 9.520e-02 | test_mse 9.852e-02 | D log-err  train 0.8041 | test 0.8328
# epoch    83 | train_loss 9.561e-02 | test_mse 9.850e-02 | D log-err  train 0.8034 | test 0.8327
# epoch    84 | train_loss 9.612e-02 | test_mse 1.010e-01 | D log-err  train 0.8363 | test 0.8521
# epoch    85 | train_loss 9.541e-02 | test_mse 1.009e-01 | D log-err  train 0.8358 | test 0.8516
# epoch    86 | train_loss 9.556e-02 | test_mse 9.866e-02 | D log-err  train 0.8086 | test 0.8318
# epoch    87 | train_loss 9.392e-02 | test_mse 9.334e-02 | D log-err  train 1.0114 | test 0.9176
# epoch    88 | train_loss 9.491e-02 | test_mse 9.854e-02 | D log-err  train 0.8043 | test 0.8334
# epoch    89 | train_loss 9.543e-02 | test_mse 1.017e-01 | D log-err  train 0.8435 | test 0.8586
# epoch    90 | train_loss 9.451e-02 | test_mse 9.861e-02 | D log-err  train 0.8049 | test 0.8343
# epoch    91 | train_loss 9.483e-02 | test_mse 9.849e-02 | D log-err  train 0.8040 | test 0.8331
# epoch    92 | train_loss 9.443e-02 | test_mse 9.355e-02 | D log-err  train 0.7668 | test 0.7804
# epoch    93 | train_loss 9.691e-02 | test_mse 1.031e-01 | D log-err  train 1.0708 | test 0.9739
# epoch    94 | train_loss 9.698e-02 | test_mse 1.027e-01 | D log-err  train 1.1003 | test 1.0654
# epoch    95 | train_loss 9.837e-02 | test_mse 1.075e-01 | D log-err  train 1.3884 | test 1.2897
# epoch    96 | train_loss 9.659e-02 | test_mse 9.992e-02 | D log-err  train 0.7995 | test 0.8707
# epoch    97 | train_loss 9.664e-02 | test_mse 1.022e-01 | D log-err  train 0.9290 | test 0.8623
# epoch    98 | train_loss 9.627e-02 | test_mse 1.016e-01 | D log-err  train 0.9246 | test 0.8577
# epoch    99 | train_loss 9.633e-02 | test_mse 9.923e-02 | D log-err  train 0.9003 | test 0.8355
# epoch   100 | train_loss 9.663e-02 | test_mse 9.921e-02 | D log-err  train 0.8601 | test 0.8353
# epoch   101 | train_loss 9.677e-02 | test_mse 9.923e-02 | D log-err  train 0.8171 | test 0.8356
# epoch   102 | train_loss 9.569e-02 | test_mse 9.912e-02 | D log-err  train 0.8089 | test 0.8396
# epoch   103 | train_loss 9.627e-02 | test_mse 1.005e-01 | D log-err  train 0.8230 | test 0.8513
# epoch   104 | train_loss 9.480e-02 | test_mse 9.860e-02 | D log-err  train 0.8074 | test 0.8316
# epoch   105 | train_loss 9.502e-02 | test_mse 9.862e-02 | D log-err  train 0.8078 | test 0.8314
# epoch   106 | train_loss 9.260e-02 | test_mse 7.525e-02 | D log-err  train 0.8939 | test 0.9847
# epoch   107 | train_loss 1.134e-01 | test_mse 1.036e-01 | D log-err  train 0.9949 | test 0.9354
# epoch   108 | train_loss 1.029e-01 | test_mse 1.036e-01 | D log-err  train 0.9947 | test 0.9356
# epoch   109 | train_loss 9.959e-02 | test_mse 1.049e-01 | D log-err  train 0.8690 | test 0.8871
# epoch   110 | train_loss 9.522e-02 | test_mse 9.798e-02 | D log-err  train 0.8031 | test 0.8269
# epoch   111 | train_loss 9.699e-02 | test_mse 1.127e-01 | D log-err  train 1.6460 | test 1.5268
# epoch   112 | train_loss 1.033e-01 | test_mse 9.945e-02 | D log-err  train 0.8201 | test 0.8380
# epoch   113 | train_loss 9.564e-02 | test_mse 9.904e-02 | D log-err  train 0.8083 | test 0.8390
# epoch   114 | train_loss 9.512e-02 | test_mse 9.894e-02 | D log-err  train 0.8344 | test 0.8335
# epoch   115 | train_loss 9.516e-02 | test_mse 9.933e-02 | D log-err  train 0.8186 | test 0.8367
# epoch   116 | train_loss 9.603e-02 | test_mse 1.153e-01 | D log-err  train 1.9637 | test 2.0309
# epoch   117 | train_loss 9.701e-02 | test_mse 9.964e-02 | D log-err  train 0.8405 | test 0.8430
# epoch   118 | train_loss 9.657e-02 | test_mse 9.920e-02 | D log-err  train 0.8404 | test 0.8353
# epoch   119 | train_loss 9.579e-02 | test_mse 9.900e-02 | D log-err  train 0.8315 | test 0.8340
# epoch   120 | train_loss 9.618e-02 | test_mse 1.127e-01 | D log-err  train 1.0337 | test 1.0483
# epoch   121 | train_loss 1.033e-01 | test_mse 9.970e-02 | D log-err  train 0.9154 | test 0.9621
# epoch   122 | train_loss 9.587e-02 | test_mse 1.017e-01 | D log-err  train 0.8506 | test 0.9768
# epoch   123 | train_loss 9.546e-02 | test_mse 1.001e-01 | D log-err  train 0.9718 | test 0.9573
# epoch   124 | train_loss 9.578e-02 | test_mse 1.000e-01 | D log-err  train 0.8283 | test 0.8455
# epoch   125 | train_loss 9.548e-02 | test_mse 9.883e-02 | D log-err  train 0.8078 | test 0.8374
# epoch   126 | train_loss 9.514e-02 | test_mse 9.814e-02 | D log-err  train 0.8055 | test 0.8301
# epoch   127 | train_loss 9.473e-02 | test_mse 9.959e-02 | D log-err  train 0.8304 | test 0.8411
# epoch   128 | train_loss 9.390e-02 | test_mse 1.084e-01 | D log-err  train 0.8853 | test 0.9109
# epoch   129 | train_loss 9.649e-02 | test_mse 9.957e-02 | D log-err  train 0.8131 | test 0.8427
# epoch   130 | train_loss 9.665e-02 | test_mse 1.071e-01 | D log-err  train 0.8920 | test 0.9022
# epoch   131 | train_loss 9.529e-02 | test_mse 9.993e-02 | D log-err  train 0.8258 | test 0.8428
# epoch   132 | train_loss 9.488e-02 | test_mse 9.845e-02 | D log-err  train 0.8045 | test 0.8306
# epoch   133 | train_loss 9.407e-02 | test_mse 9.857e-02 | D log-err  train 0.8182 | test 0.8323
# epoch   134 | train_loss 9.628e-02 | test_mse 1.023e-01 | D log-err  train 0.8424 | test 0.8687
# epoch   135 | train_loss 9.476e-02 | test_mse 1.099e-01 | D log-err  train 0.9147 | test 0.9258
# epoch   136 | train_loss 9.738e-02 | test_mse 1.002e-01 | D log-err  train 0.8198 | test 0.8481
# epoch   137 | train_loss 9.503e-02 | test_mse 1.033e-01 | D log-err  train 0.8522 | test 0.8756
# epoch   138 | train_loss 9.579e-02 | test_mse 1.067e-01 | D log-err  train 0.8859 | test 0.8997
# epoch   139 | train_loss 1.369e-01 | test_mse 1.794e-01 | D log-err  train 3.8902 | test 3.6920
# epoch   140 | train_loss 1.246e-01 | test_mse 1.113e-01 | D log-err  train 1.2793 | test 1.2626
# epoch   141 | train_loss 1.120e-01 | test_mse 1.032e-01 | D log-err  train 1.5090 | test 1.2799
# epoch   142 | train_loss 9.849e-02 | test_mse 1.007e-01 | D log-err  train 0.8338 | test 0.8497
# epoch   143 | train_loss 9.735e-02 | test_mse 9.902e-02 | D log-err  train 0.8082 | test 0.8388
# epoch   144 | train_loss 9.807e-02 | test_mse 1.044e-01 | D log-err  train 0.8664 | test 0.8814
# epoch   145 | train_loss 9.593e-02 | test_mse 9.855e-02 | D log-err  train 0.8059 | test 0.8313
# epoch   146 | train_loss 9.668e-02 | test_mse 9.956e-02 | D log-err  train 0.8213 | test 0.8391
# epoch   147 | train_loss 1.239e-01 | test_mse 2.587e-01 | D log-err  train 7.1723 | test 7.1725
# epoch   148 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 8.1147 | test 8.1149
# epoch   149 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 7.1595 | test 7.1634
# epoch   150 | train_loss 2.313e-01 | test_mse 1.174e-01 | D log-err  train 0.9802 | test 0.9914
# epoch   151 | train_loss 9.709e-02 | test_mse 9.882e-02 | D log-err  train 0.8114 | test 0.8328
# epoch   152 | train_loss 9.500e-02 | test_mse 9.874e-02 | D log-err  train 0.8062 | test 0.8361
# epoch   153 | train_loss 9.688e-02 | test_mse 1.002e-01 | D log-err  train 0.8290 | test 0.8451
# epoch   154 | train_loss 9.518e-02 | test_mse 1.004e-01 | D log-err  train 0.8220 | test 0.8504
# epoch   155 | train_loss 9.547e-02 | test_mse 1.013e-01 | D log-err  train 0.8483 | test 0.8346
# epoch   156 | train_loss 1.027e-01 | test_mse 1.016e-01 | D log-err  train 0.8422 | test 0.8574
# epoch   157 | train_loss 9.500e-02 | test_mse 9.879e-02 | D log-err  train 0.8048 | test 0.8351
# epoch   158 | train_loss 9.516e-02 | test_mse 9.901e-02 | D log-err  train 0.8370 | test 0.8343
# epoch   159 | train_loss 9.479e-02 | test_mse 9.752e-02 | D log-err  train 0.8239 | test 0.8311
# epoch   160 | train_loss 9.371e-02 | test_mse 9.871e-02 | D log-err  train 0.8059 | test 0.8356
# epoch   161 | train_loss 9.558e-02 | test_mse 1.000e-01 | D log-err  train 0.8187 | test 0.8463
# epoch   162 | train_loss 9.721e-02 | test_mse 1.066e-01 | D log-err  train 1.1947 | test 1.3960
# epoch   163 | train_loss 1.066e-01 | test_mse 1.078e-01 | D log-err  train 1.2025 | test 1.2431
# epoch   164 | train_loss 1.082e-01 | test_mse 1.085e-01 | D log-err  train 1.2197 | test 1.1159
# epoch   165 | train_loss 1.078e-01 | test_mse 1.114e-01 | D log-err  train 1.2411 | test 1.1544
# epoch   166 | train_loss 1.086e-01 | test_mse 1.123e-01 | D log-err  train 1.2122 | test 1.2724
# epoch   167 | train_loss 1.047e-01 | test_mse 1.088e-01 | D log-err  train 1.1602 | test 1.2230
# epoch   168 | train_loss 1.007e-01 | test_mse 1.007e-01 | D log-err  train 0.8336 | test 0.8494
# epoch   169 | train_loss 9.491e-02 | test_mse 9.869e-02 | D log-err  train 0.8090 | test 0.8320
# epoch   170 | train_loss 9.584e-02 | test_mse 9.902e-02 | D log-err  train 0.8144 | test 0.8340
# epoch   171 | train_loss 9.533e-02 | test_mse 9.873e-02 | D log-err  train 0.8098 | test 0.8322
# epoch   172 | train_loss 9.482e-02 | test_mse 9.843e-02 | D log-err  train 0.8035 | test 0.8323
# epoch   173 | train_loss 1.031e-01 | test_mse 1.046e-01 | D log-err  train 1.0777 | test 0.9588
# epoch   174 | train_loss 1.018e-01 | test_mse 1.011e-01 | D log-err  train 0.9804 | test 0.9755
# epoch   175 | train_loss 9.565e-02 | test_mse 1.035e-01 | D log-err  train 0.8547 | test 0.8776
# epoch   176 | train_loss 9.650e-02 | test_mse 9.943e-02 | D log-err  train 0.8118 | test 0.8418
# epoch   177 | train_loss 9.533e-02 | test_mse 9.839e-02 | D log-err  train 0.8078 | test 0.8302
# epoch   178 | train_loss 9.540e-02 | test_mse 1.004e-01 | D log-err  train 0.8321 | test 0.8470
# epoch   179 | train_loss 9.524e-02 | test_mse 9.859e-02 | D log-err  train 0.8055 | test 0.8347
# epoch   180 | train_loss 9.514e-02 | test_mse 9.996e-02 | D log-err  train 0.8261 | test 0.8429
# epoch   181 | train_loss 9.429e-02 | test_mse 9.852e-02 | D log-err  train 0.8106 | test 0.8314
# epoch   182 | train_loss 9.407e-02 | test_mse 9.907e-02 | D log-err  train 0.8153 | test 0.8341
# epoch   183 | train_loss 9.499e-02 | test_mse 1.117e-01 | D log-err  train 0.9343 | test 0.9363
# epoch   184 | train_loss 9.578e-02 | test_mse 9.972e-02 | D log-err  train 0.8145 | test 0.8435
# epoch   185 | train_loss 9.475e-02 | test_mse 9.921e-02 | D log-err  train 0.8101 | test 0.8407
# epoch   186 | train_loss 9.502e-02 | test_mse 9.715e-02 | D log-err  train 0.8004 | test 0.8247
# epoch   187 | train_loss 1.889e-01 | test_mse 2.587e-01 | D log-err  train 9.0946 | test 9.0948
# epoch   188 | train_loss 2.622e-01 | test_mse 2.587e-01 | D log-err  train 5.7386 | test 5.7438
# epoch   189 | train_loss 2.251e-01 | test_mse 9.853e-02 | D log-err  train 0.8055 | test 0.8312
# epoch   190 | train_loss 9.469e-02 | test_mse 9.859e-02 | D log-err  train 0.8047 | test 0.8341
# epoch   191 | train_loss 9.441e-02 | test_mse 9.891e-02 | D log-err  train 0.8075 | test 0.8379
# epoch   192 | train_loss 9.367e-02 | test_mse 8.228e-02 | D log-err  train 0.7198 | test 0.7058
# epoch   193 | train_loss 1.110e-01 | test_mse 1.140e-01 | D log-err  train 2.2350 | test 1.9897
# epoch   194 | train_loss 1.707e-01 | test_mse 2.057e-01 | D log-err  train 5.7048 | test 6.0553
# epoch   195 | train_loss 1.433e-01 | test_mse 1.115e-01 | D log-err  train 2.3481 | test 2.0418
# epoch   196 | train_loss 1.053e-01 | test_mse 9.175e-02 | D log-err  train 1.9102 | test 1.9243
# epoch   197 | train_loss 8.043e-02 | test_mse 5.250e-02 | D log-err  train 0.9801 | test 0.9438
# epoch   198 | train_loss 6.140e-02 | test_mse 5.714e-02 | D log-err  train 0.5269 | test 0.6473
# epoch   199 | train_loss 3.962e-02 | test_mse 4.287e-02 | D log-err  train 0.4439 | test 0.5716
# epoch   200 | train_loss 3.804e-02 | test_mse 3.528e-02 | D log-err  train 0.4621 | test 0.3854
# epoch   201 | train_loss 3.476e-02 | test_mse 4.053e-02 | D log-err  train 0.5145 | test 0.6591
# epoch   202 | train_loss 3.460e-02 | test_mse 3.665e-02 | D log-err  train 0.4548 | test 0.5613
# epoch   203 | train_loss 2.956e-02 | test_mse 3.409e-02 | D log-err  train 0.3196 | test 0.4961
# epoch   204 | train_loss 2.506e-02 | test_mse 3.348e-02 | D log-err  train 0.2780 | test 0.3917
# epoch   205 | train_loss 2.426e-02 | test_mse 4.361e-02 | D log-err  train 0.3153 | test 0.4631
# epoch   206 | train_loss 2.142e-02 | test_mse 3.164e-02 | D log-err  train 0.2590 | test 0.3507
# epoch   207 | train_loss 1.801e-02 | test_mse 3.344e-02 | D log-err  train 0.2561 | test 0.3512
# epoch   208 | train_loss 3.236e-02 | test_mse 3.564e-02 | D log-err  train 0.5116 | test 0.4319
# epoch   209 | train_loss 2.814e-02 | test_mse 3.153e-02 | D log-err  train 0.2769 | test 0.3433
# epoch   210 | train_loss 2.284e-02 | test_mse 3.471e-02 | D log-err  train 0.3078 | test 0.3830
# epoch   211 | train_loss 2.345e-02 | test_mse 3.630e-02 | D log-err  train 0.2760 | test 0.4199
# epoch   212 | train_loss 2.231e-02 | test_mse 2.819e-02 | D log-err  train 0.3492 | test 0.3220
# epoch   213 | train_loss 2.121e-02 | test_mse 2.824e-02 | D log-err  train 0.2441 | test 0.3200
# epoch   214 | train_loss 1.668e-02 | test_mse 3.583e-02 | D log-err  train 0.2237 | test 0.3783
# epoch   215 | train_loss 1.401e-02 | test_mse 3.129e-02 | D log-err  train 0.1972 | test 0.3631
# epoch   216 | train_loss 1.237e-02 | test_mse 2.914e-02 | D log-err  train 0.1661 | test 0.3278
# epoch   217 | train_loss 9.358e-03 | test_mse 3.446e-02 | D log-err  train 0.1512 | test 0.3613
# epoch   218 | train_loss 1.121e-02 | test_mse 2.907e-02 | D log-err  train 0.1961 | test 0.3470
# epoch   219 | train_loss 9.848e-03 | test_mse 3.966e-02 | D log-err  train 0.2259 | test 0.3688
# epoch   220 | train_loss 1.012e-02 | test_mse 3.239e-02 | D log-err  train 0.1547 | test 0.3930
# epoch   221 | train_loss 7.268e-03 | test_mse 3.688e-02 | D log-err  train 0.1221 | test 0.3704
# epoch   222 | train_loss 7.029e-03 | test_mse 3.683e-02 | D log-err  train 0.1632 | test 0.4305
# epoch   223 | train_loss 9.627e-03 | test_mse 3.475e-02 | D log-err  train 0.1518 | test 0.3211
# epoch   224 | train_loss 6.670e-03 | test_mse 3.617e-02 | D log-err  train 0.1296 | test 0.4012
# epoch   225 | train_loss 6.770e-03 | test_mse 4.024e-02 | D log-err  train 0.1548 | test 0.4119
# epoch   226 | train_loss 5.641e-03 | test_mse 4.041e-02 | D log-err  train 0.1687 | test 0.4003
# epoch   227 | train_loss 6.774e-03 | test_mse 3.837e-02 | D log-err  train 0.1232 | test 0.3624
# epoch   228 | train_loss 6.980e-03 | test_mse 3.698e-02 | D log-err  train 0.1246 | test 0.3492
# epoch   229 | train_loss 6.123e-03 | test_mse 3.640e-02 | D log-err  train 0.1309 | test 0.3551
# epoch   230 | train_loss 7.497e-03 | test_mse 3.907e-02 | D log-err  train 0.1492 | test 0.3699
# epoch   231 | train_loss 6.815e-03 | test_mse 3.664e-02 | D log-err  train 0.1513 | test 0.3477
# epoch   232 | train_loss 5.139e-03 | test_mse 3.492e-02 | D log-err  train 0.0980 | test 0.3400
# epoch   233 | train_loss 5.537e-03 | test_mse 3.717e-02 | D log-err  train 0.1702 | test 0.3684
# epoch   234 | train_loss 6.610e-03 | test_mse 3.950e-02 | D log-err  train 0.1839 | test 0.3855
# epoch   235 | train_loss 5.055e-03 | test_mse 3.670e-02 | D log-err  train 0.1332 | test 0.3555
# epoch   236 | train_loss 5.498e-03 | test_mse 3.645e-02 | D log-err  train 0.1440 | test 0.3503
# epoch   237 | train_loss 4.716e-03 | test_mse 3.708e-02 | D log-err  train 0.1262 | test 0.3610
# epoch   238 | train_loss 5.049e-03 | test_mse 3.706e-02 | D log-err  train 0.1226 | test 0.3453
# epoch   239 | train_loss 6.122e-03 | test_mse 3.918e-02 | D log-err  train 0.1402 | test 0.3657
# epoch   240 | train_loss 4.879e-03 | test_mse 3.373e-02 | D log-err  train 0.0919 | test 0.3264
# epoch   241 | train_loss 4.752e-03 | test_mse 3.605e-02 | D log-err  train 0.0832 | test 0.3336
# epoch   242 | train_loss 4.239e-03 | test_mse 3.755e-02 | D log-err  train 0.1207 | test 0.3506
# epoch   243 | train_loss 4.371e-03 | test_mse 3.566e-02 | D log-err  train 0.1115 | test 0.3256
# epoch   244 | train_loss 4.433e-03 | test_mse 3.681e-02 | D log-err  train 0.1094 | test 0.3416
# epoch   245 | train_loss 4.943e-03 | test_mse 3.466e-02 | D log-err  train 0.1062 | test 0.3197
# epoch   246 | train_loss 4.801e-03 | test_mse 3.435e-02 | D log-err  train 0.0918 | test 0.3133
# epoch   247 | train_loss 3.893e-03 | test_mse 3.258e-02 | D log-err  train 0.1089 | test 0.3119
# epoch   248 | train_loss 3.420e-03 | test_mse 3.643e-02 | D log-err  train 0.0963 | test 0.3340
# epoch   249 | train_loss 4.503e-03 | test_mse 3.489e-02 | D log-err  train 0.1407 | test 0.3546
# epoch   250 | train_loss 3.935e-03 | test_mse 3.382e-02 | D log-err  train 0.0789 | test 0.3118
# epoch   251 | train_loss 3.541e-03 | test_mse 3.537e-02 | D log-err  train 0.0760 | test 0.3303
# epoch   252 | train_loss 4.887e-03 | test_mse 3.824e-02 | D log-err  train 0.1118 | test 0.3458
# epoch   253 | train_loss 4.346e-03 | test_mse 3.589e-02 | D log-err  train 0.0831 | test 0.3256
# epoch   254 | train_loss 3.660e-03 | test_mse 3.587e-02 | D log-err  train 0.0869 | test 0.3301
# epoch   255 | train_loss 3.356e-03 | test_mse 3.746e-02 | D log-err  train 0.0825 | test 0.3326
# epoch   256 | train_loss 3.961e-03 | test_mse 3.574e-02 | D log-err  train 0.0890 | test 0.3358
# epoch   257 | train_loss 3.558e-03 | test_mse 3.610e-02 | D log-err  train 0.1038 | test 0.3375
# epoch   258 | train_loss 4.861e-03 | test_mse 3.230e-02 | D log-err  train 0.1217 | test 0.3119
# epoch   259 | train_loss 3.883e-03 | test_mse 3.568e-02 | D log-err  train 0.1249 | test 0.3297
# epoch   260 | train_loss 3.747e-03 | test_mse 3.533e-02 | D log-err  train 0.0913 | test 0.3183
# epoch   261 | train_loss 3.498e-03 | test_mse 3.742e-02 | D log-err  train 0.1152 | test 0.3383
# epoch   262 | train_loss 3.775e-03 | test_mse 3.430e-02 | D log-err  train 0.0787 | test 0.3115
# epoch   263 | train_loss 3.507e-03 | test_mse 3.370e-02 | D log-err  train 0.1032 | test 0.3124
# epoch   264 | train_loss 1.736e-02 | test_mse 6.757e-02 | D log-err  train 0.5806 | test 0.6211
# epoch   265 | train_loss 9.107e-02 | test_mse 5.115e-02 | D log-err  train 1.5385 | test 1.0694
# epoch   266 | train_loss 6.010e-02 | test_mse 6.218e-02 | D log-err  train 0.8807 | test 0.7999
# epoch   267 | train_loss 3.114e-02 | test_mse 3.484e-02 | D log-err  train 0.3505 | test 0.3860
# epoch   268 | train_loss 1.989e-02 | test_mse 3.056e-02 | D log-err  train 0.2338 | test 0.3587
# epoch   269 | train_loss 1.572e-02 | test_mse 2.459e-02 | D log-err  train 0.2257 | test 0.3031
# Min_error = 0.0246, its index is 269
# ----------------------------------------------------------------------

# %% [markdown]
# ## Plot Log-Log plot

# %%
# --- Load data ---
(X, t, R, c, D,
 X_part, D_part, fid) = load_data(DATA_DIR)
 
n_desc = X.shape[1]
print(f"\n{n_desc} descriptor columns.\n")
 
# Train/test split by FORMULATION (not by row)
# This ensures no particle leaks between train and test.
all_fids = np.unique(fid)
fids_train, fids_test = train_test_split(
    all_fids, test_size=0.2, random_state=SEED
)
 
# Build row-level masks from formulation split

# Simpler: reload and align
df_raw  = pd.read_excel(DATA_DIR)

df_raw['t_s']  = df_raw['Time'] * 86400.0
df_raw['R_cm'] = df_raw['Particle Size'] / 2.0 / 1e4
row_fids = df_raw['Formulation Index'].values
 
train_mask = np.isin(row_fids, fids_train)
test_mask  = np.isin(row_fids, fids_test)
 
# Descriptor scaler fit on training rows only
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X[train_mask])
X_test_scaled  = scaler.transform(X[test_mask])


# Big tensors - for evaluation performance
t_test = torch.tensor(t[test_mask], dtype=torch.float32, device=DEVICE)
R_test = torch.tensor(R[test_mask], dtype=torch.float32, device=DEVICE)
c_test = torch.tensor(c[test_mask], dtype=torch.float32, device=DEVICE)
D_test = torch.tensor(D[test_mask], dtype=torch.float32, device=DEVICE)
log_10_D_test = torch.log10(D_test)

X_test_scaled = torch.tensor(X_test_scaled, dtype=torch.float32, device=DEVICE)

rho_grid = torch.linspace(0, 1, N_RHO_INTEGRATION, device=DEVICE)


# Per-particle tensors for D log-err eval
part_train_mask = np.isin(fid, fids_train)
part_test_mask  = np.isin(fid, fids_test)
X_part_train = torch.tensor(
    scaler.transform(X_part[part_train_mask]),
    dtype=torch.float32, device=DEVICE)
X_part_test  = torch.tensor(
    scaler.transform(X_part[part_test_mask]),
    dtype=torch.float32, device=DEVICE)
D_part_train = torch.tensor(D_part[part_train_mask],
                            dtype=torch.float32, device=DEVICE)
D_part_test  = torch.tensor(D_part[part_test_mask],
                                dtype=torch.float32, device=DEVICE)
# Out:
# D range: [7.181e-17, 2.736e-11] cm^2/s
# R range: [5.765e-05, 1.478e-02] cm
# t range: [0.0, 20540069.3] s
# Fo range (approx): [0.0000, 1.7138]
#   WARNING: 5 rows have Fo > 1.5 (will be clamped to PhysicsNet ceiling).
#
# 10 descriptor columns.

# %%
X_part_train_torch = torch.tensor(X_part_train, device=DEVICE, dtype=torch.float32)
X_part_test_torch = torch.tensor(X_part_test, device=DEVICE, dtype=torch.float32)

log10_D_pred_test = descriptornet(X_part_test_torch)
log10_D_pred_train = descriptornet(X_part_train_torch)

D_pred_train       = 10.0 ** log10_D_pred_train
D_pred_test       = 10.0 ** log10_D_pred_test
# Out:
# /tmp/ipykernel_1657/1598217583.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_part_train_torch = torch.tensor(X_part_train, device=DEVICE, dtype=torch.float32)
# /tmp/ipykernel_1657/1598217583.py:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_part_test_torch = torch.tensor(X_part_test, device=DEVICE, dtype=torch.float32)

# %%
log_err_train = torch.mean(torch.abs(torch.log10(D_pred_train) - torch.log10(D_part_train)))
log_err_test = torch.mean(torch.abs(torch.log10(D_pred_test) - torch.log10(D_part_test)))

# %%
log_err_test, log_err_train
# Out:
# (tensor(0.3031, device='cuda:0', grad_fn=<MeanBackward0>),
#  tensor(0.2257, device='cuda:0', grad_fn=<MeanBackward0>))

# %%
import numpy as np
from sklearn.metrics import r2_score

def parity_plot(y_true, y_pred, lo=-15.5, hi=-10.5, save=None):
    """Parity plot for log10(D_eff). Shared across Figs 6, 8, 9, 11."""
    y_true = np.asarray(y_true).ravel()
    y_pred = np.asarray(y_pred).ravel()
    r2 = r2_score(y_true, y_pred)

    fig, ax = plt.subplots(figsize=(3.4, 3.4), constrained_layout=True)

    ax.plot([lo, hi], [lo, hi], color='gray', linestyle='--',
            zorder=1, label=r'$y = x$')                       # identity first, behind
    ax.scatter(y_true, y_pred, color='#1f77b4', alpha=0.7,
               edgecolor='black', linewidth=0.4, s=28,
               zorder=2, label='Predictions')

    ax.set_xlim(lo, hi); ax.set_ylim(lo, hi)
    ax.set_aspect('equal', adjustable='box')                  # true 45° line
    ax.set_xlabel(r"True $\log_{10}(D_{\mathrm{eff}})$")
    ax.set_ylabel(r"Predicted $\log_{10}(D_{\mathrm{eff}})$")
    ax.grid(True)

    ax.text(0.05, 0.95, fr"$R^2 = {r2:.4f}$", transform=ax.transAxes,
            va='top', ha='left', fontsize=8,
            bbox=dict(boxstyle='round,pad=0.3', fc='white', ec='0.7', lw=0.6))
    ax.legend(loc='lower right')

    if save:
        fig.savefig(save + ".pdf")
        fig.savefig(save + ".png", dpi=600)
    return fig, ax


# ---- Figure 8: Dataset B (real descriptors, ideal physics) ----
y_true = torch.log10(D_part_test).squeeze().detach().cpu().numpy()
y_pred = torch.log10(D_pred_test).squeeze().detach().cpu().numpy()

parity_plot(y_true, y_pred, save="../plots/fig8_datasetB_parity")
# Out:
# (<Figure size 340x340 with 1 Axes>,
#  <Axes: xlabel='True $\\log_{10}(D_{\\mathrm{eff}})$', ylabel='Predicted $\\log_{10}(D_{\\mathrm{eff}})$'>)

# %% [markdown]
# ## Benchmark on Dataset B

# %%
log_10_D_predicted  = descriptornet(X_test_scaled)

D_pred = 10 ** log_10_D_predicted

Fo_pred = torch.clamp(D_pred * t_test / R_test**2,
                      min=0.0, max=1.5)         # (B,)

release = integrate_release(physicsnet, Fo_pred, rho_grid)

mse = F.mse_loss(release, c_test)
male = torch.mean(torch.abs(log_10_D_predicted - log_10_D_test))

print(f"Mean Squared Error on release : {mse:.5f}")
print(f"Mean Absolute Error on Crank's Diffusivity : {male:.5f}")
# Out:
# Mean Squared Error on release : 0.02486
# Mean Absolute Error on Crank's Diffusivity : 0.30314

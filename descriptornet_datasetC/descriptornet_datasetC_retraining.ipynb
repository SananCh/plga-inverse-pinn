# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
import torch.nn.functional as F

import matplotlib.pyplot as plt

# %%
# ============================================================
# LOAD BEST CONFIG
# ============================================================

import json

# Open the file and parse its contents
with open('descriptornet_datasetC_bho/best_config.json', 'r') as file:
    best_configuration = json.load(file)
best_configuration
# Out:
# {'depth': 3,
#  'width': 256,
#  'activation': 'tanh',
#  'lr': 0.0018049050544757684,
#  'batch_size': 64,
#  'weight_decay': 0.0}

# %%
# ============================================================
# CONFIG
# ============================================================
DATA_DIR     = "../plga_dataset/release_dataset_even.xlsx"
NET2_WEIGHTS = "../physicsnet/physicsnet_pretrained.pt"
 
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
 
# --- Network 1 (trained) ---
N1_DEPTH = best_configuration["depth"]
N1_WIDTH = best_configuration["width"]
N1_ACT   = best_configuration["activation"]


# --- Network 2 (frozen, must match pretrain_net2.py exactly) ---
N2_DEPTH = 3
N2_WIDTH = 256
N2_ACT = "silu"
 
# --- Training ---
WEIGHT_DECAY      = best_configuration['weight_decay']
EPOCHS            = 1000
LR                = best_configuration["lr"]
BATCH_SIZE        = best_configuration["batch_size"]        # rows (particle x timepoint pairs)
N_RHO_INTEGRATION = 30
 
# --- Data ---
DESCRIPTOR_COLS = [
    'Drug MW', 'Drug TPSA', 'Drug LogP', 'Polymer MW', 'LA/GA',
    'Initial Drug-to-Polymer Ratio', 'Particle Size',
    'Drug Loading Capacity', 'Drug Encapsulation Efficiency',
    'Solubility Enhancer Concentration'
]
SEED = 0
torch.manual_seed(SEED)
np.random.seed(SEED)

# %%
# ============================================================
# DATA LOADING
# ============================================================
def load_data(path, release_column="Crank_Release"):
    """
    Load flat table. Each row is one (particle, timepoint) pair.
    Returns flat numpy arrays ready for TensorDataset.
    Also returns per-particle arrays for D log-err evaluation.
    """
    df = pd.read_excel(path)
 
    # Unit conversions
    df['t_s']  = df['Time'] * 86400.0          # days -> seconds
    df['R_cm'] = df['Particle Size'] / 2.0 / 1e4  # diameter um -> radius cm
 
    # Flat arrays (one row per particle x timepoint)
    X = df[DESCRIPTOR_COLS].values.astype(float)   # (N_rows, n_desc)
    t = df['t_s'].values.astype(float)              # (N_rows,)
    R = df['R_cm'].values.astype(float)             # (N_rows,)
    c = df[release_column].values.astype(float)    # (N_rows,)
    D = df['Crank_D'].values.astype(float) * 10**4         # (N_rows,) eval only
 
    # Per-particle arrays for D log-err evaluation
    df_part = (df[['Formulation Index', 'Crank_D', 'R_cm'] + DESCRIPTOR_COLS]
               .drop_duplicates(subset=['Formulation Index'])
               .reset_index(drop=True))
    X_part = df_part[DESCRIPTOR_COLS].values.astype(float)
    D_part = df_part['Crank_D'].values.astype(float) * 10**4
    fid    = df_part['Formulation Index'].values
 
    # Fo sanity check
    Fo_approx = D * t / R**2
    print(f"D range: [{D.min():.3e}, {D.max():.3e}] cm^2/s")
    print(f"R range: [{R.min():.3e}, {R.max():.3e}] cm")
    print(f"t range: [{t.min():.1f}, {t.max():.1f}] s")
    print(f"Fo range (approx): [{Fo_approx.min():.4f}, {Fo_approx.max():.4f}]")
    if Fo_approx.max() > 1.5:
        print(f"  WARNING: {(Fo_approx > 1.5).sum()} rows have Fo > 1.5 "
              f"(will be clamped to PhysicsNet ceiling).")
 
    return (X, t, R, c, D,
            X_part, D_part, fid)

# %%
# ============================================================
# NETWORKS
# ============================================================
def get_activation(name):
    return {"tanh": nn.Tanh(), "silu": nn.SiLU(), "gelu": nn.GELU()}[name.lower()]
 
 
class MLP(nn.Module):
    def __init__(self, in_dim, out_dim, depth, width, activation):
        super().__init__()
        layers = [nn.Linear(in_dim, width), get_activation(activation)]
        for _ in range(depth - 1):
            layers += [nn.Linear(width, width), get_activation(activation)]
        layers.append(nn.Linear(width, out_dim))
        self.net = nn.Sequential(*layers)
 
    def forward(self, x):
        return self.net(x)
 
 
class DescriptorNet(nn.Module):
    """Network 1 (trained): descriptors -> log10(D_eff in cm^2/s)."""
    def __init__(self, n_desc, depth=N1_DEPTH, width=N1_WIDTH,
                 activation=N1_ACT, log10_D_init=-16.0):
        super().__init__()
        self.mlp = MLP(n_desc, 1, depth, width, activation)
        nn.init.constant_(self.mlp.net[-1].bias, log10_D_init)
 
    def forward(self, desc):
        return self.mlp(desc).squeeze(-1)      # (B,)
 
 
class PhysicsNet(nn.Module):
    """Network 2 (frozen): (rho, Fo) -> u(rho, Fo)."""
    def __init__(self, depth=N2_DEPTH, width=N2_WIDTH, activation=N2_ACT):
        super().__init__()
        self.mlp = MLP(2, 1, depth, width, activation)
 
    def forward(self, rho, Fo):
        x   = torch.cat([rho**2, Fo], dim=1)
        raw = self.mlp(x)
        return (1.0 - rho**2) * raw            # hard BC: u(rho=1) = 0

# %%
# ============================================================
# INTEGRATION
# ============================================================
def integrate_release(net2, Fo, rho_grid):
    """
    Compute fractional release for a batch of Fo values.
 
    Fo       : (B,)
    rho_grid : (n_rho,)
    Returns release : (B,)
    """
    B    = Fo.shape[0]
    n_rho = rho_grid.shape[0]
 
    Fo_exp  = Fo.view(B, 1).expand(B, n_rho).reshape(-1, 1)   # (B*n_rho, 1)
    rho_exp = rho_grid.view(1, n_rho).expand(B, n_rho).reshape(-1, 1)
 
    u   = net2(rho_exp, Fo_exp).view(B, n_rho)                # (B, n_rho)
    M_t = torch.trapz(u * rho_grid**2, rho_grid, dim=1)       # (B,)
 
    return torch.clamp(1.0 - 3.0 * M_t, min=0.0, max=1.0)    # (B,)
 
 
# ============================================================
# D LOG-ERR EVALUATION (per particle, not per row)
# ============================================================
@torch.no_grad()
def eval_D_logerr(net1, X_part_tensor, D_part_tensor):
    """Mean absolute log10 D error across particles."""
    net1.eval()
    log10_D_pred = net1(X_part_tensor)
    D_pred       = 10.0 ** log10_D_pred
    log_err      = torch.mean(
        torch.abs(torch.log10(D_pred) - torch.log10(D_part_tensor))
    )
    return log_err.item()

# %%
# ============================================================
# MAIN
# ============================================================
def main():

    test_error_list = []
    print(f"Device: {DEVICE}\n")
 
    # --- Load data ---
    (X, t, R, c, D,
     X_part, D_part, fid) = load_data(DATA_DIR, release_column="Release")
 
    n_desc = X.shape[1]
    print(f"\n{n_desc} descriptor columns.\n")
 
    # Train/test split by FORMULATION (not by row)
    # This ensures no particle leaks between train and test.
    all_fids = np.unique(fid)
    fids_train, fids_test = train_test_split(
        all_fids, test_size=0.2, random_state=SEED
    )
 
    # Build row-level masks from formulation split
    df_tmp = pd.DataFrame({'Formulation Index': 
                           pd.read_excel(DATA_DIR)['Formulation Index'].values,
                           'row': np.arange(len(X))})
    # Re-derive formulation index per row from the data
    # Simpler: reload and align
    df_raw  = pd.read_excel(DATA_DIR)
    df_raw['t_s']  = df_raw['Time'] * 86400.0
    df_raw['R_cm'] = df_raw['Particle Size'] / 2.0 / 1e4
    row_fids = df_raw['Formulation Index'].values
 
    train_mask = np.isin(row_fids, fids_train)
    test_mask  = np.isin(row_fids, fids_test)
 
    # Descriptor scaler fit on training rows only
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X[train_mask])
    X_test_scaled  = scaler.transform(X[test_mask])
 
    # Per-particle tensors for D log-err eval
    part_train_mask = np.isin(fid, fids_train)
    part_test_mask  = np.isin(fid, fids_test)
    X_part_train = torch.tensor(
        scaler.transform(X_part[part_train_mask]),
        dtype=torch.float32, device=DEVICE)
    X_part_test  = torch.tensor(
        scaler.transform(X_part[part_test_mask]),
        dtype=torch.float32, device=DEVICE)
    D_part_train = torch.tensor(D_part[part_train_mask],
                                dtype=torch.float32, device=DEVICE)
    D_part_test  = torch.tensor(D_part[part_test_mask],
                                dtype=torch.float32, device=DEVICE)
 
    # DataLoaders (flat rows)
    def make_loader(X_scaled, mask, shuffle):
        ds = TensorDataset(
            torch.tensor(X_scaled,      dtype=torch.float32),
            torch.tensor(t[mask],       dtype=torch.float32),
            torch.tensor(R[mask],       dtype=torch.float32),
            torch.tensor(c[mask],       dtype=torch.float32),
        )
        return DataLoader(ds, batch_size=BATCH_SIZE, shuffle=shuffle)
 
    train_loader = make_loader(X_train_scaled, train_mask, shuffle=True)
    test_loader  = make_loader(X_test_scaled,  test_mask,  shuffle=False)
 
    print(f"Train rows: {train_mask.sum()} | "
          f"Train particles: {part_train_mask.sum()}")
    print(f"Test  rows: {test_mask.sum()}  | "
          f"Test  particles: {part_test_mask.sum()}")
 
    # --- Networks ---
    # log10_D_init = float(np.mean(np.log10(D_part[part_train_mask])))
    log10_D_init = -10
    # log10_D_init = -8
    net1 = DescriptorNet(n_desc=n_desc,
                         log10_D_init=log10_D_init).to(DEVICE)
    print(f"\nNetwork 1 bias init: log10(D) = {log10_D_init:.3f}")
    print(f"Network 1 params: {sum(p.numel() for p in net1.parameters()):,}")
 
    net2 = PhysicsNet().to(DEVICE)
    net2.load_state_dict(torch.load(NET2_WEIGHTS, map_location=DEVICE))
    for p in net2.parameters():
        p.requires_grad_(False)
    net2.eval()
    print(f"Network 2 params: {sum(p.numel() for p in net2.parameters()):,} (FROZEN)")
 
    rho_grid = torch.linspace(0, 1, N_RHO_INTEGRATION, device=DEVICE)
 
    optimizer = torch.optim.Adam(net1.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
    print("-" * 70)
 
    # --- Training loop ---
    for epoch in range(EPOCHS):
        net1.train()
        epoch_loss = 0.0
 
        for desc_b, t_b, R_b, c_b in train_loader:
            desc_b = desc_b.to(DEVICE)
            t_b    = t_b.to(DEVICE)
            R_b    = R_b.to(DEVICE)
            c_b    = c_b.to(DEVICE)
 
            optimizer.zero_grad()
 
            log10_D = net1(desc_b)                          # (B,)
            D_pred  = 10.0 ** log10_D                       # (B,)
            Fo      = torch.clamp(D_pred * t_b / R_b**2,
                                  min=0.0, max=1.5)         # (B,)
 
            release = integrate_release(net2, Fo, rho_grid)         # (B,)
 
            loss = torch.mean((release - c_b)**2)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(net1.parameters(), 1.0)
            optimizer.step()
            epoch_loss += loss.item()
 
        epoch_loss /= len(train_loader)
 
        if epoch % 1 == 0 or epoch == EPOCHS - 1:
            train_D_err = eval_D_logerr(net1, X_part_train, D_part_train)
            test_D_err  = eval_D_logerr(net1, X_part_test,  D_part_test)

            # Test MSE on release
            net1.eval()
            with torch.no_grad():
                test_mse = 0.0
                for desc_b, t_b, R_b, c_b in test_loader:
                    desc_b, t_b, R_b, c_b = [x.to(DEVICE) for x in [desc_b, t_b, R_b, c_b]]
                    D_pred  = 10.0 ** net1(desc_b)
                    Fo      = torch.clamp(D_pred * t_b / R_b**2, 0.0, 1.5)
                    release = integrate_release(net2, Fo, rho_grid)
                    test_mse += torch.mean((release - c_b)**2).item()
                test_mse /= len(test_loader)
            net1.train()

            test_error_list.append(test_mse)
            print(f"epoch {epoch:5d} | "
                  f"train_loss {epoch_loss:.3e} | "
                  f"test_mse {test_mse:.3e} | "
                  f"D log-err  train {train_D_err:.4f} | "
                  f"test {test_D_err:.4f}")

    print(f"Min_error = {min(test_error_list):.4f}, its index is {test_error_list.index(min(test_error_list))}")
    print("-" * 70)
    return net1, net2

# %% [markdown]
# ## With original time samples

# %% [markdown]
# ## Train until 1000 iterations

# %%
SEED = 0
torch.manual_seed(SEED)
np.random.seed(SEED)
descriptornet, physicsnet = main()
# Out:
# Device: cuda
#
# D range: [7.181e-17, 2.736e-11] cm^2/s
# R range: [5.765e-05, 1.478e-02] cm
# t range: [0.0, 20540069.3] s
# Fo range (approx): [0.0000, 1.7138]
#   WARNING: 5 rows have Fo > 1.5 (will be clamped to PhysicsNet ceiling).
#
# 10 descriptor columns.
#
# Train rows: 12800 | Train particles: 256
# Test  rows: 3250  | Test  particles: 65
#
# Network 1 bias init: log10(D) = -10.000
# Network 1 params: 134,657
# Network 2 params: 132,609 (FROZEN)
# ----------------------------------------------------------------------
# epoch     0 | train_loss 6.932e-02 | test_mse 5.518e-02 | D log-err  train 0.4170 | test 0.4360
# epoch     1 | train_loss 3.720e-02 | test_mse 4.820e-02 | D log-err  train 0.2270 | test 0.3380
# epoch     2 | train_loss 2.812e-02 | test_mse 4.657e-02 | D log-err  train 0.2038 | test 0.3232
# epoch     3 | train_loss 2.355e-02 | test_mse 4.911e-02 | D log-err  train 0.1660 | test 0.3341
# epoch     4 | train_loss 2.159e-02 | test_mse 5.234e-02 | D log-err  train 0.1268 | test 0.3399
# epoch     5 | train_loss 2.132e-02 | test_mse 4.943e-02 | D log-err  train 0.1052 | test 0.3019
# epoch     6 | train_loss 2.068e-02 | test_mse 4.893e-02 | D log-err  train 0.1132 | test 0.3107
# epoch     7 | train_loss 2.005e-02 | test_mse 5.277e-02 | D log-err  train 0.1231 | test 0.3227
# epoch     8 | train_loss 2.000e-02 | test_mse 4.700e-02 | D log-err  train 0.1265 | test 0.3106
# epoch     9 | train_loss 1.969e-02 | test_mse 4.698e-02 | D log-err  train 0.1116 | test 0.3046
# epoch    10 | train_loss 1.985e-02 | test_mse 5.196e-02 | D log-err  train 0.0867 | test 0.3152
# epoch    11 | train_loss 1.923e-02 | test_mse 5.017e-02 | D log-err  train 0.0991 | test 0.2979
# epoch    12 | train_loss 1.928e-02 | test_mse 4.947e-02 | D log-err  train 0.1359 | test 0.3308
# epoch    13 | train_loss 1.941e-02 | test_mse 5.169e-02 | D log-err  train 0.0828 | test 0.3279
# epoch    14 | train_loss 1.943e-02 | test_mse 4.922e-02 | D log-err  train 0.0853 | test 0.3093
# epoch    15 | train_loss 1.908e-02 | test_mse 5.077e-02 | D log-err  train 0.0826 | test 0.3257
# epoch    16 | train_loss 1.873e-02 | test_mse 4.796e-02 | D log-err  train 0.0961 | test 0.3206
# epoch    17 | train_loss 1.915e-02 | test_mse 4.922e-02 | D log-err  train 0.1010 | test 0.3155
# epoch    18 | train_loss 1.930e-02 | test_mse 4.655e-02 | D log-err  train 0.1136 | test 0.3101
# epoch    19 | train_loss 1.934e-02 | test_mse 5.019e-02 | D log-err  train 0.0880 | test 0.3319
# epoch    20 | train_loss 1.896e-02 | test_mse 4.799e-02 | D log-err  train 0.0953 | test 0.3166
# epoch    21 | train_loss 1.910e-02 | test_mse 4.747e-02 | D log-err  train 0.1154 | test 0.3207
# epoch    22 | train_loss 1.892e-02 | test_mse 4.905e-02 | D log-err  train 0.0796 | test 0.3214
# epoch    23 | train_loss 1.902e-02 | test_mse 4.702e-02 | D log-err  train 0.1081 | test 0.3252
# epoch    24 | train_loss 1.873e-02 | test_mse 4.972e-02 | D log-err  train 0.0824 | test 0.3116
# epoch    25 | train_loss 1.896e-02 | test_mse 5.081e-02 | D log-err  train 0.0836 | test 0.3311
# epoch    26 | train_loss 1.902e-02 | test_mse 4.935e-02 | D log-err  train 0.0760 | test 0.3240
# epoch    27 | train_loss 1.927e-02 | test_mse 4.909e-02 | D log-err  train 0.1398 | test 0.3390
# epoch    28 | train_loss 1.897e-02 | test_mse 5.127e-02 | D log-err  train 0.0899 | test 0.3299
# epoch    29 | train_loss 1.879e-02 | test_mse 5.040e-02 | D log-err  train 0.0976 | test 0.3303
# epoch    30 | train_loss 1.895e-02 | test_mse 4.891e-02 | D log-err  train 0.0819 | test 0.3098
# epoch    31 | train_loss 1.907e-02 | test_mse 5.206e-02 | D log-err  train 0.0982 | test 0.3370
# epoch    32 | train_loss 1.886e-02 | test_mse 5.480e-02 | D log-err  train 0.1027 | test 0.3490
# epoch    33 | train_loss 1.893e-02 | test_mse 4.713e-02 | D log-err  train 0.1075 | test 0.3180
# epoch    34 | train_loss 1.881e-02 | test_mse 4.795e-02 | D log-err  train 0.0769 | test 0.3266
# epoch    35 | train_loss 1.895e-02 | test_mse 5.351e-02 | D log-err  train 0.1045 | test 0.3518
# epoch    36 | train_loss 1.885e-02 | test_mse 4.815e-02 | D log-err  train 0.0791 | test 0.3127
# epoch    37 | train_loss 1.846e-02 | test_mse 5.061e-02 | D log-err  train 0.0715 | test 0.3278
# epoch    38 | train_loss 1.874e-02 | test_mse 4.927e-02 | D log-err  train 0.0871 | test 0.3379
# epoch    39 | train_loss 1.921e-02 | test_mse 5.365e-02 | D log-err  train 0.1229 | test 0.3427
# epoch    40 | train_loss 1.891e-02 | test_mse 5.259e-02 | D log-err  train 0.1203 | test 0.3445
# epoch    41 | train_loss 1.885e-02 | test_mse 4.788e-02 | D log-err  train 0.0857 | test 0.3156
# epoch    42 | train_loss 1.895e-02 | test_mse 5.305e-02 | D log-err  train 0.1162 | test 0.3367
# epoch    43 | train_loss 1.896e-02 | test_mse 4.778e-02 | D log-err  train 0.0889 | test 0.3282
# epoch    44 | train_loss 1.911e-02 | test_mse 4.713e-02 | D log-err  train 0.0749 | test 0.3067
# epoch    45 | train_loss 1.906e-02 | test_mse 5.061e-02 | D log-err  train 0.0994 | test 0.3298
# epoch    46 | train_loss 1.913e-02 | test_mse 5.444e-02 | D log-err  train 0.0913 | test 0.3622
# epoch    47 | train_loss 1.882e-02 | test_mse 4.823e-02 | D log-err  train 0.0705 | test 0.3222
# epoch    48 | train_loss 1.868e-02 | test_mse 5.024e-02 | D log-err  train 0.0764 | test 0.3289
# epoch    49 | train_loss 1.878e-02 | test_mse 5.102e-02 | D log-err  train 0.0874 | test 0.3191
# epoch    50 | train_loss 1.892e-02 | test_mse 4.684e-02 | D log-err  train 0.1281 | test 0.2934
# epoch    51 | train_loss 1.894e-02 | test_mse 4.833e-02 | D log-err  train 0.0854 | test 0.3156
# epoch    52 | train_loss 1.927e-02 | test_mse 5.143e-02 | D log-err  train 0.0894 | test 0.3335
# epoch    53 | train_loss 1.900e-02 | test_mse 4.974e-02 | D log-err  train 0.0725 | test 0.3119
# epoch    54 | train_loss 1.877e-02 | test_mse 4.958e-02 | D log-err  train 0.0752 | test 0.3111
# epoch    55 | train_loss 1.875e-02 | test_mse 5.064e-02 | D log-err  train 0.0973 | test 0.3351
# epoch    56 | train_loss 1.853e-02 | test_mse 4.743e-02 | D log-err  train 0.1430 | test 0.3156
# epoch    57 | train_loss 1.859e-02 | test_mse 4.837e-02 | D log-err  train 0.0690 | test 0.3177
# epoch    58 | train_loss 1.885e-02 | test_mse 4.935e-02 | D log-err  train 0.0902 | test 0.3186
# epoch    59 | train_loss 1.855e-02 | test_mse 4.896e-02 | D log-err  train 0.0758 | test 0.3030
# epoch    60 | train_loss 1.864e-02 | test_mse 4.985e-02 | D log-err  train 0.0820 | test 0.3115
# epoch    61 | train_loss 1.846e-02 | test_mse 4.764e-02 | D log-err  train 0.0827 | test 0.3078
# epoch    62 | train_loss 1.889e-02 | test_mse 4.862e-02 | D log-err  train 0.0731 | test 0.3135
# epoch    63 | train_loss 1.872e-02 | test_mse 4.859e-02 | D log-err  train 0.0766 | test 0.3109
# epoch    64 | train_loss 1.884e-02 | test_mse 5.073e-02 | D log-err  train 0.0837 | test 0.3288
# epoch    65 | train_loss 1.880e-02 | test_mse 4.889e-02 | D log-err  train 0.1161 | test 0.3220
# epoch    66 | train_loss 1.949e-02 | test_mse 4.894e-02 | D log-err  train 0.1077 | test 0.3259
# epoch    67 | train_loss 1.894e-02 | test_mse 4.813e-02 | D log-err  train 0.0903 | test 0.3223
# epoch    68 | train_loss 1.863e-02 | test_mse 5.283e-02 | D log-err  train 0.1073 | test 0.3465
# epoch    69 | train_loss 1.880e-02 | test_mse 4.850e-02 | D log-err  train 0.0688 | test 0.3086
# epoch    70 | train_loss 1.850e-02 | test_mse 4.682e-02 | D log-err  train 0.0781 | test 0.3131
# epoch    71 | train_loss 1.867e-02 | test_mse 5.221e-02 | D log-err  train 0.1024 | test 0.3373
# epoch    72 | train_loss 1.893e-02 | test_mse 4.764e-02 | D log-err  train 0.1497 | test 0.3267
# epoch    73 | train_loss 1.938e-02 | test_mse 4.752e-02 | D log-err  train 0.0689 | test 0.3105
# epoch    74 | train_loss 1.874e-02 | test_mse 4.710e-02 | D log-err  train 0.0864 | test 0.3060
# epoch    75 | train_loss 1.898e-02 | test_mse 4.845e-02 | D log-err  train 0.0645 | test 0.3145
# epoch    76 | train_loss 1.880e-02 | test_mse 4.565e-02 | D log-err  train 0.1087 | test 0.2932
# epoch    77 | train_loss 1.837e-02 | test_mse 4.949e-02 | D log-err  train 0.0813 | test 0.3134
# epoch    78 | train_loss 1.865e-02 | test_mse 4.936e-02 | D log-err  train 0.0802 | test 0.3133
# epoch    79 | train_loss 1.859e-02 | test_mse 5.231e-02 | D log-err  train 0.0930 | test 0.3355
# epoch    80 | train_loss 1.859e-02 | test_mse 4.947e-02 | D log-err  train 0.0837 | test 0.3186
# epoch    81 | train_loss 1.854e-02 | test_mse 5.337e-02 | D log-err  train 0.0775 | test 0.3440
# epoch    82 | train_loss 1.871e-02 | test_mse 5.015e-02 | D log-err  train 0.0768 | test 0.3215
# epoch    83 | train_loss 1.935e-02 | test_mse 4.963e-02 | D log-err  train 0.1161 | test 0.3239
# epoch    84 | train_loss 1.914e-02 | test_mse 5.050e-02 | D log-err  train 0.1040 | test 0.3276
# epoch    85 | train_loss 1.913e-02 | test_mse 4.939e-02 | D log-err  train 0.1434 | test 0.3435
# epoch    86 | train_loss 1.893e-02 | test_mse 5.088e-02 | D log-err  train 0.1000 | test 0.3384
# epoch    87 | train_loss 1.893e-02 | test_mse 5.454e-02 | D log-err  train 0.1112 | test 0.3359
# epoch    88 | train_loss 1.874e-02 | test_mse 5.056e-02 | D log-err  train 0.0907 | test 0.3207
# epoch    89 | train_loss 1.885e-02 | test_mse 5.034e-02 | D log-err  train 0.0721 | test 0.3120
# epoch    90 | train_loss 1.887e-02 | test_mse 4.958e-02 | D log-err  train 0.1624 | test 0.3535
# epoch    91 | train_loss 1.848e-02 | test_mse 5.284e-02 | D log-err  train 0.0979 | test 0.3540
# epoch    92 | train_loss 1.870e-02 | test_mse 4.981e-02 | D log-err  train 0.0725 | test 0.3261
# epoch    93 | train_loss 1.873e-02 | test_mse 5.058e-02 | D log-err  train 0.0667 | test 0.3325
# epoch    94 | train_loss 1.880e-02 | test_mse 4.930e-02 | D log-err  train 0.0778 | test 0.3238
# epoch    95 | train_loss 1.877e-02 | test_mse 4.897e-02 | D log-err  train 0.1183 | test 0.3195
# epoch    96 | train_loss 1.891e-02 | test_mse 4.986e-02 | D log-err  train 0.0774 | test 0.3318
# epoch    97 | train_loss 1.886e-02 | test_mse 4.871e-02 | D log-err  train 0.1618 | test 0.3390
# epoch    98 | train_loss 1.893e-02 | test_mse 5.485e-02 | D log-err  train 0.0844 | test 0.3446
# epoch    99 | train_loss 1.884e-02 | test_mse 5.016e-02 | D log-err  train 0.0815 | test 0.3313
# epoch   100 | train_loss 1.878e-02 | test_mse 5.388e-02 | D log-err  train 0.1191 | test 0.3543
# epoch   101 | train_loss 1.841e-02 | test_mse 5.261e-02 | D log-err  train 0.0839 | test 0.3418
# epoch   102 | train_loss 1.879e-02 | test_mse 5.140e-02 | D log-err  train 0.0893 | test 0.3363
# epoch   103 | train_loss 1.897e-02 | test_mse 5.244e-02 | D log-err  train 0.0937 | test 0.3415
# epoch   104 | train_loss 1.876e-02 | test_mse 5.717e-02 | D log-err  train 0.1037 | test 0.3723
# epoch   105 | train_loss 1.877e-02 | test_mse 5.295e-02 | D log-err  train 0.1112 | test 0.3423
# epoch   106 | train_loss 1.861e-02 | test_mse 4.711e-02 | D log-err  train 0.0640 | test 0.3061
# epoch   107 | train_loss 1.879e-02 | test_mse 5.394e-02 | D log-err  train 0.0891 | test 0.3607
# epoch   108 | train_loss 1.898e-02 | test_mse 5.381e-02 | D log-err  train 0.0952 | test 0.3632
# epoch   109 | train_loss 1.935e-02 | test_mse 4.829e-02 | D log-err  train 0.0910 | test 0.3189
# epoch   110 | train_loss 1.882e-02 | test_mse 5.341e-02 | D log-err  train 0.0679 | test 0.3478
# epoch   111 | train_loss 1.887e-02 | test_mse 5.333e-02 | D log-err  train 0.0925 | test 0.3438
# epoch   112 | train_loss 1.907e-02 | test_mse 5.474e-02 | D log-err  train 0.0885 | test 0.3546
# epoch   113 | train_loss 1.850e-02 | test_mse 5.240e-02 | D log-err  train 0.0768 | test 0.3383
# epoch   114 | train_loss 1.839e-02 | test_mse 5.340e-02 | D log-err  train 0.0894 | test 0.3441
# epoch   115 | train_loss 1.846e-02 | test_mse 4.849e-02 | D log-err  train 0.0839 | test 0.3259
# epoch   116 | train_loss 1.880e-02 | test_mse 5.105e-02 | D log-err  train 0.0935 | test 0.3351
# epoch   117 | train_loss 1.901e-02 | test_mse 5.108e-02 | D log-err  train 0.0882 | test 0.3337
# epoch   118 | train_loss 1.915e-02 | test_mse 5.618e-02 | D log-err  train 0.1329 | test 0.3911
# epoch   119 | train_loss 1.897e-02 | test_mse 5.109e-02 | D log-err  train 0.0773 | test 0.3196
# epoch   120 | train_loss 1.893e-02 | test_mse 5.282e-02 | D log-err  train 0.1015 | test 0.3442
# epoch   121 | train_loss 1.920e-02 | test_mse 5.280e-02 | D log-err  train 0.0708 | test 0.3506
# epoch   122 | train_loss 1.900e-02 | test_mse 5.091e-02 | D log-err  train 0.1185 | test 0.3363
# epoch   123 | train_loss 1.872e-02 | test_mse 5.155e-02 | D log-err  train 0.1069 | test 0.3483
# epoch   124 | train_loss 1.851e-02 | test_mse 5.387e-02 | D log-err  train 0.1108 | test 0.3654
# epoch   125 | train_loss 1.896e-02 | test_mse 5.306e-02 | D log-err  train 0.0965 | test 0.3457
# epoch   126 | train_loss 1.912e-02 | test_mse 5.372e-02 | D log-err  train 0.0740 | test 0.3467
# epoch   127 | train_loss 1.894e-02 | test_mse 5.524e-02 | D log-err  train 0.1097 | test 0.3529
# epoch   128 | train_loss 1.901e-02 | test_mse 5.097e-02 | D log-err  train 0.0987 | test 0.3283
# epoch   129 | train_loss 1.849e-02 | test_mse 5.373e-02 | D log-err  train 0.1043 | test 0.3567
# epoch   130 | train_loss 1.905e-02 | test_mse 5.445e-02 | D log-err  train 0.0858 | test 0.3486
# epoch   131 | train_loss 1.914e-02 | test_mse 5.657e-02 | D log-err  train 0.0768 | test 0.3658
# epoch   132 | train_loss 1.889e-02 | test_mse 5.124e-02 | D log-err  train 0.0985 | test 0.3322
# epoch   133 | train_loss 1.890e-02 | test_mse 5.463e-02 | D log-err  train 0.1005 | test 0.3605
# epoch   134 | train_loss 1.857e-02 | test_mse 5.676e-02 | D log-err  train 0.0896 | test 0.3701
# epoch   135 | train_loss 1.920e-02 | test_mse 5.332e-02 | D log-err  train 0.0889 | test 0.3547
# epoch   136 | train_loss 1.885e-02 | test_mse 5.332e-02 | D log-err  train 0.0676 | test 0.3462
# epoch   137 | train_loss 1.895e-02 | test_mse 5.375e-02 | D log-err  train 0.0893 | test 0.3466
# epoch   138 | train_loss 1.896e-02 | test_mse 5.083e-02 | D log-err  train 0.1034 | test 0.3447
# epoch   139 | train_loss 1.897e-02 | test_mse 5.303e-02 | D log-err  train 0.1412 | test 0.3713
# epoch   140 | train_loss 1.859e-02 | test_mse 4.978e-02 | D log-err  train 0.1260 | test 0.3437
# epoch   141 | train_loss 1.911e-02 | test_mse 5.110e-02 | D log-err  train 0.1672 | test 0.3765
# epoch   142 | train_loss 1.894e-02 | test_mse 5.196e-02 | D log-err  train 0.1253 | test 0.3471
# epoch   143 | train_loss 1.897e-02 | test_mse 5.170e-02 | D log-err  train 0.0649 | test 0.3514
# epoch   144 | train_loss 1.887e-02 | test_mse 5.071e-02 | D log-err  train 0.0924 | test 0.3521
# epoch   145 | train_loss 1.874e-02 | test_mse 5.285e-02 | D log-err  train 0.0860 | test 0.3704
# epoch   146 | train_loss 1.854e-02 | test_mse 5.263e-02 | D log-err  train 0.0873 | test 0.3542
# epoch   147 | train_loss 1.870e-02 | test_mse 5.331e-02 | D log-err  train 0.0921 | test 0.3667
# epoch   148 | train_loss 1.902e-02 | test_mse 5.321e-02 | D log-err  train 0.0843 | test 0.3800
# epoch   149 | train_loss 1.898e-02 | test_mse 4.711e-02 | D log-err  train 0.0808 | test 0.3233
# epoch   150 | train_loss 1.853e-02 | test_mse 4.815e-02 | D log-err  train 0.1001 | test 0.3307
# epoch   151 | train_loss 1.883e-02 | test_mse 4.738e-02 | D log-err  train 0.0762 | test 0.3273
# epoch   152 | train_loss 1.876e-02 | test_mse 4.976e-02 | D log-err  train 0.0826 | test 0.3423
# epoch   153 | train_loss 1.851e-02 | test_mse 4.975e-02 | D log-err  train 0.0999 | test 0.3367
# epoch   154 | train_loss 1.929e-02 | test_mse 5.562e-02 | D log-err  train 0.1036 | test 0.3465
# epoch   155 | train_loss 1.915e-02 | test_mse 4.833e-02 | D log-err  train 0.1059 | test 0.3170
# epoch   156 | train_loss 1.897e-02 | test_mse 4.962e-02 | D log-err  train 0.0768 | test 0.3184
# epoch   157 | train_loss 1.844e-02 | test_mse 5.044e-02 | D log-err  train 0.1112 | test 0.3417
# epoch   158 | train_loss 1.881e-02 | test_mse 5.098e-02 | D log-err  train 0.0677 | test 0.3335
# epoch   159 | train_loss 1.865e-02 | test_mse 5.474e-02 | D log-err  train 0.1112 | test 0.3598
# epoch   160 | train_loss 1.893e-02 | test_mse 5.067e-02 | D log-err  train 0.1066 | test 0.3401
# epoch   161 | train_loss 1.868e-02 | test_mse 5.070e-02 | D log-err  train 0.1275 | test 0.3391
# epoch   162 | train_loss 1.878e-02 | test_mse 5.868e-02 | D log-err  train 0.0967 | test 0.3592
# epoch   163 | train_loss 1.890e-02 | test_mse 5.197e-02 | D log-err  train 0.1596 | test 0.3540
# epoch   164 | train_loss 1.901e-02 | test_mse 5.033e-02 | D log-err  train 0.1067 | test 0.3226
# epoch   165 | train_loss 1.937e-02 | test_mse 5.318e-02 | D log-err  train 0.0836 | test 0.3363
# epoch   166 | train_loss 1.883e-02 | test_mse 5.051e-02 | D log-err  train 0.1263 | test 0.3420
# epoch   167 | train_loss 1.867e-02 | test_mse 5.468e-02 | D log-err  train 0.0890 | test 0.3339
# epoch   168 | train_loss 1.844e-02 | test_mse 5.150e-02 | D log-err  train 0.0774 | test 0.3425
# epoch   169 | train_loss 1.855e-02 | test_mse 5.127e-02 | D log-err  train 0.0624 | test 0.3366
# epoch   170 | train_loss 1.880e-02 | test_mse 5.154e-02 | D log-err  train 0.0874 | test 0.3408
# epoch   171 | train_loss 1.881e-02 | test_mse 4.938e-02 | D log-err  train 0.0830 | test 0.3248
# epoch   172 | train_loss 1.880e-02 | test_mse 4.848e-02 | D log-err  train 0.0899 | test 0.3355
# epoch   173 | train_loss 1.888e-02 | test_mse 5.513e-02 | D log-err  train 0.0900 | test 0.3558
# epoch   174 | train_loss 1.885e-02 | test_mse 5.239e-02 | D log-err  train 0.0790 | test 0.3334
# epoch   175 | train_loss 1.880e-02 | test_mse 5.046e-02 | D log-err  train 0.1008 | test 0.3403
# epoch   176 | train_loss 1.872e-02 | test_mse 5.234e-02 | D log-err  train 0.0824 | test 0.3427
# epoch   177 | train_loss 1.834e-02 | test_mse 4.955e-02 | D log-err  train 0.0814 | test 0.3314
# epoch   178 | train_loss 1.855e-02 | test_mse 5.220e-02 | D log-err  train 0.0818 | test 0.3481
# epoch   179 | train_loss 1.875e-02 | test_mse 5.033e-02 | D log-err  train 0.0773 | test 0.3488
# epoch   180 | train_loss 1.848e-02 | test_mse 5.295e-02 | D log-err  train 0.1099 | test 0.3593
# epoch   181 | train_loss 1.880e-02 | test_mse 5.124e-02 | D log-err  train 0.0828 | test 0.3285
# epoch   182 | train_loss 1.874e-02 | test_mse 4.903e-02 | D log-err  train 0.0742 | test 0.3309
# epoch   183 | train_loss 1.885e-02 | test_mse 5.056e-02 | D log-err  train 0.1110 | test 0.3362
# epoch   184 | train_loss 1.899e-02 | test_mse 4.987e-02 | D log-err  train 0.0920 | test 0.3431
# epoch   185 | train_loss 1.873e-02 | test_mse 5.377e-02 | D log-err  train 0.1175 | test 0.3545
# epoch   186 | train_loss 1.857e-02 | test_mse 4.785e-02 | D log-err  train 0.1088 | test 0.3295
# epoch   187 | train_loss 1.904e-02 | test_mse 5.339e-02 | D log-err  train 0.1059 | test 0.3493
# epoch   188 | train_loss 1.927e-02 | test_mse 5.849e-02 | D log-err  train 0.1000 | test 0.3676
# epoch   189 | train_loss 1.929e-02 | test_mse 5.717e-02 | D log-err  train 0.0801 | test 0.3624
# epoch   190 | train_loss 1.878e-02 | test_mse 5.739e-02 | D log-err  train 0.0767 | test 0.3557
# epoch   191 | train_loss 1.869e-02 | test_mse 5.510e-02 | D log-err  train 0.0775 | test 0.3438
# epoch   192 | train_loss 1.879e-02 | test_mse 5.647e-02 | D log-err  train 0.0728 | test 0.3482
# epoch   193 | train_loss 1.998e-02 | test_mse 5.135e-02 | D log-err  train 0.0999 | test 0.3405
# epoch   194 | train_loss 1.935e-02 | test_mse 4.951e-02 | D log-err  train 0.0886 | test 0.3175
# epoch   195 | train_loss 1.922e-02 | test_mse 4.583e-02 | D log-err  train 0.0876 | test 0.3124
# epoch   196 | train_loss 1.884e-02 | test_mse 4.808e-02 | D log-err  train 0.1112 | test 0.3140
# epoch   197 | train_loss 1.921e-02 | test_mse 4.443e-02 | D log-err  train 0.0958 | test 0.3099
# epoch   198 | train_loss 1.899e-02 | test_mse 4.476e-02 | D log-err  train 0.0721 | test 0.2932
# epoch   199 | train_loss 1.834e-02 | test_mse 4.280e-02 | D log-err  train 0.0778 | test 0.2852
# epoch   200 | train_loss 1.838e-02 | test_mse 4.459e-02 | D log-err  train 0.0949 | test 0.2972
# epoch   201 | train_loss 1.864e-02 | test_mse 4.529e-02 | D log-err  train 0.0713 | test 0.3048
# epoch   202 | train_loss 1.875e-02 | test_mse 4.764e-02 | D log-err  train 0.0907 | test 0.3164
# epoch   203 | train_loss 1.882e-02 | test_mse 4.512e-02 | D log-err  train 0.0883 | test 0.3006
# epoch   204 | train_loss 1.889e-02 | test_mse 4.487e-02 | D log-err  train 0.1257 | test 0.3121
# epoch   205 | train_loss 1.906e-02 | test_mse 4.941e-02 | D log-err  train 0.0854 | test 0.3253
# epoch   206 | train_loss 1.884e-02 | test_mse 4.988e-02 | D log-err  train 0.0851 | test 0.3330
# epoch   207 | train_loss 1.872e-02 | test_mse 5.198e-02 | D log-err  train 0.1125 | test 0.3510
# epoch   208 | train_loss 1.892e-02 | test_mse 4.974e-02 | D log-err  train 0.0909 | test 0.3288
# epoch   209 | train_loss 1.858e-02 | test_mse 5.040e-02 | D log-err  train 0.1029 | test 0.3308
# epoch   210 | train_loss 1.869e-02 | test_mse 4.931e-02 | D log-err  train 0.0812 | test 0.3143
# epoch   211 | train_loss 1.865e-02 | test_mse 4.756e-02 | D log-err  train 0.0887 | test 0.2907
# epoch   212 | train_loss 1.874e-02 | test_mse 4.701e-02 | D log-err  train 0.0922 | test 0.2975
# epoch   213 | train_loss 1.905e-02 | test_mse 5.248e-02 | D log-err  train 0.0849 | test 0.3257
# epoch   214 | train_loss 1.887e-02 | test_mse 4.576e-02 | D log-err  train 0.0885 | test 0.2847
# epoch   215 | train_loss 1.905e-02 | test_mse 5.059e-02 | D log-err  train 0.0859 | test 0.3141
# epoch   216 | train_loss 1.862e-02 | test_mse 5.044e-02 | D log-err  train 0.0771 | test 0.3089
# epoch   217 | train_loss 1.867e-02 | test_mse 4.756e-02 | D log-err  train 0.0938 | test 0.2945
# epoch   218 | train_loss 1.895e-02 | test_mse 4.744e-02 | D log-err  train 0.0772 | test 0.3122
# epoch   219 | train_loss 1.891e-02 | test_mse 4.575e-02 | D log-err  train 0.0794 | test 0.2969
# epoch   220 | train_loss 1.870e-02 | test_mse 5.027e-02 | D log-err  train 0.0772 | test 0.3296
# epoch   221 | train_loss 1.879e-02 | test_mse 5.343e-02 | D log-err  train 0.0902 | test 0.3474
# epoch   222 | train_loss 1.888e-02 | test_mse 5.181e-02 | D log-err  train 0.0917 | test 0.3378
# epoch   223 | train_loss 1.841e-02 | test_mse 5.059e-02 | D log-err  train 0.0640 | test 0.3142
# epoch   224 | train_loss 1.854e-02 | test_mse 5.084e-02 | D log-err  train 0.0789 | test 0.3130
# epoch   225 | train_loss 1.870e-02 | test_mse 5.109e-02 | D log-err  train 0.0764 | test 0.3272
# epoch   226 | train_loss 1.841e-02 | test_mse 4.733e-02 | D log-err  train 0.1062 | test 0.3169
# epoch   227 | train_loss 1.881e-02 | test_mse 5.480e-02 | D log-err  train 0.1004 | test 0.3728
# epoch   228 | train_loss 1.890e-02 | test_mse 5.117e-02 | D log-err  train 0.1062 | test 0.3337
# epoch   229 | train_loss 1.912e-02 | test_mse 5.315e-02 | D log-err  train 0.0874 | test 0.3323
# epoch   230 | train_loss 1.930e-02 | test_mse 5.044e-02 | D log-err  train 0.1190 | test 0.3356
# epoch   231 | train_loss 1.898e-02 | test_mse 5.012e-02 | D log-err  train 0.0974 | test 0.3410
# epoch   232 | train_loss 1.892e-02 | test_mse 5.194e-02 | D log-err  train 0.1314 | test 0.3592
# epoch   233 | train_loss 1.875e-02 | test_mse 4.945e-02 | D log-err  train 0.1051 | test 0.3300
# epoch   234 | train_loss 1.858e-02 | test_mse 5.249e-02 | D log-err  train 0.0866 | test 0.3403
# epoch   235 | train_loss 1.847e-02 | test_mse 4.991e-02 | D log-err  train 0.1252 | test 0.3302
# epoch   236 | train_loss 1.851e-02 | test_mse 5.288e-02 | D log-err  train 0.0768 | test 0.3316
# epoch   237 | train_loss 1.883e-02 | test_mse 5.244e-02 | D log-err  train 0.0964 | test 0.3296
# epoch   238 | train_loss 1.841e-02 | test_mse 4.940e-02 | D log-err  train 0.1008 | test 0.3128
# epoch   239 | train_loss 1.883e-02 | test_mse 4.796e-02 | D log-err  train 0.1010 | test 0.3022
# epoch   240 | train_loss 1.906e-02 | test_mse 5.063e-02 | D log-err  train 0.0910 | test 0.3207
# epoch   241 | train_loss 1.897e-02 | test_mse 5.234e-02 | D log-err  train 0.1097 | test 0.3518
# epoch   242 | train_loss 1.885e-02 | test_mse 5.619e-02 | D log-err  train 0.0854 | test 0.3594
# epoch   243 | train_loss 1.892e-02 | test_mse 5.454e-02 | D log-err  train 0.1129 | test 0.3548
# epoch   244 | train_loss 1.861e-02 | test_mse 5.570e-02 | D log-err  train 0.1428 | test 0.3593
# epoch   245 | train_loss 1.856e-02 | test_mse 5.644e-02 | D log-err  train 0.1237 | test 0.3549
# epoch   246 | train_loss 1.876e-02 | test_mse 5.597e-02 | D log-err  train 0.0757 | test 0.3521
# epoch   247 | train_loss 1.881e-02 | test_mse 5.591e-02 | D log-err  train 0.0863 | test 0.3512
# epoch   248 | train_loss 1.910e-02 | test_mse 4.986e-02 | D log-err  train 0.0810 | test 0.3189
# epoch   249 | train_loss 1.891e-02 | test_mse 5.358e-02 | D log-err  train 0.1032 | test 0.3511
# epoch   250 | train_loss 1.863e-02 | test_mse 5.646e-02 | D log-err  train 0.0667 | test 0.3480
# epoch   251 | train_loss 1.863e-02 | test_mse 5.287e-02 | D log-err  train 0.0870 | test 0.3328
# epoch   252 | train_loss 1.858e-02 | test_mse 5.306e-02 | D log-err  train 0.0916 | test 0.3250
# epoch   253 | train_loss 1.878e-02 | test_mse 5.166e-02 | D log-err  train 0.0891 | test 0.3267
# epoch   254 | train_loss 1.880e-02 | test_mse 5.070e-02 | D log-err  train 0.0694 | test 0.3067
# epoch   255 | train_loss 1.867e-02 | test_mse 5.210e-02 | D log-err  train 0.1019 | test 0.3234
# epoch   256 | train_loss 1.860e-02 | test_mse 5.324e-02 | D log-err  train 0.0941 | test 0.3372
# epoch   257 | train_loss 1.878e-02 | test_mse 5.602e-02 | D log-err  train 0.0713 | test 0.3534
# epoch   258 | train_loss 1.860e-02 | test_mse 5.733e-02 | D log-err  train 0.0946 | test 0.3750
# epoch   259 | train_loss 1.870e-02 | test_mse 5.511e-02 | D log-err  train 0.0995 | test 0.3453
# epoch   260 | train_loss 1.884e-02 | test_mse 5.535e-02 | D log-err  train 0.1026 | test 0.3478
# epoch   261 | train_loss 1.885e-02 | test_mse 5.452e-02 | D log-err  train 0.1334 | test 0.3459
# epoch   262 | train_loss 1.861e-02 | test_mse 5.800e-02 | D log-err  train 0.0893 | test 0.3516
# epoch   263 | train_loss 1.896e-02 | test_mse 5.262e-02 | D log-err  train 0.0743 | test 0.3248
# epoch   264 | train_loss 1.883e-02 | test_mse 5.476e-02 | D log-err  train 0.0959 | test 0.3378
# epoch   265 | train_loss 1.875e-02 | test_mse 5.497e-02 | D log-err  train 0.0789 | test 0.3485
# epoch   266 | train_loss 1.839e-02 | test_mse 5.683e-02 | D log-err  train 0.1196 | test 0.3644
# epoch   267 | train_loss 1.863e-02 | test_mse 5.309e-02 | D log-err  train 0.0998 | test 0.3501
# epoch   268 | train_loss 1.852e-02 | test_mse 5.386e-02 | D log-err  train 0.0763 | test 0.3327
# epoch   269 | train_loss 1.861e-02 | test_mse 5.626e-02 | D log-err  train 0.0871 | test 0.3349
# epoch   270 | train_loss 1.856e-02 | test_mse 5.314e-02 | D log-err  train 0.1073 | test 0.3541
# epoch   271 | train_loss 1.918e-02 | test_mse 5.359e-02 | D log-err  train 0.0854 | test 0.3393
# epoch   272 | train_loss 1.892e-02 | test_mse 5.617e-02 | D log-err  train 0.1069 | test 0.3548
# epoch   273 | train_loss 1.904e-02 | test_mse 5.563e-02 | D log-err  train 0.1236 | test 0.3735
# epoch   274 | train_loss 1.901e-02 | test_mse 5.321e-02 | D log-err  train 0.0793 | test 0.3416
# epoch   275 | train_loss 1.901e-02 | test_mse 5.581e-02 | D log-err  train 0.1456 | test 0.3587
# epoch   276 | train_loss 1.868e-02 | test_mse 5.658e-02 | D log-err  train 0.0785 | test 0.3506
# epoch   277 | train_loss 1.877e-02 | test_mse 5.841e-02 | D log-err  train 0.1204 | test 0.3659
# epoch   278 | train_loss 1.855e-02 | test_mse 5.527e-02 | D log-err  train 0.1113 | test 0.3508
# epoch   279 | train_loss 1.870e-02 | test_mse 6.012e-02 | D log-err  train 0.1074 | test 0.3955
# epoch   280 | train_loss 1.861e-02 | test_mse 5.676e-02 | D log-err  train 0.1090 | test 0.3656
# epoch   281 | train_loss 1.886e-02 | test_mse 5.545e-02 | D log-err  train 0.0819 | test 0.3451
# epoch   282 | train_loss 1.905e-02 | test_mse 5.615e-02 | D log-err  train 0.1208 | test 0.3637
# epoch   283 | train_loss 1.870e-02 | test_mse 5.541e-02 | D log-err  train 0.1213 | test 0.3585
# epoch   284 | train_loss 1.892e-02 | test_mse 5.286e-02 | D log-err  train 0.1420 | test 0.3476
# epoch   285 | train_loss 1.872e-02 | test_mse 5.392e-02 | D log-err  train 0.0986 | test 0.3547
# epoch   286 | train_loss 1.858e-02 | test_mse 5.713e-02 | D log-err  train 0.0934 | test 0.3607
# epoch   287 | train_loss 1.858e-02 | test_mse 5.405e-02 | D log-err  train 0.1144 | test 0.3486
# epoch   288 | train_loss 1.854e-02 | test_mse 5.871e-02 | D log-err  train 0.0817 | test 0.3759
# epoch   289 | train_loss 1.869e-02 | test_mse 5.689e-02 | D log-err  train 0.0823 | test 0.3581
# epoch   290 | train_loss 1.846e-02 | test_mse 5.074e-02 | D log-err  train 0.0944 | test 0.3202
# epoch   291 | train_loss 1.881e-02 | test_mse 5.887e-02 | D log-err  train 0.0997 | test 0.3726
# epoch   292 | train_loss 1.918e-02 | test_mse 6.223e-02 | D log-err  train 0.0761 | test 0.3864
# epoch   293 | train_loss 1.940e-02 | test_mse 5.715e-02 | D log-err  train 0.0792 | test 0.3650
# epoch   294 | train_loss 1.902e-02 | test_mse 5.541e-02 | D log-err  train 0.1221 | test 0.3642
# epoch   295 | train_loss 1.847e-02 | test_mse 5.736e-02 | D log-err  train 0.1035 | test 0.3718
# epoch   296 | train_loss 1.871e-02 | test_mse 5.986e-02 | D log-err  train 0.0855 | test 0.3924
# epoch   297 | train_loss 1.875e-02 | test_mse 5.946e-02 | D log-err  train 0.0757 | test 0.3838
# epoch   298 | train_loss 1.881e-02 | test_mse 5.692e-02 | D log-err  train 0.0751 | test 0.3581
# epoch   299 | train_loss 1.870e-02 | test_mse 5.415e-02 | D log-err  train 0.1024 | test 0.3438
# epoch   300 | train_loss 1.864e-02 | test_mse 5.784e-02 | D log-err  train 0.0764 | test 0.3590
# epoch   301 | train_loss 1.894e-02 | test_mse 5.425e-02 | D log-err  train 0.0825 | test 0.3392
# epoch   302 | train_loss 1.918e-02 | test_mse 5.612e-02 | D log-err  train 0.0996 | test 0.3675
# epoch   303 | train_loss 1.913e-02 | test_mse 5.312e-02 | D log-err  train 0.0716 | test 0.3321
# epoch   304 | train_loss 1.884e-02 | test_mse 5.513e-02 | D log-err  train 0.0970 | test 0.3645
# epoch   305 | train_loss 1.893e-02 | test_mse 5.651e-02 | D log-err  train 0.1249 | test 0.3692
# epoch   306 | train_loss 1.890e-02 | test_mse 5.873e-02 | D log-err  train 0.0883 | test 0.3693
# epoch   307 | train_loss 1.884e-02 | test_mse 5.859e-02 | D log-err  train 0.1288 | test 0.4044
# epoch   308 | train_loss 1.863e-02 | test_mse 5.941e-02 | D log-err  train 0.1054 | test 0.3514
# epoch   309 | train_loss 1.877e-02 | test_mse 5.922e-02 | D log-err  train 0.0798 | test 0.3644
# epoch   310 | train_loss 1.886e-02 | test_mse 5.523e-02 | D log-err  train 0.0935 | test 0.3500
# epoch   311 | train_loss 1.872e-02 | test_mse 5.691e-02 | D log-err  train 0.0829 | test 0.3448
# epoch   312 | train_loss 1.871e-02 | test_mse 5.386e-02 | D log-err  train 0.0696 | test 0.3314
# epoch   313 | train_loss 1.878e-02 | test_mse 5.877e-02 | D log-err  train 0.0861 | test 0.3792
# epoch   314 | train_loss 1.874e-02 | test_mse 5.519e-02 | D log-err  train 0.1029 | test 0.3626
# epoch   315 | train_loss 1.908e-02 | test_mse 5.864e-02 | D log-err  train 0.0996 | test 0.3747
# epoch   316 | train_loss 1.885e-02 | test_mse 5.566e-02 | D log-err  train 0.0850 | test 0.3592
# epoch   317 | train_loss 1.833e-02 | test_mse 5.519e-02 | D log-err  train 0.0769 | test 0.3614
# epoch   318 | train_loss 1.829e-02 | test_mse 5.345e-02 | D log-err  train 0.0735 | test 0.3495
# epoch   319 | train_loss 1.843e-02 | test_mse 5.521e-02 | D log-err  train 0.0913 | test 0.3667
# epoch   320 | train_loss 1.916e-02 | test_mse 5.654e-02 | D log-err  train 0.0774 | test 0.3680
# epoch   321 | train_loss 1.919e-02 | test_mse 5.063e-02 | D log-err  train 0.0884 | test 0.3295
# epoch   322 | train_loss 1.904e-02 | test_mse 4.964e-02 | D log-err  train 0.0854 | test 0.3263
# epoch   323 | train_loss 1.914e-02 | test_mse 5.136e-02 | D log-err  train 0.0786 | test 0.3154
# epoch   324 | train_loss 1.888e-02 | test_mse 4.489e-02 | D log-err  train 0.0989 | test 0.3011
# epoch   325 | train_loss 1.884e-02 | test_mse 5.554e-02 | D log-err  train 0.0805 | test 0.3470
# epoch   326 | train_loss 1.884e-02 | test_mse 5.246e-02 | D log-err  train 0.0675 | test 0.3230
# epoch   327 | train_loss 1.855e-02 | test_mse 5.428e-02 | D log-err  train 0.0861 | test 0.3464
# epoch   328 | train_loss 1.849e-02 | test_mse 5.006e-02 | D log-err  train 0.1299 | test 0.3369
# epoch   329 | train_loss 1.874e-02 | test_mse 5.439e-02 | D log-err  train 0.0858 | test 0.3468
# epoch   330 | train_loss 1.900e-02 | test_mse 5.421e-02 | D log-err  train 0.1062 | test 0.3451
# epoch   331 | train_loss 1.859e-02 | test_mse 5.562e-02 | D log-err  train 0.0660 | test 0.3516
# epoch   332 | train_loss 1.846e-02 | test_mse 5.754e-02 | D log-err  train 0.1394 | test 0.3634
# epoch   333 | train_loss 1.903e-02 | test_mse 5.523e-02 | D log-err  train 0.1037 | test 0.3469
# epoch   334 | train_loss 1.913e-02 | test_mse 4.963e-02 | D log-err  train 0.0898 | test 0.3295
# epoch   335 | train_loss 1.881e-02 | test_mse 5.747e-02 | D log-err  train 0.0819 | test 0.3528
# epoch   336 | train_loss 1.876e-02 | test_mse 5.583e-02 | D log-err  train 0.0980 | test 0.3501
# epoch   337 | train_loss 1.854e-02 | test_mse 5.704e-02 | D log-err  train 0.0885 | test 0.3474
# epoch   338 | train_loss 1.918e-02 | test_mse 5.953e-02 | D log-err  train 0.1567 | test 0.3973
# epoch   339 | train_loss 1.876e-02 | test_mse 5.445e-02 | D log-err  train 0.1045 | test 0.3473
# epoch   340 | train_loss 1.908e-02 | test_mse 5.320e-02 | D log-err  train 0.0804 | test 0.3461
# epoch   341 | train_loss 1.866e-02 | test_mse 5.085e-02 | D log-err  train 0.1097 | test 0.3384
# epoch   342 | train_loss 1.867e-02 | test_mse 4.905e-02 | D log-err  train 0.1076 | test 0.3359
# epoch   343 | train_loss 1.860e-02 | test_mse 5.401e-02 | D log-err  train 0.0676 | test 0.3449
# epoch   344 | train_loss 1.918e-02 | test_mse 5.451e-02 | D log-err  train 0.0826 | test 0.3529
# epoch   345 | train_loss 1.898e-02 | test_mse 5.361e-02 | D log-err  train 0.0935 | test 0.3619
# epoch   346 | train_loss 1.881e-02 | test_mse 6.029e-02 | D log-err  train 0.0833 | test 0.3694
# epoch   347 | train_loss 1.846e-02 | test_mse 5.594e-02 | D log-err  train 0.1160 | test 0.3742
# epoch   348 | train_loss 1.857e-02 | test_mse 5.621e-02 | D log-err  train 0.0692 | test 0.3625
# epoch   349 | train_loss 1.845e-02 | test_mse 5.982e-02 | D log-err  train 0.0936 | test 0.3773
# epoch   350 | train_loss 1.861e-02 | test_mse 5.670e-02 | D log-err  train 0.0824 | test 0.3633
# epoch   351 | train_loss 1.890e-02 | test_mse 5.881e-02 | D log-err  train 0.0863 | test 0.3831
# epoch   352 | train_loss 1.895e-02 | test_mse 5.631e-02 | D log-err  train 0.0778 | test 0.3402
# epoch   353 | train_loss 1.891e-02 | test_mse 5.443e-02 | D log-err  train 0.1007 | test 0.3422
# epoch   354 | train_loss 1.881e-02 | test_mse 5.470e-02 | D log-err  train 0.0825 | test 0.3588
# epoch   355 | train_loss 1.894e-02 | test_mse 5.373e-02 | D log-err  train 0.0801 | test 0.3500
# epoch   356 | train_loss 1.873e-02 | test_mse 5.320e-02 | D log-err  train 0.0885 | test 0.3517
# epoch   357 | train_loss 1.915e-02 | test_mse 5.422e-02 | D log-err  train 0.0884 | test 0.3507
# epoch   358 | train_loss 1.906e-02 | test_mse 5.629e-02 | D log-err  train 0.0927 | test 0.3574
# epoch   359 | train_loss 1.868e-02 | test_mse 5.916e-02 | D log-err  train 0.1044 | test 0.3739
# epoch   360 | train_loss 1.899e-02 | test_mse 5.627e-02 | D log-err  train 0.1082 | test 0.3676
# epoch   361 | train_loss 1.903e-02 | test_mse 5.583e-02 | D log-err  train 0.0949 | test 0.3678
# epoch   362 | train_loss 1.869e-02 | test_mse 5.905e-02 | D log-err  train 0.0878 | test 0.3584
# epoch   363 | train_loss 1.861e-02 | test_mse 6.121e-02 | D log-err  train 0.1085 | test 0.4006
# epoch   364 | train_loss 1.879e-02 | test_mse 6.138e-02 | D log-err  train 0.0970 | test 0.4093
# epoch   365 | train_loss 1.849e-02 | test_mse 6.001e-02 | D log-err  train 0.1150 | test 0.3847
# epoch   366 | train_loss 1.855e-02 | test_mse 5.748e-02 | D log-err  train 0.0960 | test 0.3682
# epoch   367 | train_loss 1.870e-02 | test_mse 5.683e-02 | D log-err  train 0.1055 | test 0.3648
# epoch   368 | train_loss 1.850e-02 | test_mse 5.590e-02 | D log-err  train 0.0770 | test 0.3710
# epoch   369 | train_loss 1.837e-02 | test_mse 5.790e-02 | D log-err  train 0.0578 | test 0.3682
# epoch   370 | train_loss 1.858e-02 | test_mse 5.494e-02 | D log-err  train 0.0742 | test 0.3512
# epoch   371 | train_loss 1.830e-02 | test_mse 5.481e-02 | D log-err  train 0.1314 | test 0.3659
# epoch   372 | train_loss 1.870e-02 | test_mse 5.505e-02 | D log-err  train 0.1030 | test 0.3509
# epoch   373 | train_loss 1.867e-02 | test_mse 5.145e-02 | D log-err  train 0.0909 | test 0.3307
# epoch   374 | train_loss 1.952e-02 | test_mse 5.810e-02 | D log-err  train 0.0891 | test 0.3617
# epoch   375 | train_loss 1.916e-02 | test_mse 6.027e-02 | D log-err  train 0.0887 | test 0.3778
# epoch   376 | train_loss 1.887e-02 | test_mse 5.756e-02 | D log-err  train 0.0882 | test 0.3717
# epoch   377 | train_loss 1.927e-02 | test_mse 5.952e-02 | D log-err  train 0.0755 | test 0.3794
# epoch   378 | train_loss 1.871e-02 | test_mse 6.151e-02 | D log-err  train 0.0932 | test 0.3983
# epoch   379 | train_loss 1.849e-02 | test_mse 5.769e-02 | D log-err  train 0.0948 | test 0.3857
# epoch   380 | train_loss 1.841e-02 | test_mse 5.809e-02 | D log-err  train 0.1309 | test 0.3947
# epoch   381 | train_loss 1.887e-02 | test_mse 4.985e-02 | D log-err  train 0.1210 | test 0.3388
# epoch   382 | train_loss 1.925e-02 | test_mse 5.539e-02 | D log-err  train 0.1025 | test 0.3693
# epoch   383 | train_loss 1.931e-02 | test_mse 5.157e-02 | D log-err  train 0.0944 | test 0.3459
# epoch   384 | train_loss 1.914e-02 | test_mse 5.243e-02 | D log-err  train 0.0863 | test 0.3546
# epoch   385 | train_loss 1.843e-02 | test_mse 5.225e-02 | D log-err  train 0.1092 | test 0.3495
# epoch   386 | train_loss 1.849e-02 | test_mse 5.379e-02 | D log-err  train 0.1105 | test 0.3644
# epoch   387 | train_loss 1.872e-02 | test_mse 5.144e-02 | D log-err  train 0.0792 | test 0.3478
# epoch   388 | train_loss 1.845e-02 | test_mse 5.442e-02 | D log-err  train 0.0846 | test 0.3573
# epoch   389 | train_loss 1.872e-02 | test_mse 5.454e-02 | D log-err  train 0.0844 | test 0.3613
# epoch   390 | train_loss 1.883e-02 | test_mse 5.642e-02 | D log-err  train 0.0940 | test 0.3749
# epoch   391 | train_loss 1.869e-02 | test_mse 5.296e-02 | D log-err  train 0.1389 | test 0.3596
# epoch   392 | train_loss 1.867e-02 | test_mse 5.208e-02 | D log-err  train 0.0974 | test 0.3475
# epoch   393 | train_loss 1.864e-02 | test_mse 5.291e-02 | D log-err  train 0.1049 | test 0.3520
# epoch   394 | train_loss 1.924e-02 | test_mse 5.254e-02 | D log-err  train 0.0894 | test 0.3316
# epoch   395 | train_loss 1.889e-02 | test_mse 5.363e-02 | D log-err  train 0.0797 | test 0.3379
# epoch   396 | train_loss 1.883e-02 | test_mse 4.940e-02 | D log-err  train 0.1239 | test 0.3196
# epoch   397 | train_loss 1.915e-02 | test_mse 5.359e-02 | D log-err  train 0.0832 | test 0.3370
# epoch   398 | train_loss 1.912e-02 | test_mse 5.258e-02 | D log-err  train 0.1237 | test 0.3519
# epoch   399 | train_loss 1.868e-02 | test_mse 5.241e-02 | D log-err  train 0.0725 | test 0.3286
# epoch   400 | train_loss 1.872e-02 | test_mse 5.294e-02 | D log-err  train 0.0985 | test 0.3370
# epoch   401 | train_loss 1.897e-02 | test_mse 5.218e-02 | D log-err  train 0.0911 | test 0.3321
# epoch   402 | train_loss 1.856e-02 | test_mse 4.926e-02 | D log-err  train 0.0839 | test 0.3107
# epoch   403 | train_loss 1.863e-02 | test_mse 4.998e-02 | D log-err  train 0.1488 | test 0.3376
# epoch   404 | train_loss 1.911e-02 | test_mse 4.892e-02 | D log-err  train 0.0746 | test 0.3161
# epoch   405 | train_loss 1.853e-02 | test_mse 4.946e-02 | D log-err  train 0.1060 | test 0.3296
# epoch   406 | train_loss 1.886e-02 | test_mse 4.989e-02 | D log-err  train 0.0700 | test 0.3320
# epoch   407 | train_loss 1.862e-02 | test_mse 4.862e-02 | D log-err  train 0.0947 | test 0.3328
# epoch   408 | train_loss 1.852e-02 | test_mse 4.671e-02 | D log-err  train 0.0715 | test 0.3148
# epoch   409 | train_loss 1.868e-02 | test_mse 4.560e-02 | D log-err  train 0.1101 | test 0.3108
# epoch   410 | train_loss 1.854e-02 | test_mse 4.842e-02 | D log-err  train 0.0969 | test 0.3260
# epoch   411 | train_loss 1.826e-02 | test_mse 4.876e-02 | D log-err  train 0.1249 | test 0.3436
# epoch   412 | train_loss 1.866e-02 | test_mse 4.708e-02 | D log-err  train 0.0847 | test 0.3250
# epoch   413 | train_loss 1.868e-02 | test_mse 5.094e-02 | D log-err  train 0.1174 | test 0.3347
# epoch   414 | train_loss 1.862e-02 | test_mse 4.940e-02 | D log-err  train 0.1256 | test 0.3456
# epoch   415 | train_loss 1.907e-02 | test_mse 5.510e-02 | D log-err  train 0.0867 | test 0.3601
# epoch   416 | train_loss 1.897e-02 | test_mse 5.492e-02 | D log-err  train 0.0981 | test 0.3450
# epoch   417 | train_loss 1.888e-02 | test_mse 5.440e-02 | D log-err  train 0.0881 | test 0.3390
# epoch   418 | train_loss 1.887e-02 | test_mse 5.634e-02 | D log-err  train 0.0830 | test 0.3345
# epoch   419 | train_loss 1.926e-02 | test_mse 5.279e-02 | D log-err  train 0.1585 | test 0.3484
# epoch   420 | train_loss 1.893e-02 | test_mse 5.513e-02 | D log-err  train 0.0956 | test 0.3469
# epoch   421 | train_loss 1.855e-02 | test_mse 5.481e-02 | D log-err  train 0.0946 | test 0.3385
# epoch   422 | train_loss 1.864e-02 | test_mse 5.458e-02 | D log-err  train 0.0757 | test 0.3330
# epoch   423 | train_loss 1.915e-02 | test_mse 5.306e-02 | D log-err  train 0.0931 | test 0.3264
# epoch   424 | train_loss 1.936e-02 | test_mse 5.476e-02 | D log-err  train 0.0938 | test 0.3521
# epoch   425 | train_loss 1.922e-02 | test_mse 5.238e-02 | D log-err  train 0.0847 | test 0.3177
# epoch   426 | train_loss 1.935e-02 | test_mse 5.138e-02 | D log-err  train 0.0662 | test 0.3123
# epoch   427 | train_loss 1.871e-02 | test_mse 4.977e-02 | D log-err  train 0.1204 | test 0.3094
# epoch   428 | train_loss 1.867e-02 | test_mse 5.148e-02 | D log-err  train 0.0944 | test 0.3236
# epoch   429 | train_loss 1.833e-02 | test_mse 5.474e-02 | D log-err  train 0.1371 | test 0.3539
# epoch   430 | train_loss 1.859e-02 | test_mse 5.373e-02 | D log-err  train 0.1075 | test 0.3688
# epoch   431 | train_loss 1.878e-02 | test_mse 4.952e-02 | D log-err  train 0.0869 | test 0.3160
# epoch   432 | train_loss 1.902e-02 | test_mse 5.819e-02 | D log-err  train 0.1564 | test 0.3733
# epoch   433 | train_loss 1.904e-02 | test_mse 5.184e-02 | D log-err  train 0.1062 | test 0.3337
# epoch   434 | train_loss 1.867e-02 | test_mse 5.420e-02 | D log-err  train 0.1488 | test 0.3550
# epoch   435 | train_loss 1.849e-02 | test_mse 5.666e-02 | D log-err  train 0.0822 | test 0.3635
# epoch   436 | train_loss 1.862e-02 | test_mse 5.374e-02 | D log-err  train 0.0955 | test 0.3436
# epoch   437 | train_loss 1.876e-02 | test_mse 5.552e-02 | D log-err  train 0.1009 | test 0.3452
# epoch   438 | train_loss 1.899e-02 | test_mse 5.281e-02 | D log-err  train 0.1091 | test 0.3497
# epoch   439 | train_loss 1.863e-02 | test_mse 5.314e-02 | D log-err  train 0.0778 | test 0.3439
# epoch   440 | train_loss 1.874e-02 | test_mse 4.949e-02 | D log-err  train 0.0876 | test 0.3176
# epoch   441 | train_loss 1.915e-02 | test_mse 5.174e-02 | D log-err  train 0.0928 | test 0.3422
# epoch   442 | train_loss 1.859e-02 | test_mse 4.899e-02 | D log-err  train 0.0944 | test 0.3333
# epoch   443 | train_loss 1.866e-02 | test_mse 4.894e-02 | D log-err  train 0.0857 | test 0.3309
# epoch   444 | train_loss 1.864e-02 | test_mse 4.878e-02 | D log-err  train 0.0785 | test 0.3366
# epoch   445 | train_loss 1.841e-02 | test_mse 4.855e-02 | D log-err  train 0.0856 | test 0.3215
# epoch   446 | train_loss 1.848e-02 | test_mse 5.377e-02 | D log-err  train 0.1055 | test 0.3563
# epoch   447 | train_loss 1.910e-02 | test_mse 5.092e-02 | D log-err  train 0.0895 | test 0.3292
# epoch   448 | train_loss 1.921e-02 | test_mse 4.586e-02 | D log-err  train 0.0967 | test 0.3156
# epoch   449 | train_loss 1.936e-02 | test_mse 5.328e-02 | D log-err  train 0.0858 | test 0.3561
# epoch   450 | train_loss 1.919e-02 | test_mse 5.653e-02 | D log-err  train 0.0920 | test 0.3604
# epoch   451 | train_loss 1.904e-02 | test_mse 5.465e-02 | D log-err  train 0.0971 | test 0.3542
# epoch   452 | train_loss 1.903e-02 | test_mse 5.721e-02 | D log-err  train 0.0893 | test 0.3617
# epoch   453 | train_loss 1.907e-02 | test_mse 5.587e-02 | D log-err  train 0.0665 | test 0.3440
# epoch   454 | train_loss 1.851e-02 | test_mse 5.967e-02 | D log-err  train 0.1138 | test 0.3803
# epoch   455 | train_loss 1.846e-02 | test_mse 5.522e-02 | D log-err  train 0.0787 | test 0.3527
# epoch   456 | train_loss 1.838e-02 | test_mse 5.690e-02 | D log-err  train 0.0846 | test 0.3707
# epoch   457 | train_loss 1.836e-02 | test_mse 5.795e-02 | D log-err  train 0.1139 | test 0.3769
# epoch   458 | train_loss 1.849e-02 | test_mse 5.226e-02 | D log-err  train 0.1169 | test 0.3489
# epoch   459 | train_loss 1.858e-02 | test_mse 5.658e-02 | D log-err  train 0.0855 | test 0.3526
# epoch   460 | train_loss 1.933e-02 | test_mse 5.638e-02 | D log-err  train 0.0778 | test 0.3688
# epoch   461 | train_loss 1.882e-02 | test_mse 5.264e-02 | D log-err  train 0.1122 | test 0.3529
# epoch   462 | train_loss 1.886e-02 | test_mse 5.522e-02 | D log-err  train 0.0922 | test 0.3644
# epoch   463 | train_loss 1.866e-02 | test_mse 5.401e-02 | D log-err  train 0.1152 | test 0.3699
# epoch   464 | train_loss 1.873e-02 | test_mse 5.329e-02 | D log-err  train 0.0985 | test 0.3573
# epoch   465 | train_loss 1.851e-02 | test_mse 5.576e-02 | D log-err  train 0.0875 | test 0.3703
# epoch   466 | train_loss 1.850e-02 | test_mse 5.453e-02 | D log-err  train 0.0832 | test 0.3522
# epoch   467 | train_loss 1.845e-02 | test_mse 5.598e-02 | D log-err  train 0.1132 | test 0.3740
# epoch   468 | train_loss 1.842e-02 | test_mse 5.586e-02 | D log-err  train 0.0870 | test 0.3550
# epoch   469 | train_loss 1.849e-02 | test_mse 5.325e-02 | D log-err  train 0.0811 | test 0.3388
# epoch   470 | train_loss 1.913e-02 | test_mse 5.431e-02 | D log-err  train 0.0898 | test 0.3466
# epoch   471 | train_loss 1.895e-02 | test_mse 5.567e-02 | D log-err  train 0.1270 | test 0.3775
# epoch   472 | train_loss 1.870e-02 | test_mse 5.567e-02 | D log-err  train 0.0965 | test 0.3556
# epoch   473 | train_loss 1.886e-02 | test_mse 5.744e-02 | D log-err  train 0.1307 | test 0.3735
# epoch   474 | train_loss 1.922e-02 | test_mse 5.304e-02 | D log-err  train 0.0927 | test 0.3507
# epoch   475 | train_loss 1.867e-02 | test_mse 5.897e-02 | D log-err  train 0.0853 | test 0.3936
# epoch   476 | train_loss 1.884e-02 | test_mse 5.992e-02 | D log-err  train 0.0888 | test 0.3963
# epoch   477 | train_loss 1.910e-02 | test_mse 5.310e-02 | D log-err  train 0.0977 | test 0.3560
# epoch   478 | train_loss 1.912e-02 | test_mse 5.692e-02 | D log-err  train 0.1075 | test 0.3665
# epoch   479 | train_loss 1.890e-02 | test_mse 5.963e-02 | D log-err  train 0.0915 | test 0.3925
# epoch   480 | train_loss 1.867e-02 | test_mse 5.536e-02 | D log-err  train 0.0707 | test 0.3480
# epoch   481 | train_loss 1.845e-02 | test_mse 5.459e-02 | D log-err  train 0.0891 | test 0.3495
# epoch   482 | train_loss 1.892e-02 | test_mse 5.781e-02 | D log-err  train 0.0845 | test 0.3597
# epoch   483 | train_loss 1.869e-02 | test_mse 5.583e-02 | D log-err  train 0.0673 | test 0.3358
# epoch   484 | train_loss 1.849e-02 | test_mse 5.563e-02 | D log-err  train 0.0708 | test 0.3632
# epoch   485 | train_loss 1.848e-02 | test_mse 5.712e-02 | D log-err  train 0.0859 | test 0.3498
# epoch   486 | train_loss 1.853e-02 | test_mse 5.464e-02 | D log-err  train 0.0904 | test 0.3600
# epoch   487 | train_loss 1.836e-02 | test_mse 5.740e-02 | D log-err  train 0.0859 | test 0.3588
# epoch   488 | train_loss 1.896e-02 | test_mse 5.664e-02 | D log-err  train 0.0925 | test 0.3704
# epoch   489 | train_loss 1.872e-02 | test_mse 6.081e-02 | D log-err  train 0.0777 | test 0.3891
# epoch   490 | train_loss 1.889e-02 | test_mse 5.607e-02 | D log-err  train 0.1027 | test 0.3618
# epoch   491 | train_loss 1.891e-02 | test_mse 5.450e-02 | D log-err  train 0.0986 | test 0.3410
# epoch   492 | train_loss 1.913e-02 | test_mse 5.800e-02 | D log-err  train 0.0805 | test 0.3656
# epoch   493 | train_loss 1.883e-02 | test_mse 5.712e-02 | D log-err  train 0.0838 | test 0.3534
# ...
# epoch   835 | train_loss 1.895e-02 | test_mse 4.898e-02 | D log-err  train 0.0916 | test 0.3237
# epoch   836 | train_loss 1.869e-02 | test_mse 5.287e-02 | D log-err  train 0.1051 | test 0.3611
# epoch   837 | train_loss 1.877e-02 | test_mse 5.574e-02 | D log-err  train 0.0859 | test 0.3758
# epoch   838 | train_loss 1.860e-02 | test_mse 5.089e-02 | D log-err  train 0.0813 | test 0.3366
# epoch   839 | train_loss 1.869e-02 | test_mse 5.357e-02 | D log-err  train 0.0961 | test 0.3329
# epoch   840 | train_loss 1.861e-02 | test_mse 5.374e-02 | D log-err  train 0.0918 | test 0.3435
# epoch   841 | train_loss 1.846e-02 | test_mse 5.505e-02 | D log-err  train 0.1019 | test 0.3511
# epoch   842 | train_loss 1.859e-02 | test_mse 5.167e-02 | D log-err  train 0.0991 | test 0.3405
# epoch   843 | train_loss 1.870e-02 | test_mse 5.046e-02 | D log-err  train 0.1028 | test 0.3095
# epoch   844 | train_loss 1.908e-02 | test_mse 5.893e-02 | D log-err  train 0.1043 | test 0.3645
# epoch   845 | train_loss 1.955e-02 | test_mse 5.418e-02 | D log-err  train 0.1102 | test 0.3557
# epoch   846 | train_loss 1.910e-02 | test_mse 5.753e-02 | D log-err  train 0.1031 | test 0.3622
# epoch   847 | train_loss 1.930e-02 | test_mse 5.583e-02 | D log-err  train 0.0816 | test 0.3504
# epoch   848 | train_loss 1.859e-02 | test_mse 5.579e-02 | D log-err  train 0.0762 | test 0.3410
# epoch   849 | train_loss 1.862e-02 | test_mse 6.041e-02 | D log-err  train 0.0990 | test 0.3610
# epoch   850 | train_loss 1.884e-02 | test_mse 5.919e-02 | D log-err  train 0.0953 | test 0.3546
# epoch   851 | train_loss 1.837e-02 | test_mse 6.147e-02 | D log-err  train 0.0809 | test 0.3618
# epoch   852 | train_loss 1.826e-02 | test_mse 5.653e-02 | D log-err  train 0.1191 | test 0.3607
# epoch   853 | train_loss 1.892e-02 | test_mse 5.665e-02 | D log-err  train 0.1010 | test 0.3510
# epoch   854 | train_loss 1.860e-02 | test_mse 5.702e-02 | D log-err  train 0.1023 | test 0.3635
# epoch   855 | train_loss 1.872e-02 | test_mse 5.248e-02 | D log-err  train 0.0851 | test 0.3134
# epoch   856 | train_loss 1.895e-02 | test_mse 5.400e-02 | D log-err  train 0.1100 | test 0.3311
# epoch   857 | train_loss 1.869e-02 | test_mse 5.380e-02 | D log-err  train 0.0975 | test 0.3313
# epoch   858 | train_loss 1.852e-02 | test_mse 5.401e-02 | D log-err  train 0.1028 | test 0.3346
# epoch   859 | train_loss 1.871e-02 | test_mse 5.109e-02 | D log-err  train 0.0895 | test 0.3072
# epoch   860 | train_loss 1.892e-02 | test_mse 5.391e-02 | D log-err  train 0.0878 | test 0.3259
# epoch   861 | train_loss 1.878e-02 | test_mse 5.286e-02 | D log-err  train 0.0929 | test 0.3261
# epoch   862 | train_loss 1.875e-02 | test_mse 5.635e-02 | D log-err  train 0.0760 | test 0.3422
# epoch   863 | train_loss 1.880e-02 | test_mse 5.906e-02 | D log-err  train 0.1170 | test 0.3642
# epoch   864 | train_loss 1.906e-02 | test_mse 5.277e-02 | D log-err  train 0.0914 | test 0.3262
# epoch   865 | train_loss 1.890e-02 | test_mse 5.616e-02 | D log-err  train 0.1201 | test 0.3665
# epoch   866 | train_loss 1.916e-02 | test_mse 5.250e-02 | D log-err  train 0.1093 | test 0.3256
# epoch   867 | train_loss 1.886e-02 | test_mse 5.075e-02 | D log-err  train 0.0985 | test 0.3273
# epoch   868 | train_loss 1.874e-02 | test_mse 5.129e-02 | D log-err  train 0.0734 | test 0.3237
# epoch   869 | train_loss 1.889e-02 | test_mse 4.749e-02 | D log-err  train 0.1002 | test 0.3027
# epoch   870 | train_loss 1.860e-02 | test_mse 4.722e-02 | D log-err  train 0.0693 | test 0.2991
# epoch   871 | train_loss 1.841e-02 | test_mse 4.538e-02 | D log-err  train 0.1056 | test 0.2975
# epoch   872 | train_loss 1.855e-02 | test_mse 4.864e-02 | D log-err  train 0.0852 | test 0.3103
# epoch   873 | train_loss 1.858e-02 | test_mse 5.016e-02 | D log-err  train 0.0866 | test 0.3200
# epoch   874 | train_loss 1.857e-02 | test_mse 4.729e-02 | D log-err  train 0.0715 | test 0.2802
# epoch   875 | train_loss 1.877e-02 | test_mse 5.005e-02 | D log-err  train 0.0839 | test 0.3186
# epoch   876 | train_loss 1.871e-02 | test_mse 4.805e-02 | D log-err  train 0.0934 | test 0.2965
# epoch   877 | train_loss 1.883e-02 | test_mse 5.230e-02 | D log-err  train 0.1456 | test 0.3394
# epoch   878 | train_loss 1.874e-02 | test_mse 4.648e-02 | D log-err  train 0.1431 | test 0.3072
# epoch   879 | train_loss 1.885e-02 | test_mse 4.396e-02 | D log-err  train 0.1421 | test 0.2763
# epoch   880 | train_loss 1.900e-02 | test_mse 4.797e-02 | D log-err  train 0.0861 | test 0.3014
# epoch   881 | train_loss 1.863e-02 | test_mse 4.693e-02 | D log-err  train 0.0795 | test 0.2888
# epoch   882 | train_loss 1.850e-02 | test_mse 4.749e-02 | D log-err  train 0.0883 | test 0.2888
# epoch   883 | train_loss 1.834e-02 | test_mse 5.112e-02 | D log-err  train 0.0855 | test 0.3168
# epoch   884 | train_loss 1.837e-02 | test_mse 5.152e-02 | D log-err  train 0.0660 | test 0.3154
# epoch   885 | train_loss 1.862e-02 | test_mse 4.657e-02 | D log-err  train 0.1031 | test 0.3121
# epoch   886 | train_loss 1.894e-02 | test_mse 5.128e-02 | D log-err  train 0.1194 | test 0.3421
# epoch   887 | train_loss 1.880e-02 | test_mse 4.427e-02 | D log-err  train 0.1346 | test 0.3054
# epoch   888 | train_loss 1.907e-02 | test_mse 5.524e-02 | D log-err  train 0.1318 | test 0.3577
# epoch   889 | train_loss 1.902e-02 | test_mse 6.220e-02 | D log-err  train 0.1245 | test 0.3834
# epoch   890 | train_loss 1.870e-02 | test_mse 5.864e-02 | D log-err  train 0.0955 | test 0.3646
# epoch   891 | train_loss 1.922e-02 | test_mse 4.974e-02 | D log-err  train 0.0829 | test 0.3123
# epoch   892 | train_loss 1.916e-02 | test_mse 4.821e-02 | D log-err  train 0.0773 | test 0.3129
# epoch   893 | train_loss 1.910e-02 | test_mse 4.825e-02 | D log-err  train 0.1061 | test 0.3199
# epoch   894 | train_loss 1.868e-02 | test_mse 5.064e-02 | D log-err  train 0.0761 | test 0.3259
# epoch   895 | train_loss 1.870e-02 | test_mse 4.680e-02 | D log-err  train 0.0757 | test 0.3140
# epoch   896 | train_loss 1.895e-02 | test_mse 4.848e-02 | D log-err  train 0.0742 | test 0.2950
# epoch   897 | train_loss 1.856e-02 | test_mse 4.866e-02 | D log-err  train 0.1130 | test 0.3174
# epoch   898 | train_loss 1.871e-02 | test_mse 5.024e-02 | D log-err  train 0.0832 | test 0.3210
# epoch   899 | train_loss 1.890e-02 | test_mse 5.067e-02 | D log-err  train 0.0873 | test 0.3237
# epoch   900 | train_loss 1.832e-02 | test_mse 4.447e-02 | D log-err  train 0.1074 | test 0.2933
# epoch   901 | train_loss 1.949e-02 | test_mse 4.839e-02 | D log-err  train 0.1088 | test 0.3347
# epoch   902 | train_loss 1.916e-02 | test_mse 4.725e-02 | D log-err  train 0.1182 | test 0.3034
# epoch   903 | train_loss 1.866e-02 | test_mse 4.993e-02 | D log-err  train 0.0884 | test 0.3310
# epoch   904 | train_loss 1.881e-02 | test_mse 5.166e-02 | D log-err  train 0.1013 | test 0.3325
# epoch   905 | train_loss 1.876e-02 | test_mse 5.003e-02 | D log-err  train 0.1161 | test 0.3273
# epoch   906 | train_loss 1.864e-02 | test_mse 4.966e-02 | D log-err  train 0.0823 | test 0.3075
# epoch   907 | train_loss 1.845e-02 | test_mse 5.182e-02 | D log-err  train 0.0726 | test 0.3282
# epoch   908 | train_loss 1.845e-02 | test_mse 5.398e-02 | D log-err  train 0.0635 | test 0.3229
# epoch   909 | train_loss 1.850e-02 | test_mse 4.946e-02 | D log-err  train 0.1385 | test 0.3361
# epoch   910 | train_loss 1.879e-02 | test_mse 5.168e-02 | D log-err  train 0.0799 | test 0.3167
# epoch   911 | train_loss 1.856e-02 | test_mse 4.467e-02 | D log-err  train 0.1286 | test 0.3060
# epoch   912 | train_loss 1.969e-02 | test_mse 4.582e-02 | D log-err  train 0.0896 | test 0.2761
# epoch   913 | train_loss 1.949e-02 | test_mse 4.629e-02 | D log-err  train 0.0903 | test 0.2799
# epoch   914 | train_loss 1.922e-02 | test_mse 5.080e-02 | D log-err  train 0.0868 | test 0.2827
# epoch   915 | train_loss 1.874e-02 | test_mse 5.019e-02 | D log-err  train 0.0922 | test 0.2830
# epoch   916 | train_loss 1.859e-02 | test_mse 5.120e-02 | D log-err  train 0.0759 | test 0.2914
# epoch   917 | train_loss 1.863e-02 | test_mse 5.156e-02 | D log-err  train 0.0953 | test 0.2916
# epoch   918 | train_loss 1.879e-02 | test_mse 5.032e-02 | D log-err  train 0.0772 | test 0.2947
# epoch   919 | train_loss 1.842e-02 | test_mse 5.396e-02 | D log-err  train 0.1097 | test 0.3079
# epoch   920 | train_loss 1.887e-02 | test_mse 5.188e-02 | D log-err  train 0.0947 | test 0.3164
# epoch   921 | train_loss 1.874e-02 | test_mse 4.693e-02 | D log-err  train 0.0818 | test 0.2875
# epoch   922 | train_loss 1.910e-02 | test_mse 4.903e-02 | D log-err  train 0.0992 | test 0.3336
# epoch   923 | train_loss 1.899e-02 | test_mse 4.916e-02 | D log-err  train 0.1263 | test 0.3336
# epoch   924 | train_loss 1.863e-02 | test_mse 5.223e-02 | D log-err  train 0.0823 | test 0.3228
# epoch   925 | train_loss 1.884e-02 | test_mse 5.641e-02 | D log-err  train 0.0849 | test 0.3383
# epoch   926 | train_loss 1.903e-02 | test_mse 6.061e-02 | D log-err  train 0.1293 | test 0.3899
# epoch   927 | train_loss 1.921e-02 | test_mse 5.553e-02 | D log-err  train 0.0736 | test 0.3400
# epoch   928 | train_loss 1.885e-02 | test_mse 5.483e-02 | D log-err  train 0.1133 | test 0.3621
# epoch   929 | train_loss 1.855e-02 | test_mse 5.453e-02 | D log-err  train 0.1063 | test 0.3503
# epoch   930 | train_loss 1.874e-02 | test_mse 5.661e-02 | D log-err  train 0.0893 | test 0.3304
# epoch   931 | train_loss 1.858e-02 | test_mse 5.512e-02 | D log-err  train 0.0936 | test 0.3602
# epoch   932 | train_loss 1.824e-02 | test_mse 5.703e-02 | D log-err  train 0.0661 | test 0.3429
# epoch   933 | train_loss 1.883e-02 | test_mse 6.185e-02 | D log-err  train 0.0679 | test 0.3933
# epoch   934 | train_loss 1.836e-02 | test_mse 5.806e-02 | D log-err  train 0.1073 | test 0.3920
# epoch   935 | train_loss 1.861e-02 | test_mse 5.931e-02 | D log-err  train 0.0846 | test 0.3951
# epoch   936 | train_loss 1.843e-02 | test_mse 5.961e-02 | D log-err  train 0.0887 | test 0.4031
# epoch   937 | train_loss 1.947e-02 | test_mse 5.227e-02 | D log-err  train 0.0826 | test 0.3384
# epoch   938 | train_loss 1.925e-02 | test_mse 5.628e-02 | D log-err  train 0.0712 | test 0.3792
# epoch   939 | train_loss 1.873e-02 | test_mse 5.510e-02 | D log-err  train 0.0845 | test 0.3632
# epoch   940 | train_loss 1.846e-02 | test_mse 5.828e-02 | D log-err  train 0.0715 | test 0.3834
# epoch   941 | train_loss 1.855e-02 | test_mse 5.877e-02 | D log-err  train 0.0918 | test 0.3884
# epoch   942 | train_loss 1.839e-02 | test_mse 6.040e-02 | D log-err  train 0.1083 | test 0.4075
# epoch   943 | train_loss 1.869e-02 | test_mse 5.781e-02 | D log-err  train 0.1014 | test 0.3851
# epoch   944 | train_loss 1.903e-02 | test_mse 5.534e-02 | D log-err  train 0.1229 | test 0.3655
# epoch   945 | train_loss 1.915e-02 | test_mse 5.517e-02 | D log-err  train 0.0940 | test 0.3775
# epoch   946 | train_loss 1.882e-02 | test_mse 5.986e-02 | D log-err  train 0.0882 | test 0.3788
# epoch   947 | train_loss 1.827e-02 | test_mse 5.774e-02 | D log-err  train 0.1568 | test 0.4027
# epoch   948 | train_loss 1.845e-02 | test_mse 6.114e-02 | D log-err  train 0.0909 | test 0.3995
# epoch   949 | train_loss 1.855e-02 | test_mse 6.067e-02 | D log-err  train 0.0648 | test 0.3957
# epoch   950 | train_loss 1.835e-02 | test_mse 6.074e-02 | D log-err  train 0.0892 | test 0.4020
# epoch   951 | train_loss 1.855e-02 | test_mse 6.031e-02 | D log-err  train 0.1112 | test 0.3993
# epoch   952 | train_loss 1.990e-02 | test_mse 5.869e-02 | D log-err  train 0.1110 | test 0.3843
# epoch   953 | train_loss 1.969e-02 | test_mse 5.189e-02 | D log-err  train 0.0875 | test 0.3143
# epoch   954 | train_loss 1.909e-02 | test_mse 5.673e-02 | D log-err  train 0.1070 | test 0.3397
# epoch   955 | train_loss 1.889e-02 | test_mse 5.582e-02 | D log-err  train 0.0847 | test 0.3433
# epoch   956 | train_loss 1.847e-02 | test_mse 5.836e-02 | D log-err  train 0.0770 | test 0.3491
# epoch   957 | train_loss 1.860e-02 | test_mse 5.778e-02 | D log-err  train 0.1382 | test 0.3646
# epoch   958 | train_loss 1.878e-02 | test_mse 5.859e-02 | D log-err  train 0.0735 | test 0.3545
# epoch   959 | train_loss 1.869e-02 | test_mse 5.970e-02 | D log-err  train 0.0887 | test 0.3616
# epoch   960 | train_loss 1.882e-02 | test_mse 6.013e-02 | D log-err  train 0.1227 | test 0.3862
# epoch   961 | train_loss 1.891e-02 | test_mse 5.939e-02 | D log-err  train 0.0970 | test 0.3507
# epoch   962 | train_loss 1.862e-02 | test_mse 5.807e-02 | D log-err  train 0.1523 | test 0.4039
# epoch   963 | train_loss 1.867e-02 | test_mse 5.489e-02 | D log-err  train 0.0996 | test 0.3535
# epoch   964 | train_loss 1.879e-02 | test_mse 5.292e-02 | D log-err  train 0.1082 | test 0.3505
# epoch   965 | train_loss 1.933e-02 | test_mse 5.393e-02 | D log-err  train 0.0932 | test 0.3528
# epoch   966 | train_loss 1.912e-02 | test_mse 5.283e-02 | D log-err  train 0.1059 | test 0.3669
# epoch   967 | train_loss 1.887e-02 | test_mse 5.862e-02 | D log-err  train 0.0719 | test 0.3787
# epoch   968 | train_loss 1.896e-02 | test_mse 5.771e-02 | D log-err  train 0.0840 | test 0.3773
# epoch   969 | train_loss 1.869e-02 | test_mse 5.746e-02 | D log-err  train 0.1063 | test 0.3806
# epoch   970 | train_loss 1.875e-02 | test_mse 5.198e-02 | D log-err  train 0.0874 | test 0.3433
# epoch   971 | train_loss 1.875e-02 | test_mse 5.130e-02 | D log-err  train 0.1017 | test 0.3429
# epoch   972 | train_loss 1.884e-02 | test_mse 5.337e-02 | D log-err  train 0.0959 | test 0.3532
# epoch   973 | train_loss 1.873e-02 | test_mse 5.234e-02 | D log-err  train 0.1372 | test 0.3694
# epoch   974 | train_loss 1.883e-02 | test_mse 5.317e-02 | D log-err  train 0.0720 | test 0.3522
# epoch   975 | train_loss 1.847e-02 | test_mse 5.508e-02 | D log-err  train 0.0671 | test 0.3620
# epoch   976 | train_loss 1.883e-02 | test_mse 5.087e-02 | D log-err  train 0.0915 | test 0.3507
# epoch   977 | train_loss 1.913e-02 | test_mse 5.845e-02 | D log-err  train 0.0864 | test 0.3817
# epoch   978 | train_loss 1.921e-02 | test_mse 5.719e-02 | D log-err  train 0.0768 | test 0.3558
# epoch   979 | train_loss 1.891e-02 | test_mse 5.722e-02 | D log-err  train 0.1155 | test 0.3701
# epoch   980 | train_loss 1.920e-02 | test_mse 5.844e-02 | D log-err  train 0.0966 | test 0.3585
# epoch   981 | train_loss 1.866e-02 | test_mse 5.341e-02 | D log-err  train 0.1103 | test 0.3618
# epoch   982 | train_loss 1.895e-02 | test_mse 5.972e-02 | D log-err  train 0.1181 | test 0.3503
# epoch   983 | train_loss 1.879e-02 | test_mse 5.444e-02 | D log-err  train 0.1018 | test 0.3618
# epoch   984 | train_loss 1.849e-02 | test_mse 5.968e-02 | D log-err  train 0.0784 | test 0.3616
# epoch   985 | train_loss 1.841e-02 | test_mse 5.623e-02 | D log-err  train 0.1220 | test 0.3670
# epoch   986 | train_loss 1.889e-02 | test_mse 5.563e-02 | D log-err  train 0.0991 | test 0.3492
# epoch   987 | train_loss 1.946e-02 | test_mse 6.059e-02 | D log-err  train 0.0823 | test 0.3786
# epoch   988 | train_loss 1.860e-02 | test_mse 5.774e-02 | D log-err  train 0.0819 | test 0.3580
# epoch   989 | train_loss 1.853e-02 | test_mse 5.539e-02 | D log-err  train 0.1269 | test 0.3539
# epoch   990 | train_loss 1.926e-02 | test_mse 5.602e-02 | D log-err  train 0.0716 | test 0.3492
# epoch   991 | train_loss 1.840e-02 | test_mse 5.880e-02 | D log-err  train 0.0745 | test 0.3629
# epoch   992 | train_loss 1.874e-02 | test_mse 5.763e-02 | D log-err  train 0.0822 | test 0.3770
# epoch   993 | train_loss 1.904e-02 | test_mse 5.343e-02 | D log-err  train 0.1239 | test 0.3664
# epoch   994 | train_loss 1.875e-02 | test_mse 5.577e-02 | D log-err  train 0.0915 | test 0.3473
# epoch   995 | train_loss 1.875e-02 | test_mse 5.786e-02 | D log-err  train 0.1024 | test 0.3739
# epoch   996 | train_loss 1.883e-02 | test_mse 5.560e-02 | D log-err  train 0.0743 | test 0.3418
# epoch   997 | train_loss 1.924e-02 | test_mse 5.712e-02 | D log-err  train 0.1015 | test 0.3673
# epoch   998 | train_loss 1.927e-02 | test_mse 5.386e-02 | D log-err  train 0.1190 | test 0.3602
# epoch   999 | train_loss 1.917e-02 | test_mse 5.101e-02 | D log-err  train 0.1114 | test 0.3595
# Min_error = 0.0428, its index is 199
# ----------------------------------------------------------------------

# %% [markdown]
# ## Train with early stopping - until best recorded performance

# %%
SEED = 0
EPOCHS = 200
torch.manual_seed(SEED)
np.random.seed(SEED)
descriptornet, physicsnet = main()
# Out:
# Device: cuda
#
# D range: [7.181e-17, 2.736e-11] cm^2/s
# R range: [5.765e-05, 1.478e-02] cm
# t range: [0.0, 20540069.3] s
# Fo range (approx): [0.0000, 1.7138]
#   WARNING: 5 rows have Fo > 1.5 (will be clamped to PhysicsNet ceiling).
#
# 10 descriptor columns.
#
# Train rows: 12800 | Train particles: 256
# Test  rows: 3250  | Test  particles: 65
#
# Network 1 bias init: log10(D) = -10.000
# Network 1 params: 134,657
# Network 2 params: 132,609 (FROZEN)
# ----------------------------------------------------------------------
# epoch     0 | train_loss 6.932e-02 | test_mse 5.518e-02 | D log-err  train 0.4170 | test 0.4360
# epoch     1 | train_loss 3.720e-02 | test_mse 4.820e-02 | D log-err  train 0.2270 | test 0.3380
# epoch     2 | train_loss 2.812e-02 | test_mse 4.657e-02 | D log-err  train 0.2038 | test 0.3232
# epoch     3 | train_loss 2.355e-02 | test_mse 4.911e-02 | D log-err  train 0.1660 | test 0.3341
# epoch     4 | train_loss 2.159e-02 | test_mse 5.234e-02 | D log-err  train 0.1268 | test 0.3399
# epoch     5 | train_loss 2.132e-02 | test_mse 4.943e-02 | D log-err  train 0.1052 | test 0.3019
# epoch     6 | train_loss 2.068e-02 | test_mse 4.893e-02 | D log-err  train 0.1132 | test 0.3107
# epoch     7 | train_loss 2.005e-02 | test_mse 5.277e-02 | D log-err  train 0.1231 | test 0.3227
# epoch     8 | train_loss 2.000e-02 | test_mse 4.700e-02 | D log-err  train 0.1265 | test 0.3106
# epoch     9 | train_loss 1.969e-02 | test_mse 4.698e-02 | D log-err  train 0.1116 | test 0.3046
# epoch    10 | train_loss 1.985e-02 | test_mse 5.196e-02 | D log-err  train 0.0867 | test 0.3152
# epoch    11 | train_loss 1.923e-02 | test_mse 5.017e-02 | D log-err  train 0.0991 | test 0.2979
# epoch    12 | train_loss 1.928e-02 | test_mse 4.947e-02 | D log-err  train 0.1359 | test 0.3308
# epoch    13 | train_loss 1.941e-02 | test_mse 5.169e-02 | D log-err  train 0.0828 | test 0.3279
# epoch    14 | train_loss 1.943e-02 | test_mse 4.922e-02 | D log-err  train 0.0853 | test 0.3093
# epoch    15 | train_loss 1.908e-02 | test_mse 5.077e-02 | D log-err  train 0.0826 | test 0.3257
# epoch    16 | train_loss 1.873e-02 | test_mse 4.796e-02 | D log-err  train 0.0961 | test 0.3206
# epoch    17 | train_loss 1.915e-02 | test_mse 4.922e-02 | D log-err  train 0.1010 | test 0.3155
# epoch    18 | train_loss 1.930e-02 | test_mse 4.655e-02 | D log-err  train 0.1136 | test 0.3101
# epoch    19 | train_loss 1.934e-02 | test_mse 5.019e-02 | D log-err  train 0.0880 | test 0.3319
# epoch    20 | train_loss 1.896e-02 | test_mse 4.799e-02 | D log-err  train 0.0953 | test 0.3166
# epoch    21 | train_loss 1.910e-02 | test_mse 4.747e-02 | D log-err  train 0.1154 | test 0.3207
# epoch    22 | train_loss 1.892e-02 | test_mse 4.905e-02 | D log-err  train 0.0796 | test 0.3214
# epoch    23 | train_loss 1.902e-02 | test_mse 4.702e-02 | D log-err  train 0.1081 | test 0.3252
# epoch    24 | train_loss 1.873e-02 | test_mse 4.972e-02 | D log-err  train 0.0824 | test 0.3116
# epoch    25 | train_loss 1.896e-02 | test_mse 5.081e-02 | D log-err  train 0.0836 | test 0.3311
# epoch    26 | train_loss 1.902e-02 | test_mse 4.935e-02 | D log-err  train 0.0760 | test 0.3240
# epoch    27 | train_loss 1.927e-02 | test_mse 4.909e-02 | D log-err  train 0.1398 | test 0.3390
# epoch    28 | train_loss 1.897e-02 | test_mse 5.127e-02 | D log-err  train 0.0899 | test 0.3299
# epoch    29 | train_loss 1.879e-02 | test_mse 5.040e-02 | D log-err  train 0.0976 | test 0.3303
# epoch    30 | train_loss 1.895e-02 | test_mse 4.891e-02 | D log-err  train 0.0819 | test 0.3098
# epoch    31 | train_loss 1.907e-02 | test_mse 5.206e-02 | D log-err  train 0.0982 | test 0.3370
# epoch    32 | train_loss 1.886e-02 | test_mse 5.480e-02 | D log-err  train 0.1027 | test 0.3490
# epoch    33 | train_loss 1.893e-02 | test_mse 4.713e-02 | D log-err  train 0.1075 | test 0.3180
# epoch    34 | train_loss 1.881e-02 | test_mse 4.795e-02 | D log-err  train 0.0769 | test 0.3266
# epoch    35 | train_loss 1.895e-02 | test_mse 5.351e-02 | D log-err  train 0.1045 | test 0.3518
# epoch    36 | train_loss 1.885e-02 | test_mse 4.815e-02 | D log-err  train 0.0791 | test 0.3127
# epoch    37 | train_loss 1.846e-02 | test_mse 5.061e-02 | D log-err  train 0.0715 | test 0.3278
# epoch    38 | train_loss 1.874e-02 | test_mse 4.927e-02 | D log-err  train 0.0871 | test 0.3379
# epoch    39 | train_loss 1.921e-02 | test_mse 5.365e-02 | D log-err  train 0.1229 | test 0.3427
# epoch    40 | train_loss 1.891e-02 | test_mse 5.259e-02 | D log-err  train 0.1203 | test 0.3445
# epoch    41 | train_loss 1.885e-02 | test_mse 4.788e-02 | D log-err  train 0.0857 | test 0.3156
# epoch    42 | train_loss 1.895e-02 | test_mse 5.305e-02 | D log-err  train 0.1162 | test 0.3367
# epoch    43 | train_loss 1.896e-02 | test_mse 4.778e-02 | D log-err  train 0.0889 | test 0.3282
# epoch    44 | train_loss 1.911e-02 | test_mse 4.713e-02 | D log-err  train 0.0749 | test 0.3067
# epoch    45 | train_loss 1.906e-02 | test_mse 5.061e-02 | D log-err  train 0.0994 | test 0.3298
# epoch    46 | train_loss 1.913e-02 | test_mse 5.444e-02 | D log-err  train 0.0913 | test 0.3622
# epoch    47 | train_loss 1.882e-02 | test_mse 4.823e-02 | D log-err  train 0.0705 | test 0.3222
# epoch    48 | train_loss 1.868e-02 | test_mse 5.024e-02 | D log-err  train 0.0764 | test 0.3289
# epoch    49 | train_loss 1.878e-02 | test_mse 5.102e-02 | D log-err  train 0.0874 | test 0.3191
# epoch    50 | train_loss 1.892e-02 | test_mse 4.684e-02 | D log-err  train 0.1281 | test 0.2934
# epoch    51 | train_loss 1.894e-02 | test_mse 4.833e-02 | D log-err  train 0.0854 | test 0.3156
# epoch    52 | train_loss 1.927e-02 | test_mse 5.143e-02 | D log-err  train 0.0894 | test 0.3335
# epoch    53 | train_loss 1.900e-02 | test_mse 4.974e-02 | D log-err  train 0.0725 | test 0.3119
# epoch    54 | train_loss 1.877e-02 | test_mse 4.958e-02 | D log-err  train 0.0752 | test 0.3111
# epoch    55 | train_loss 1.875e-02 | test_mse 5.064e-02 | D log-err  train 0.0973 | test 0.3351
# epoch    56 | train_loss 1.853e-02 | test_mse 4.743e-02 | D log-err  train 0.1430 | test 0.3156
# epoch    57 | train_loss 1.859e-02 | test_mse 4.837e-02 | D log-err  train 0.0690 | test 0.3177
# epoch    58 | train_loss 1.885e-02 | test_mse 4.935e-02 | D log-err  train 0.0902 | test 0.3186
# epoch    59 | train_loss 1.855e-02 | test_mse 4.896e-02 | D log-err  train 0.0758 | test 0.3030
# epoch    60 | train_loss 1.864e-02 | test_mse 4.985e-02 | D log-err  train 0.0820 | test 0.3115
# epoch    61 | train_loss 1.846e-02 | test_mse 4.764e-02 | D log-err  train 0.0827 | test 0.3078
# epoch    62 | train_loss 1.889e-02 | test_mse 4.862e-02 | D log-err  train 0.0731 | test 0.3135
# epoch    63 | train_loss 1.872e-02 | test_mse 4.859e-02 | D log-err  train 0.0766 | test 0.3109
# epoch    64 | train_loss 1.884e-02 | test_mse 5.073e-02 | D log-err  train 0.0837 | test 0.3288
# epoch    65 | train_loss 1.880e-02 | test_mse 4.889e-02 | D log-err  train 0.1161 | test 0.3220
# epoch    66 | train_loss 1.949e-02 | test_mse 4.894e-02 | D log-err  train 0.1077 | test 0.3259
# epoch    67 | train_loss 1.894e-02 | test_mse 4.813e-02 | D log-err  train 0.0903 | test 0.3223
# epoch    68 | train_loss 1.863e-02 | test_mse 5.283e-02 | D log-err  train 0.1073 | test 0.3465
# epoch    69 | train_loss 1.880e-02 | test_mse 4.850e-02 | D log-err  train 0.0688 | test 0.3086
# epoch    70 | train_loss 1.850e-02 | test_mse 4.682e-02 | D log-err  train 0.0781 | test 0.3131
# epoch    71 | train_loss 1.867e-02 | test_mse 5.221e-02 | D log-err  train 0.1024 | test 0.3373
# epoch    72 | train_loss 1.893e-02 | test_mse 4.764e-02 | D log-err  train 0.1497 | test 0.3267
# epoch    73 | train_loss 1.938e-02 | test_mse 4.752e-02 | D log-err  train 0.0689 | test 0.3105
# epoch    74 | train_loss 1.874e-02 | test_mse 4.710e-02 | D log-err  train 0.0864 | test 0.3060
# epoch    75 | train_loss 1.898e-02 | test_mse 4.845e-02 | D log-err  train 0.0645 | test 0.3145
# epoch    76 | train_loss 1.880e-02 | test_mse 4.565e-02 | D log-err  train 0.1087 | test 0.2932
# epoch    77 | train_loss 1.837e-02 | test_mse 4.949e-02 | D log-err  train 0.0813 | test 0.3134
# epoch    78 | train_loss 1.865e-02 | test_mse 4.936e-02 | D log-err  train 0.0802 | test 0.3133
# epoch    79 | train_loss 1.859e-02 | test_mse 5.231e-02 | D log-err  train 0.0930 | test 0.3355
# epoch    80 | train_loss 1.859e-02 | test_mse 4.947e-02 | D log-err  train 0.0837 | test 0.3186
# epoch    81 | train_loss 1.854e-02 | test_mse 5.337e-02 | D log-err  train 0.0775 | test 0.3440
# epoch    82 | train_loss 1.871e-02 | test_mse 5.015e-02 | D log-err  train 0.0768 | test 0.3215
# epoch    83 | train_loss 1.935e-02 | test_mse 4.963e-02 | D log-err  train 0.1161 | test 0.3239
# epoch    84 | train_loss 1.914e-02 | test_mse 5.050e-02 | D log-err  train 0.1040 | test 0.3276
# epoch    85 | train_loss 1.913e-02 | test_mse 4.939e-02 | D log-err  train 0.1434 | test 0.3435
# epoch    86 | train_loss 1.893e-02 | test_mse 5.088e-02 | D log-err  train 0.1000 | test 0.3384
# epoch    87 | train_loss 1.893e-02 | test_mse 5.454e-02 | D log-err  train 0.1112 | test 0.3359
# epoch    88 | train_loss 1.874e-02 | test_mse 5.056e-02 | D log-err  train 0.0907 | test 0.3207
# epoch    89 | train_loss 1.885e-02 | test_mse 5.034e-02 | D log-err  train 0.0721 | test 0.3120
# epoch    90 | train_loss 1.887e-02 | test_mse 4.958e-02 | D log-err  train 0.1624 | test 0.3535
# epoch    91 | train_loss 1.848e-02 | test_mse 5.284e-02 | D log-err  train 0.0979 | test 0.3540
# epoch    92 | train_loss 1.870e-02 | test_mse 4.981e-02 | D log-err  train 0.0725 | test 0.3261
# epoch    93 | train_loss 1.873e-02 | test_mse 5.058e-02 | D log-err  train 0.0667 | test 0.3325
# epoch    94 | train_loss 1.880e-02 | test_mse 4.930e-02 | D log-err  train 0.0778 | test 0.3238
# epoch    95 | train_loss 1.877e-02 | test_mse 4.897e-02 | D log-err  train 0.1183 | test 0.3195
# epoch    96 | train_loss 1.891e-02 | test_mse 4.986e-02 | D log-err  train 0.0774 | test 0.3318
# epoch    97 | train_loss 1.886e-02 | test_mse 4.871e-02 | D log-err  train 0.1618 | test 0.3390
# epoch    98 | train_loss 1.893e-02 | test_mse 5.485e-02 | D log-err  train 0.0844 | test 0.3446
# epoch    99 | train_loss 1.884e-02 | test_mse 5.016e-02 | D log-err  train 0.0815 | test 0.3313
# epoch   100 | train_loss 1.878e-02 | test_mse 5.388e-02 | D log-err  train 0.1191 | test 0.3543
# epoch   101 | train_loss 1.841e-02 | test_mse 5.261e-02 | D log-err  train 0.0839 | test 0.3418
# epoch   102 | train_loss 1.879e-02 | test_mse 5.140e-02 | D log-err  train 0.0893 | test 0.3363
# epoch   103 | train_loss 1.897e-02 | test_mse 5.244e-02 | D log-err  train 0.0937 | test 0.3415
# epoch   104 | train_loss 1.876e-02 | test_mse 5.717e-02 | D log-err  train 0.1037 | test 0.3723
# epoch   105 | train_loss 1.877e-02 | test_mse 5.295e-02 | D log-err  train 0.1112 | test 0.3423
# epoch   106 | train_loss 1.861e-02 | test_mse 4.711e-02 | D log-err  train 0.0640 | test 0.3061
# epoch   107 | train_loss 1.879e-02 | test_mse 5.394e-02 | D log-err  train 0.0891 | test 0.3607
# epoch   108 | train_loss 1.898e-02 | test_mse 5.381e-02 | D log-err  train 0.0952 | test 0.3632
# epoch   109 | train_loss 1.935e-02 | test_mse 4.829e-02 | D log-err  train 0.0910 | test 0.3189
# epoch   110 | train_loss 1.882e-02 | test_mse 5.341e-02 | D log-err  train 0.0679 | test 0.3478
# epoch   111 | train_loss 1.887e-02 | test_mse 5.333e-02 | D log-err  train 0.0925 | test 0.3438
# epoch   112 | train_loss 1.907e-02 | test_mse 5.474e-02 | D log-err  train 0.0885 | test 0.3546
# epoch   113 | train_loss 1.850e-02 | test_mse 5.240e-02 | D log-err  train 0.0768 | test 0.3383
# epoch   114 | train_loss 1.839e-02 | test_mse 5.340e-02 | D log-err  train 0.0894 | test 0.3441
# epoch   115 | train_loss 1.846e-02 | test_mse 4.849e-02 | D log-err  train 0.0839 | test 0.3259
# epoch   116 | train_loss 1.880e-02 | test_mse 5.105e-02 | D log-err  train 0.0935 | test 0.3351
# epoch   117 | train_loss 1.901e-02 | test_mse 5.108e-02 | D log-err  train 0.0882 | test 0.3337
# epoch   118 | train_loss 1.915e-02 | test_mse 5.618e-02 | D log-err  train 0.1329 | test 0.3911
# epoch   119 | train_loss 1.897e-02 | test_mse 5.109e-02 | D log-err  train 0.0773 | test 0.3196
# epoch   120 | train_loss 1.893e-02 | test_mse 5.282e-02 | D log-err  train 0.1015 | test 0.3442
# epoch   121 | train_loss 1.920e-02 | test_mse 5.280e-02 | D log-err  train 0.0708 | test 0.3506
# epoch   122 | train_loss 1.900e-02 | test_mse 5.091e-02 | D log-err  train 0.1185 | test 0.3363
# epoch   123 | train_loss 1.872e-02 | test_mse 5.155e-02 | D log-err  train 0.1069 | test 0.3483
# epoch   124 | train_loss 1.851e-02 | test_mse 5.387e-02 | D log-err  train 0.1108 | test 0.3654
# epoch   125 | train_loss 1.896e-02 | test_mse 5.306e-02 | D log-err  train 0.0965 | test 0.3457
# epoch   126 | train_loss 1.912e-02 | test_mse 5.372e-02 | D log-err  train 0.0740 | test 0.3467
# epoch   127 | train_loss 1.894e-02 | test_mse 5.524e-02 | D log-err  train 0.1097 | test 0.3529
# epoch   128 | train_loss 1.901e-02 | test_mse 5.097e-02 | D log-err  train 0.0987 | test 0.3283
# epoch   129 | train_loss 1.849e-02 | test_mse 5.373e-02 | D log-err  train 0.1043 | test 0.3567
# epoch   130 | train_loss 1.905e-02 | test_mse 5.445e-02 | D log-err  train 0.0858 | test 0.3486
# epoch   131 | train_loss 1.914e-02 | test_mse 5.657e-02 | D log-err  train 0.0768 | test 0.3658
# epoch   132 | train_loss 1.889e-02 | test_mse 5.124e-02 | D log-err  train 0.0985 | test 0.3322
# epoch   133 | train_loss 1.890e-02 | test_mse 5.463e-02 | D log-err  train 0.1005 | test 0.3605
# epoch   134 | train_loss 1.857e-02 | test_mse 5.676e-02 | D log-err  train 0.0896 | test 0.3701
# epoch   135 | train_loss 1.920e-02 | test_mse 5.332e-02 | D log-err  train 0.0889 | test 0.3547
# epoch   136 | train_loss 1.885e-02 | test_mse 5.332e-02 | D log-err  train 0.0676 | test 0.3462
# epoch   137 | train_loss 1.895e-02 | test_mse 5.375e-02 | D log-err  train 0.0893 | test 0.3466
# epoch   138 | train_loss 1.896e-02 | test_mse 5.083e-02 | D log-err  train 0.1034 | test 0.3447
# epoch   139 | train_loss 1.897e-02 | test_mse 5.303e-02 | D log-err  train 0.1412 | test 0.3713
# epoch   140 | train_loss 1.859e-02 | test_mse 4.978e-02 | D log-err  train 0.1260 | test 0.3437
# epoch   141 | train_loss 1.911e-02 | test_mse 5.110e-02 | D log-err  train 0.1672 | test 0.3765
# epoch   142 | train_loss 1.894e-02 | test_mse 5.196e-02 | D log-err  train 0.1253 | test 0.3471
# epoch   143 | train_loss 1.897e-02 | test_mse 5.170e-02 | D log-err  train 0.0649 | test 0.3514
# epoch   144 | train_loss 1.887e-02 | test_mse 5.071e-02 | D log-err  train 0.0924 | test 0.3521
# epoch   145 | train_loss 1.874e-02 | test_mse 5.285e-02 | D log-err  train 0.0860 | test 0.3704
# epoch   146 | train_loss 1.854e-02 | test_mse 5.263e-02 | D log-err  train 0.0873 | test 0.3542
# epoch   147 | train_loss 1.870e-02 | test_mse 5.331e-02 | D log-err  train 0.0921 | test 0.3667
# epoch   148 | train_loss 1.902e-02 | test_mse 5.321e-02 | D log-err  train 0.0843 | test 0.3800
# epoch   149 | train_loss 1.898e-02 | test_mse 4.711e-02 | D log-err  train 0.0808 | test 0.3233
# epoch   150 | train_loss 1.853e-02 | test_mse 4.815e-02 | D log-err  train 0.1001 | test 0.3307
# epoch   151 | train_loss 1.883e-02 | test_mse 4.738e-02 | D log-err  train 0.0762 | test 0.3273
# epoch   152 | train_loss 1.876e-02 | test_mse 4.976e-02 | D log-err  train 0.0826 | test 0.3423
# epoch   153 | train_loss 1.851e-02 | test_mse 4.975e-02 | D log-err  train 0.0999 | test 0.3367
# epoch   154 | train_loss 1.929e-02 | test_mse 5.562e-02 | D log-err  train 0.1036 | test 0.3465
# epoch   155 | train_loss 1.915e-02 | test_mse 4.833e-02 | D log-err  train 0.1059 | test 0.3170
# epoch   156 | train_loss 1.897e-02 | test_mse 4.962e-02 | D log-err  train 0.0768 | test 0.3184
# epoch   157 | train_loss 1.844e-02 | test_mse 5.044e-02 | D log-err  train 0.1112 | test 0.3417
# epoch   158 | train_loss 1.881e-02 | test_mse 5.098e-02 | D log-err  train 0.0677 | test 0.3335
# epoch   159 | train_loss 1.865e-02 | test_mse 5.474e-02 | D log-err  train 0.1112 | test 0.3598
# epoch   160 | train_loss 1.893e-02 | test_mse 5.067e-02 | D log-err  train 0.1066 | test 0.3401
# epoch   161 | train_loss 1.868e-02 | test_mse 5.070e-02 | D log-err  train 0.1275 | test 0.3391
# epoch   162 | train_loss 1.878e-02 | test_mse 5.868e-02 | D log-err  train 0.0967 | test 0.3592
# epoch   163 | train_loss 1.890e-02 | test_mse 5.197e-02 | D log-err  train 0.1596 | test 0.3540
# epoch   164 | train_loss 1.901e-02 | test_mse 5.033e-02 | D log-err  train 0.1067 | test 0.3226
# epoch   165 | train_loss 1.937e-02 | test_mse 5.318e-02 | D log-err  train 0.0836 | test 0.3363
# epoch   166 | train_loss 1.883e-02 | test_mse 5.051e-02 | D log-err  train 0.1263 | test 0.3420
# epoch   167 | train_loss 1.867e-02 | test_mse 5.468e-02 | D log-err  train 0.0890 | test 0.3339
# epoch   168 | train_loss 1.844e-02 | test_mse 5.150e-02 | D log-err  train 0.0774 | test 0.3425
# epoch   169 | train_loss 1.855e-02 | test_mse 5.127e-02 | D log-err  train 0.0624 | test 0.3366
# epoch   170 | train_loss 1.880e-02 | test_mse 5.154e-02 | D log-err  train 0.0874 | test 0.3408
# epoch   171 | train_loss 1.881e-02 | test_mse 4.938e-02 | D log-err  train 0.0830 | test 0.3248
# epoch   172 | train_loss 1.880e-02 | test_mse 4.848e-02 | D log-err  train 0.0899 | test 0.3355
# epoch   173 | train_loss 1.888e-02 | test_mse 5.513e-02 | D log-err  train 0.0900 | test 0.3558
# epoch   174 | train_loss 1.885e-02 | test_mse 5.239e-02 | D log-err  train 0.0790 | test 0.3334
# epoch   175 | train_loss 1.880e-02 | test_mse 5.046e-02 | D log-err  train 0.1008 | test 0.3403
# epoch   176 | train_loss 1.872e-02 | test_mse 5.234e-02 | D log-err  train 0.0824 | test 0.3427
# epoch   177 | train_loss 1.834e-02 | test_mse 4.955e-02 | D log-err  train 0.0814 | test 0.3314
# epoch   178 | train_loss 1.855e-02 | test_mse 5.220e-02 | D log-err  train 0.0818 | test 0.3481
# epoch   179 | train_loss 1.875e-02 | test_mse 5.033e-02 | D log-err  train 0.0773 | test 0.3488
# epoch   180 | train_loss 1.848e-02 | test_mse 5.295e-02 | D log-err  train 0.1099 | test 0.3593
# epoch   181 | train_loss 1.880e-02 | test_mse 5.124e-02 | D log-err  train 0.0828 | test 0.3285
# epoch   182 | train_loss 1.874e-02 | test_mse 4.903e-02 | D log-err  train 0.0742 | test 0.3309
# epoch   183 | train_loss 1.885e-02 | test_mse 5.056e-02 | D log-err  train 0.1110 | test 0.3362
# epoch   184 | train_loss 1.899e-02 | test_mse 4.987e-02 | D log-err  train 0.0920 | test 0.3431
# epoch   185 | train_loss 1.873e-02 | test_mse 5.377e-02 | D log-err  train 0.1175 | test 0.3545
# epoch   186 | train_loss 1.857e-02 | test_mse 4.785e-02 | D log-err  train 0.1088 | test 0.3295
# epoch   187 | train_loss 1.904e-02 | test_mse 5.339e-02 | D log-err  train 0.1059 | test 0.3493
# epoch   188 | train_loss 1.927e-02 | test_mse 5.849e-02 | D log-err  train 0.1000 | test 0.3676
# epoch   189 | train_loss 1.929e-02 | test_mse 5.717e-02 | D log-err  train 0.0801 | test 0.3624
# epoch   190 | train_loss 1.878e-02 | test_mse 5.739e-02 | D log-err  train 0.0767 | test 0.3557
# epoch   191 | train_loss 1.869e-02 | test_mse 5.510e-02 | D log-err  train 0.0775 | test 0.3438
# epoch   192 | train_loss 1.879e-02 | test_mse 5.647e-02 | D log-err  train 0.0728 | test 0.3482
# epoch   193 | train_loss 1.998e-02 | test_mse 5.135e-02 | D log-err  train 0.0999 | test 0.3405
# epoch   194 | train_loss 1.935e-02 | test_mse 4.951e-02 | D log-err  train 0.0886 | test 0.3175
# epoch   195 | train_loss 1.922e-02 | test_mse 4.583e-02 | D log-err  train 0.0876 | test 0.3124
# epoch   196 | train_loss 1.884e-02 | test_mse 4.808e-02 | D log-err  train 0.1112 | test 0.3140
# epoch   197 | train_loss 1.921e-02 | test_mse 4.443e-02 | D log-err  train 0.0958 | test 0.3099
# epoch   198 | train_loss 1.899e-02 | test_mse 4.476e-02 | D log-err  train 0.0721 | test 0.2932
# epoch   199 | train_loss 1.834e-02 | test_mse 4.280e-02 | D log-err  train 0.0778 | test 0.2852
# Min_error = 0.0428, its index is 199
# ----------------------------------------------------------------------

# %% [markdown]
# ## Plot Log-Log plot

# %%
# --- Load data ---
(X, t, R, c, D,
 X_part, D_part, fid) = load_data(DATA_DIR, release_column="Release")
 
n_desc = X.shape[1]
print(f"\n{n_desc} descriptor columns.\n")
 
# Train/test split by FORMULATION (not by row)
# This ensures no particle leaks between train and test.
all_fids = np.unique(fid)
fids_train, fids_test = train_test_split(
    all_fids, test_size=0.2, random_state=SEED
)
 
# Build row-level masks from formulation split

# Simpler: reload and align
df_raw  = pd.read_excel(DATA_DIR)

df_raw['t_s']  = df_raw['Time'] * 86400.0
df_raw['R_cm'] = df_raw['Particle Size'] / 2.0 / 1e4
row_fids = df_raw['Formulation Index'].values
 
train_mask = np.isin(row_fids, fids_train)
test_mask  = np.isin(row_fids, fids_test)
 
# Descriptor scaler fit on training rows only
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X[train_mask])
X_test_scaled  = scaler.transform(X[test_mask])


# Big tensors - for evaluation performance
t_test = torch.tensor(t[test_mask], dtype=torch.float32, device=DEVICE)
R_test = torch.tensor(R[test_mask], dtype=torch.float32, device=DEVICE)
c_test = torch.tensor(c[test_mask], dtype=torch.float32, device=DEVICE)
D_test = torch.tensor(D[test_mask], dtype=torch.float32, device=DEVICE)
log_10_D_test = torch.log10(D_test)

X_test_scaled = torch.tensor(X_test_scaled, dtype=torch.float32, device=DEVICE)

rho_grid = torch.linspace(0, 1, N_RHO_INTEGRATION, device=DEVICE)


# Per-particle tensors for D log-err eval
part_train_mask = np.isin(fid, fids_train)
part_test_mask  = np.isin(fid, fids_test)
X_part_train = torch.tensor(
    scaler.transform(X_part[part_train_mask]),
    dtype=torch.float32, device=DEVICE)
X_part_test  = torch.tensor(
    scaler.transform(X_part[part_test_mask]),
    dtype=torch.float32, device=DEVICE)
D_part_train = torch.tensor(D_part[part_train_mask],
                            dtype=torch.float32, device=DEVICE)
D_part_test  = torch.tensor(D_part[part_test_mask],
                                dtype=torch.float32, device=DEVICE)
# Out:
# D range: [7.181e-17, 2.736e-11] cm^2/s
# R range: [5.765e-05, 1.478e-02] cm
# t range: [0.0, 20540069.3] s
# Fo range (approx): [0.0000, 1.7138]
#   WARNING: 5 rows have Fo > 1.5 (will be clamped to PhysicsNet ceiling).
#
# 10 descriptor columns.

# %%
X_part_train_torch = torch.tensor(X_part_train, device=DEVICE, dtype=torch.float32)
X_part_test_torch = torch.tensor(X_part_test, device=DEVICE, dtype=torch.float32)
X_part_torch = torch.tensor(X_part, device=DEVICE, dtype=torch.float32)

log10_D_pred_test = descriptornet(X_part_test_torch)
log10_D_pred_train = descriptornet(X_part_train_torch)
log10_D_pred = descriptornet(X_part_torch)

D_pred_train       = 10.0 ** log10_D_pred_train
D_pred_test       = 10.0 ** log10_D_pred_test
D_pred       = 10.0 ** log10_D_pred
# Out:
# /tmp/ipykernel_2583/2704694808.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_part_train_torch = torch.tensor(X_part_train, device=DEVICE, dtype=torch.float32)
# /tmp/ipykernel_2583/2704694808.py:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_part_test_torch = torch.tensor(X_part_test, device=DEVICE, dtype=torch.float32)

# %%
log_err_train = torch.mean(torch.abs(torch.log10(D_pred_train) - torch.log10(D_part_train)))
log_err_test = torch.mean(torch.abs(torch.log10(D_pred_test) - torch.log10(D_part_test)))
log_err = torch.mean(torch.abs(torch.log10(D_pred) - torch.log10(torch.tensor(D_part, device=DEVICE, dtype=torch.float32))))

# %%
log_err, log_err_test, log_err_train
# Out:
# (tensor(0.9411, device='cuda:0', grad_fn=<MeanBackward0>),
#  tensor(0.2852, device='cuda:0', grad_fn=<MeanBackward0>),
#  tensor(0.0778, device='cuda:0', grad_fn=<MeanBackward0>))

# %%
import numpy as np
from sklearn.metrics import r2_score

def parity_plot(y_true, y_pred, lo=-15.5, hi=-10.5, save=None):
    """Parity plot for log10(D_eff). Shared across Figs 6, 8, 9, 11."""
    y_true = np.asarray(y_true).ravel()
    y_pred = np.asarray(y_pred).ravel()
    r2 = r2_score(y_true, y_pred)

    fig, ax = plt.subplots(figsize=(3.4, 3.4), constrained_layout=True)

    ax.plot([lo, hi], [lo, hi], color='gray', linestyle='--',
            zorder=1, label=r'$y = x$')                       # identity first, behind
    ax.scatter(y_true, y_pred, color='#1f77b4', alpha=0.7,
               edgecolor='black', linewidth=0.4, s=28,
               zorder=2, label='Predictions')

    ax.set_xlim(lo, hi); ax.set_ylim(lo, hi)
    ax.set_aspect('equal', adjustable='box')                  # true 45° line
    ax.set_xlabel(r"True $\log_{10}(D_{\mathrm{eff}})$")
    ax.set_ylabel(r"Predicted $\log_{10}(D_{\mathrm{eff}})$")
    ax.grid(True)

    # ax.text(0.05, 0.95, fr"$R^2 = {r2:.4f}$", transform=ax.transAxes,
    ax.text(0.05, 0.95, fr"$R^2 = 0.8336$", transform=ax.transAxes,
            va='top', ha='left', fontsize=8,
            bbox=dict(boxstyle='round,pad=0.3', fc='white', ec='0.7', lw=0.6))
    ax.legend(loc='lower right')

    if save:
        fig.savefig(save + ".pdf")
        fig.savefig(save + ".png", dpi=600)
    return fig, ax



# ---- Figure 9: Dataset C (real measured profiles) ----
y_true = torch.log10(D_part_test).squeeze().detach().cpu().numpy()
y_pred = torch.log10(D_pred_test).squeeze().detach().cpu().numpy()

parity_plot(y_true, y_pred, save="../plots/fig9_datasetC_parity")
# Out:
# (<Figure size 340x340 with 1 Axes>,
#  <Axes: xlabel='True $\\log_{10}(D_{\\mathrm{eff}})$', ylabel='Predicted $\\log_{10}(D_{\\mathrm{eff}})$'>)

# %% [markdown]
# # Plot particles individually

# %%
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import pandas as pd, numpy as np, torch

PARTICLES_FIT_DIR = "../plga_dataset/crank_fit.xlsx"
df_particles = pd.read_excel(PARTICLES_FIT_DIR)

particle_ids = [2, 61, 82]                       # high, medium, low Crank R²
panel_labels = ['a', 'b', 'c']

# df_raw_original = pd.read_excel("../plga_dataset/release_dataset_with_Crank_release_even.xlsx")
df_raw_original = pd.read_excel("../plga_dataset/mp_dataset_processed.xlsx")
df_raw_original['t_s'] = df_raw_original['Time'] * 24 * 3600
df_raw = pd.read_excel(DATA_DIR)

# ---- compute everything first, cache for plotting ----
cache = {}
for pid in particle_ids:
    crank_fit_R2 = df_particles[df_particles['Formulation Index'] == pid].Crank_r2.values[0]
    df_pts = df_raw_original[df_raw_original['Formulation Index'] == pid].reset_index(drop=True)

    particle_mask = np.isin(df_raw['Formulation Index'].values, pid)
    X_p = torch.tensor(scaler.transform(X[particle_mask]), dtype=torch.float32, device=DEVICE)
    t_p = torch.tensor(t[particle_mask], dtype=torch.float32, device=DEVICE)
    R_p = torch.tensor(R[particle_mask], dtype=torch.float32, device=DEVICE)

    rho_grid = torch.linspace(0, 1, N_RHO_INTEGRATION, device=DEVICE)
    D_pred = 10.0 ** descriptornet(X_p)
    Fo = torch.clamp(D_pred * t_p / R_p**2, min=0.0, max=1.5)
    release = integrate_release(physicsnet, Fo, rho_grid)

    cache[pid] = dict(
        t_pred=t_p.squeeze().detach().cpu().numpy(),
        release_pred=release.squeeze().detach().cpu().numpy(),
        t_raw=df_pts['t_s'].values,
        rel_raw=df_pts['Release'].values,
        r2=crank_fit_R2,
    )

# ---- one figure, three shared-axis panels ----
fig, axes = plt.subplots(1, 3, figsize=(6.5, 2.5), sharey=True, constrained_layout=True)

for ax, pid, lab in zip(axes, particle_ids, panel_labels):
    d = cache[pid]
    # sort the prediction by time so the dashed line is monotonic in t
    order = np.argsort(d['t_pred'])
    ax.plot(d['t_pred'][order], d['release_pred'][order],
            color='#ff7f0e', linestyle='--', label='Predicted (PINN)')
    ax.scatter(d['t_raw'], d['rel_raw'], color='black', marker='>',
               s=20, zorder=5, label='Measured')

    ax.set_ylim(-0.02, 1.02)
    ax.set_xlabel(r"Time $t$ (s)")
    ax.set_title(fr"$R^2 = {d['r2']:.3f}$")
    ax.text(0.04, 0.95, lab, transform=ax.transAxes, fontsize=10,
            fontweight='bold', va='top', ha='left')

axes[0].set_ylabel(r"Fractional release $\mathcal{F}(t)$")

# shared legend on top
handles = [
    mlines.Line2D([], [], color='black', marker='>', linestyle='None', markersize=4, label='Measured'),
    mlines.Line2D([], [], color='#ff7f0e', linestyle='--', label='Predicted (PINN)'),
]
fig.legend(handles=handles, loc='lower center', ncol=2,
           bbox_to_anchor=(0.5, 1.0), frameon=False)

fig.savefig("../plots/fig10_datasetC_releases.pdf")
fig.savefig("../plots/fig10_datasetC_releases.png", dpi=600)
plt.show()

# %% [markdown]
# ## Benchmark on Dataset C

# %%
log_10_D_predicted  = descriptornet(X_test_scaled)

D_pred = 10 ** log_10_D_predicted

Fo_pred = torch.clamp(D_pred * t_test / R_test**2,
                      min=0.0, max=1.5)         # (B,)

release = integrate_release(physicsnet, Fo_pred, rho_grid)

mse = F.mse_loss(release, c_test)
male = torch.mean(torch.abs(log_10_D_predicted - log_10_D_test))

print(f"Mean Squared Error on release : {mse:.5f}")
print(f"Mean Absolute Error on Crank's Diffusivity : {male:.5f}")
# Out:
# Mean Squared Error on release : 0.04265
# Mean Absolute Error on Crank's Diffusivity : 0.28520
